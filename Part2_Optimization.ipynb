# %% [markdown]
# $$
# \newcommand{\mat}[1]{\boldsymbol {#1}}
# \newcommand{\mattr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\matinv}[1]{\boldsymbol {#1}^{-1}}
# \newcommand{\vec}[1]{\boldsymbol {#1}}
# \newcommand{\vectr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\rvar}[1]{\mathrm {#1}}
# \newcommand{\rvec}[1]{\boldsymbol{\mathrm{#1}}}
# \newcommand{\diag}{\mathop{\mathrm {diag}}}
# \newcommand{\set}[1]{\mathbb {#1}}
# \newcommand{\norm}[1]{\left\lVert#1\right\rVert}
# \newcommand{\pderiv}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\bb}[1]{\boldsymbol{#1}}
# $$
# # Part 2: Optimization and Training
# <a id=part2></a>

# %% [markdown]
# In this part we will learn how to implement optimization algorithms for deep networks. Additionally, we'll learn how to write training loops and implement a modular model trainer.
# We'll use our optimizers and training code to test a few configurations for classifying images with an MLP model.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import unittest
import torch
import torchvision
import torchvision.transforms as tvtf

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

seed = 42

plt.rcParams.update({'font.size': 12})
test = unittest.TestCase()

# %% [markdown]
# ## Implementing Optimization Algorithms
# <a id=part2_1></a>

# %% [markdown]
# In the context of deep learning, an optimization algorithm is some method of iteratively updating model parameters so that the loss converges toward some local minimum (which we hope will be good enough).
#
# Gradient descent-based methods are by far the most popular algorithms for optimization of neural network parameters.
# However the high-dimensional loss-surfaces we encounter in deep learning applications are highly non-convex.
# They may be riddled with local minima, saddle points, large plateaus and a host of very challenging "terrain" for gradient-based optimization.
# This gave rise to many different methods of performing the parameter updates based on the loss gradients,
# aiming to tackle these optimization challenges.
#
# The most basic gradient-based update rule can be written as,
#
# $$
# \vec{\theta} \leftarrow \vec{\theta} - \eta \nabla_{\vec{\theta}} L(\vec{\theta}; \mathcal{D})
# $$
#
# where $\mathcal{D} = \left\{ (\vec{x}^i, \vec{y}^i) \right\}_{i=1}^{M}$ is our training dataset or part of it. Specifically, if we have in total $N$ training samples, then
# - If $M=N$ this is known as regular gradient descent. If the dataset does not fit in memory it becomes infeasible to compute.
# - If $M=1$, the loss is computed w.r.t. a single different sample each time. This is known as stochastic gradient descent.
# - If $1<M<N$ this is known as stochastic mini-batch gradient descent. This is the most commonly-used option.
#
# The intuition behind gradient descent is simple: since the gradient of a multivariate function points to the direction of steepest ascent ("uphill"), we move in the opposite direction. A small step size $\eta$ known as the **learning rate** is required since, as with any derivative, the gradient's value is only accurate close to the point it was evaluated at (the current value of $\vec{\theta}$).
#
# <img src="imgs/sgd2d.png" width="600" />
#
# The idea behind the stochastic versions is that by constantly changing the samples we compute the loss with,
# we get a dynamic error surface, i.e. it's different for each set of training samples.
# This is thought to generally improve the optimization since it may help the optimizer get out of flat regions or sharp local minima since these features may disappear in the loss surface of subsequent batches. The image below illustrates this. The different lines are different 1-dimensional losses for different training set-samples.
#
# <img src="imgs/sgd1d.png" width="600" />

# %% [markdown]
# Deep learning frameworks generally provide implementations of various gradient-based optimization algorithms.
# Here we'll implement our own optimization module from scratch, this time keeping a similar API to the PyTorch `optim` package.
#
# We define a base `Optimizer` class. An optimizer holds a set of parameter tensors (these are the trainable parameters of some model) and maintains internal state. It may be used as follows:
# - After the forward pass has been performed the optimizer's `zero_grad()` function is invoked to clear the parameter gradients computed by previous iterations.
# - After the backward pass has been performed, and gradients have been calculated for these parameters, the optimizer's `step()` function is invoked in order to update the value of each parameter based on it's gradient.
#
# The exact method of update is implementation-specific for each optimizer and may depend on it's internal state. In addition, adding the regularization penalty to the gradient is handled by the optimizer since it only depends on the parameter values (and not the data).

# %% [markdown]
# Here's the API of our `Optimizer`:

# %%
import hw2.optimizers as optimizers
help(optimizers.Optimizer)
# Out:
# Help on class Optimizer in module hw2.optimizers:
#
# class Optimizer(abc.ABC)
#  |  Optimizer(params)
#  |
#  |  Base class for optimizers.
#  |
#  |  Method resolution order:
#  |      Optimizer
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, params)
#  |      :param params: A sequence of model parameters to optimize. Can be a
#  |      list of (param,grad) tuples as returned by the Blocks, or a list of
#  |      pytorch tensors in which case the grad will be taken from them.
#  |
#  |  step(self)
#  |      Updates all the registered parameter values based on their gradients.
#  |
#  |  zero_grad(self)
#  |      Sets the gradient of the optimized parameters to zero (in place).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  params
#  |      :return: A sequence of parameter tuples, each tuple containing
#  |      (param_data, param_grad). The data should be updated in-place
#  |      according to the grad.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset({'step'})

# %% [markdown]
# ## Vanilla SGD with Regularization
# <a id=part2_2></a>

# %% [markdown]
# Let's start by implementing the simplest gradient based optimizer. The update rule will be exacly as stated above, but we'll also add a L2-regularization term to the gradient. Remember that in the **loss function**, the L2 regularization term is expressed by
#
# $$R(\vec{\theta}) = \frac{1}{2}\lambda||\vec{\theta}||^2_2.$$

# %% [markdown]
# **TODO**: Complete the implementation of the `VanillaSGD` class in the `hw2/optimizers.py` module.

# %%
# Test VanillaSGD
torch.manual_seed(42)
p = torch.randn(500, 10)
dp = torch.randn(*p.shape)*2
params = [(p, dp)]

vsgd = optimizers.VanillaSGD(params, learn_rate=0.5, reg=0.1)
vsgd.step()

expected_p = torch.load('tests/assets/expected_vsgd.pt')
diff = torch.norm(p-expected_p).item()
print(f'diff={diff}')
test.assertLess(diff, 1e-3)
# Out:
# diff=0.0

# %% [markdown]
# ## Training
# <a id=part2_3></a>

# %% [markdown]
# Now that we can build a model and loss function, compute their gradients and we have an optimizer, we can finally do some training!
#
# In the spirit of more modular software design, we'll implement a class that will aid us in automating the repetitive training loop code that we usually write over and over again. This will be useful for both training our `Block`-based models and also later for training PyTorch `nn.Module`s.
#
# Here's our `Trainer` API:

# %%
import hw2.training as training
help(training.Trainer)
# Out:
# Help on class Trainer in module hw2.training:
#
# class Trainer(abc.ABC)
#  |  Trainer(model, loss_fn, optimizer, device=None)
#  |
#  |  A class abstracting the various tasks of training models.
#  |  Provides methods at multiple levels of granularity:
#  |  - Multiple epochs (fit)
#  |  - Single epoch (train_epoch/test_epoch)
#  |  - Single batch (train_batch/test_batch)
#  |
#  |  Method resolution order:
#  |      Trainer
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, model, loss_fn, optimizer, device=None)
#  |      Initialize the trainer.
#  |      :param model: Instance of the model to train.
#  |      :param loss_fn: The loss function to evaluate with.
#  |      :param optimizer: The optimizer to train with.
#  |      :param device: torch.device to run training on (CPU or GPU).
#  |
#  |  fit(self, dl_train: torch.utils.data.dataloader.DataLoader, dl_test: torch.utils.data.dataloader.DataLoader, num_epochs, checkpoints: str = None, early_stopping: int = None, print_every=1, **kw) -> helpers.train_results.FitResult
#  |      Trains the model for multiple epochs with a given training set,
#  |      and calculates validation loss over a given validation set.
#  |      :param dl_train: Dataloader for the training set.
#  |      :param dl_test: Dataloader for the test set.
#  |      :param num_epochs: Number of epochs to train for.
#  |      :param checkpoints: Whether to save model to file every time the
#  |          test set accuracy improves. Should be a string containing a
#  |          filename without extension.
#  |      :param early_stopping: Whether to stop training early if there is no
#  |          test loss improvement for this number of epochs.
#  |      :param print_every: Print progress every this number of epochs.
#  |      :return: A FitResult object containing train and test losses per epoch.
#  |
#  |  test_batch(self, batch) -> helpers.train_results.BatchResult
#  |      Runs a single batch forward through the model and calculates loss.
#  |      :param batch: A single batch of data  from a data loader (might
#  |          be a tuple of data and labels or anything else depending on
#  |          the underlying dataset.
#  |      :return: A BatchResult containing the value of the loss function and
#  |          the number of correctly classified samples in the batch.
#  |
#  |  test_epoch(self, dl_test: torch.utils.data.dataloader.DataLoader, **kw) -> helpers.train_results.EpochResult
#  |      Evaluate model once over a test set (single epoch).
#  |      :param dl_test: DataLoader for the test set.
#  |      :param kw: Keyword args supported by _foreach_batch.
#  |      :return: An EpochResult for the epoch.
#  |
#  |  train_batch(self, batch) -> helpers.train_results.BatchResult
#  |      Runs a single batch forward through the model, calculates loss,
#  |      preforms back-propagation and uses the optimizer to update weights.
#  |      :param batch: A single batch of data  from a data loader (might
#  |          be a tuple of data and labels or anything else depending on
#  |          the underlying dataset.
#  |      :return: A BatchResult containing the value of the loss function and
#  |          the number of correctly classified samples in the batch.
#  |
#  |  train_epoch(self, dl_train: torch.utils.data.dataloader.DataLoader, **kw) -> helpers.train_results.EpochResult
#  |      Train once over a training set (single epoch).
#  |      :param dl_train: DataLoader for the training set.
#  |      :param kw: Keyword args supported by _foreach_batch.
#  |      :return: An EpochResult for the epoch.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset({'test_batch', 'train_batch'})

# %% [markdown]
# The `Trainer` class splits the task of training (and evaluating) models into three conceptual levels,
# - Multiple epochs - the `fit` method, which returns a `FitResult` containing losses and accuracies for all epochs.
# - Single epoch - the `train_epoch` and `test_epoch` methods, which return an `EpochResult` containing losses per batch and the single accuracy result of the epoch.
# - Single batch - the `train_batch` and `test_batch` methods, which return a `BatchResult` containing a single loss and the number of correctly classified samples in the batch.
#
# It implements the first two levels. Inheriting classes are expected to implement the single-batch level methods since these are model and/or task specific.

# %% [markdown]
# The first thing we should do in order to verify our model, gradient calculations and optimizer implementation is to try to overfit a large model (many parameters) to a small dataset (few images). This will show us that things are working properly.
#
# Let's begin by loading the CIFAR-10 dataset.

# %% [markdown]
# Note: If you enconter an [SSL: CERTIFICATE_VERIFY_FAILED], uncomment the below lines and run them.

# %%
import ssl 
ssl._create_default_https_context = ssl._create_unverified_context

# %%
data_dir = os.path.join(os.getcwd(), '.pytorch-datasets')
ds_train = torchvision.datasets.CIFAR10(root=data_dir, download=True, train=True, transform=tvtf.ToTensor())
ds_test = torchvision.datasets.CIFAR10(root=data_dir, download=True, train=False, transform=tvtf.ToTensor())

print(f'Train: {len(ds_train)} samples')
print(f'Test: {len(ds_test)} samples')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Train: 50000 samples
# Test: 10000 samples

# %% [markdown]
# Now, let's implement just a small part of our training logic since that's what we need right now.

# %% [markdown]
# **TODO**:
# 1. Complete the implementation of the `train_batch()` method in the `BlocksTrainer` class within the `hw2/training.py` module.
# 1. Update the hyperparameter values in the `part2_overfit_hp()` function in the `hw2/answers.py` module. Tweak the hyperparameter values until your model overfits a small number of samples in the block below. You should get 100% accuracy within a few epochs.

# %%
import hw2.blocks as blocks
import hw2.models as models
import hw2.answers as answers
from torch.utils.data import DataLoader

# Overfit to a very small dataset of 20 samples
batch_size = 10
max_batches = 2
dl_train = torch.utils.data.DataLoader(ds_train, batch_size, shuffle=False)

# Get hyperparameters
hp = answers.part2_overfit_hp()

torch.manual_seed(seed)

# Build a model and loss using our custom MLP and CE implementations
model = models.MLP(3*32*32, num_classes=10, hidden_features=[128]*3, wstd=hp['wstd'])
loss_fn = blocks.CrossEntropyLoss()

# Use our custom optimizer
optimizer = optimizers.VanillaSGD(model.params(), learn_rate=hp['lr'], reg=hp['reg'])

# Run training over small dataset multiple times
trainer = training.BlocksTrainer(model, loss_fn, optimizer)
best_acc = 0
for i in range(20):
    res = trainer.train_epoch(dl_train, max_batches=max_batches)
    best_acc = res.accuracy if res.accuracy > best_acc else best_acc
    
test.assertGreaterEqual(best_acc, 98)
# Out:
# train_batch (Avg. Loss 7.353, Accuracy 20.0): 100%|██████████| 2/2 [00:00<00:00, 80.21it/s]
# train_batch (Avg. Loss 21.743, Accuracy 15.0): 100%|██████████| 2/2 [00:00<00:00, 91.15it/s]
# train_batch (Avg. Loss 4.461, Accuracy 10.0): 100%|██████████| 2/2 [00:00<00:00, 77.13it/s]
# train_batch (Avg. Loss 2.402, Accuracy 35.0): 100%|██████████| 2/2 [00:00<00:00, 87.18it/s]
# train_batch (Avg. Loss 1.275, Accuracy 55.0): 100%|██████████| 2/2 [00:00<00:00, 66.85it/s]
# train_batch (Avg. Loss 0.668, Accuracy 95.0): 100%|██████████| 2/2 [00:00<00:00, 45.58it/s]
# train_batch (Avg. Loss 0.487, Accuracy 95.0): 100%|██████████| 2/2 [00:00<00:00, 80.22it/s]
# train_batch (Avg. Loss 0.375, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 77.13it/s]
# train_batch (Avg. Loss 0.295, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 71.62it/s]
# train_batch (Avg. Loss 0.246, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 25.38it/s]
# train_batch (Avg. Loss 0.208, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 87.19it/s]
# train_batch (Avg. Loss 0.179, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 95.50it/s]
# train_batch (Avg. Loss 0.156, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 83.56it/s]
# train_batch (Avg. Loss 0.137, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 80.10it/s]
# train_batch (Avg. Loss 0.123, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 90.98it/s]
# train_batch (Avg. Loss 0.111, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 68.80it/s]
# train_batch (Avg. Loss 0.101, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 80.08it/s]
# train_batch (Avg. Loss 0.092, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 95.22it/s]
# train_batch (Avg. Loss 0.084, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 76.85it/s]
# train_batch (Avg. Loss 0.078, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 79.75it/s]

# %% [markdown]
# Now that we know training works, let's try to fit a model to a bit more data for a few epochs, to see how well we're doing. First, we need a function to plot the FitResults object.

# %%
from helpers.plot import plot_fit
plot_fit?
# Out:
# Signature:
# plot_fit(
#     fit_res: helpers.train_results.FitResult,
#     fig=None,
#     log_loss=False,
#     legend=None,
# )
# Docstring:
# Plots a FitResult object.
# Creates four plots: train loss, test loss, train acc, test acc.
# :param fit_res: The fit result to plot.
# :param fig: A figure previously returned from this function. If not None,
#     plots will the added to this figure.
# :param log_loss: Whether to plot the losses in log scale.
# :param legend: What to call this FitResult in the legend.
# :return: The figure.
# File:      c:\users\user\desktop\university\masters\semester4\assignment2\helpers\plot.py
# Type:      function

# %% [markdown]
# **TODO**:
# 1. Complete the implementation of the `test_batch()` method in the `BlocksTrainer` class within the `hw2/training.py` module.
# 1. Implement the `fit()` method of the `Trainer` class within the `hw2/training.py` module.
# 1. Tweak the hyperparameters for this section in the `part2_optim_hp()` function in the `hw2/answers.py` module.
# 1. Run the following blocks to train. Try to get above 35-40% test-set accuracy.

# %%
# Define a larger part of the CIFAR-10 dataset (still not the whole thing)
batch_size = 50
max_batches = 100
in_features = 3*32*32
num_classes = 10
dl_train = torch.utils.data.DataLoader(ds_train, batch_size, shuffle=False)
dl_test = torch.utils.data.DataLoader(ds_test, batch_size//2, shuffle=False)

# %%
# Define a function to train a model with our Trainer and various optimizers
def train_with_optimizer(opt_name, opt_class, fig):
    torch.manual_seed(seed)
    
    # Get hyperparameters
    hp = answers.part2_optim_hp(opt_name)
    hidden_features = [128] * 5
    num_epochs = 10
    
    # Create model, loss and optimizer instances
    model = models.MLP(in_features, num_classes, hidden_features, wstd=hp['wstd'])
    loss_fn = blocks.CrossEntropyLoss()
    optimizer = opt_class(model.params(), learn_rate=hp['lr'], reg=hp['reg'])

    # Train with the Trainer
    trainer = training.BlocksTrainer(model, loss_fn, optimizer)
    fit_res = trainer.fit(dl_train, dl_test, num_epochs, max_batches=max_batches)
    
    fig, axes = plot_fit(fit_res, fig=fig, legend=opt_name)
    return fig

# %%
fig_optim = None
fig_optim = train_with_optimizer('vanilla', optimizers.VanillaSGD, fig_optim)
# Out:
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.196, Accuracy 19.2): 100%|██████████| 100/100 [00:01<00:00, 54.54it/s]
# test_batch (Avg. Loss 2.113, Accuracy 21.5): 100%|██████████| 100/100 [00:00<00:00, 125.84it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 2.019, Accuracy 26.4): 100%|██████████| 100/100 [00:01<00:00, 54.32it/s]
# test_batch (Avg. Loss 2.011, Accuracy 27.6): 100%|██████████| 100/100 [00:00<00:00, 135.12it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.938, Accuracy 29.4): 100%|██████████| 100/100 [00:01<00:00, 54.05it/s]
# test_batch (Avg. Loss 1.965, Accuracy 29.8): 100%|██████████| 100/100 [00:00<00:00, 134.32it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.880, Accuracy 32.1): 100%|██████████| 100/100 [00:01<00:00, 56.48it/s]
# test_batch (Avg. Loss 1.924, Accuracy 31.6): 100%|██████████| 100/100 [00:00<00:00, 139.13it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.836, Accuracy 34.1): 100%|██████████| 100/100 [00:01<00:00, 56.45it/s]
# test_batch (Avg. Loss 1.896, Accuracy 32.1): 100%|██████████| 100/100 [00:00<00:00, 139.97it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.797, Accuracy 35.3): 100%|██████████| 100/100 [00:01<00:00, 56.74it/s]
# test_batch (Avg. Loss 1.875, Accuracy 33.1): 100%|██████████| 100/100 [00:00<00:00, 141.43it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.766, Accuracy 36.2): 100%|██████████| 100/100 [00:01<00:00, 53.40it/s]
# test_batch (Avg. Loss 1.860, Accuracy 33.4): 100%|██████████| 100/100 [00:00<00:00, 139.07it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.736, Accuracy 37.3): 100%|██████████| 100/100 [00:01<00:00, 57.54it/s]
# test_batch (Avg. Loss 1.838, Accuracy 33.5): 100%|██████████| 100/100 [00:00<00:00, 135.87it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.709, Accuracy 38.4): 100%|██████████| 100/100 [00:01<00:00, 55.93it/s]
# test_batch (Avg. Loss 1.826, Accuracy 34.5): 100%|██████████| 100/100 [00:00<00:00, 136.12it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.682, Accuracy 39.0): 100%|██████████| 100/100 [00:01<00:00, 59.05it/s]
# test_batch (Avg. Loss 1.821, Accuracy 34.6): 100%|██████████| 100/100 [00:00<00:00, 132.00it/s]

# %% [markdown]
# ## Momentum
# <a id=part2_4></a>

# %% [markdown]
# The simple vanilla SGD update is rarely used in practice since it's very slow to converge relative to other optimization algorithms.
#
# One reason is that naïvely updating in the direction of the current gradient causes it to fluctuate wildly in areas of the loss surface where some dimensions are much steeper than others.
# Another reason is that using the same learning rate for all parameters is not a great idea since not all parameters are created equal. For example, parameters associated with rare features should be updated with a larger step than ones associated with commonly-occurring features because they'll get less updates through the gradients.
#
# Therefore more advanced optimizers take into account the previous gradients of a parameter and/or try to use a per-parameter specific learning rate instead of a common one.

# %% [markdown]
# Let's now implement a simple and common optimizer: SGD with Momentum. This optimizer takes **previous gradients** of a parameter into account when updating it's value instead of just the current one. In practice it usually provides faster convergence than the vanilla SGD.
#
# The SGD with Momentum update rule can be stated as follows:
# $$\begin{align}
# \vec{v}_{t+1} &= \mu \vec{v}_t - \eta \delta \vec{\theta}_t \\
# \vec{\theta}_{t+1} &= \vec{\theta}_t + \vec{v}_{t+1}
# \end{align}$$
#
# Where $\eta$ is the learning rate,
# $\vec{\theta}$ is a model parameter,
# $\delta \vec{\theta}_t=\pderiv{L}{\vec{\theta}}(\vec{\theta}_t)$ is the gradient of the loss w.r.t. to the parameter and $\mu$ is a hyperparameter known as momentum.
#
# Expanding the update rule recursively shows us now the parameter update infact depends on all previous gradient values for that parameter, where the old gradients are exponentially decayed by a factor of $\mu$ at each timestep.
#
# Since we're incorporating previous gradient (update directions), a noisy value of the current gradient will have less effect so that the general direction of previous updates is maintained somewhat. The following figure illustrates this.
#
# <img src="imgs/sgd-momentum.png" width="600" />

# %% [markdown]
# **TODO**:
# 1. Complete the implementation of the `MomentumSGD` class in the `hw2/optimizers.py` module.
# 1. Tweak the learning rate for momentum in `part2_optim_hp()` the function in the `hw2/answers.py` module.
# 1. Run the following block to compare to the vanilla SGD.

# %%
fig_optim = train_with_optimizer('momentum', optimizers.MomentumSGD, fig_optim)
fig_optim
# Out:
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.230, Accuracy 17.1): 100%|██████████| 100/100 [00:01<00:00, 51.73it/s]
# test_batch (Avg. Loss 2.101, Accuracy 20.8): 100%|██████████| 100/100 [00:00<00:00, 134.98it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 2.012, Accuracy 25.9): 100%|██████████| 100/100 [00:01<00:00, 55.60it/s]
# test_batch (Avg. Loss 1.998, Accuracy 27.0): 100%|██████████| 100/100 [00:00<00:00, 129.26it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.920, Accuracy 29.4): 100%|██████████| 100/100 [00:01<00:00, 53.86it/s]
# test_batch (Avg. Loss 1.927, Accuracy 31.6): 100%|██████████| 100/100 [00:00<00:00, 139.27it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.855, Accuracy 32.4): 100%|██████████| 100/100 [00:01<00:00, 53.18it/s]
# test_batch (Avg. Loss 1.897, Accuracy 31.8): 100%|██████████| 100/100 [00:00<00:00, 131.24it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.806, Accuracy 34.7): 100%|██████████| 100/100 [00:01<00:00, 55.37it/s]
# test_batch (Avg. Loss 1.868, Accuracy 33.6): 100%|██████████| 100/100 [00:00<00:00, 126.43it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.765, Accuracy 36.4): 100%|██████████| 100/100 [00:01<00:00, 54.17it/s]
# test_batch (Avg. Loss 1.836, Accuracy 34.4): 100%|██████████| 100/100 [00:00<00:00, 140.24it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.724, Accuracy 37.9): 100%|██████████| 100/100 [00:01<00:00, 54.41it/s]
# test_batch (Avg. Loss 1.809, Accuracy 35.3): 100%|██████████| 100/100 [00:00<00:00, 141.83it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.683, Accuracy 39.6): 100%|██████████| 100/100 [00:01<00:00, 51.28it/s]
# test_batch (Avg. Loss 1.784, Accuracy 36.8): 100%|██████████| 100/100 [00:00<00:00, 133.88it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.654, Accuracy 40.6): 100%|██████████| 100/100 [00:01<00:00, 53.99it/s]
# test_batch (Avg. Loss 1.764, Accuracy 37.6): 100%|██████████| 100/100 [00:00<00:00, 131.39it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.618, Accuracy 41.9): 100%|██████████| 100/100 [00:01<00:00, 54.80it/s]
# test_batch (Avg. Loss 1.749, Accuracy 38.3): 100%|██████████| 100/100 [00:00<00:00, 121.37it/s]

# %% [markdown]
# ## RMSProp
# <a id=part2_5></a>

# %% [markdown]
# This is another optmizer that accounts for previous gradients, but this time it uses them to adapt the learning rate per parameter.
#
# RMSProp maintains a decaying moving average of previous squared gradients,
# $$
# \vec{r}_{t+1} = \gamma\vec{r}_{t} + (1-\gamma)\delta\vec{\theta}_t^2
# $$
#
# where $0<\gamma<1$ is a decay constant usually set close to $1$. The update rule for each parameter is then,
# $$
# \vec{\theta}_{t+1} = \vec{\theta}_t - \left( \frac{\eta}{\sqrt{r_{t+1}+\varepsilon}} \right) \delta\vec{\theta}_t
# $$
#
# where $\varepsilon$ is a small constant to prevent numerical instability. The idea here is to decrease the learning rate for parameters with high gradient values and vice-versa. The decaying moving average prevents accumulating all the past gradients which would cause the effective learning rate to become zero.

# %% [markdown]
# **TODO**:
# 1. Complete the implementation of the `RMSProp` class in the `hw2/optimizers.py` module.
# 1. Tweak the learning rate for RMSProp in `part2_optim_hp()` the function in the `hw2/answers.py` module.
# 1. Run the following block to compare to the other optimizers.

# %%
fig_optim = train_with_optimizer('rmsprop', optimizers.RMSProp, fig_optim)
fig_optim
# Out:
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.156, Accuracy 19.7): 100%|██████████| 100/100 [00:02<00:00, 41.82it/s]
# test_batch (Avg. Loss 2.024, Accuracy 26.5): 100%|██████████| 100/100 [00:00<00:00, 144.84it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 1.946, Accuracy 29.0): 100%|██████████| 100/100 [00:02<00:00, 42.02it/s]
# test_batch (Avg. Loss 1.933, Accuracy 31.1): 100%|██████████| 100/100 [00:00<00:00, 141.64it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.865, Accuracy 32.0): 100%|██████████| 100/100 [00:02<00:00, 41.48it/s]
# test_batch (Avg. Loss 1.894, Accuracy 32.7): 100%|██████████| 100/100 [00:00<00:00, 133.34it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.811, Accuracy 34.0): 100%|██████████| 100/100 [00:02<00:00, 42.41it/s]
# test_batch (Avg. Loss 1.868, Accuracy 34.0): 100%|██████████| 100/100 [00:00<00:00, 139.27it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.769, Accuracy 35.5): 100%|██████████| 100/100 [00:02<00:00, 41.03it/s]
# test_batch (Avg. Loss 1.852, Accuracy 33.8): 100%|██████████| 100/100 [00:00<00:00, 128.71it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.734, Accuracy 37.3): 100%|██████████| 100/100 [00:02<00:00, 41.74it/s]
# test_batch (Avg. Loss 1.847, Accuracy 34.5): 100%|██████████| 100/100 [00:00<00:00, 135.69it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.703, Accuracy 38.6): 100%|██████████| 100/100 [00:02<00:00, 41.00it/s]
# test_batch (Avg. Loss 1.817, Accuracy 34.8): 100%|██████████| 100/100 [00:00<00:00, 130.39it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.672, Accuracy 40.1): 100%|██████████| 100/100 [00:02<00:00, 41.00it/s]
# test_batch (Avg. Loss 1.817, Accuracy 35.6): 100%|██████████| 100/100 [00:00<00:00, 143.88it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.645, Accuracy 41.3): 100%|██████████| 100/100 [00:02<00:00, 41.31it/s]
# test_batch (Avg. Loss 1.806, Accuracy 35.6): 100%|██████████| 100/100 [00:00<00:00, 124.94it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.619, Accuracy 42.3): 100%|██████████| 100/100 [00:02<00:00, 41.67it/s]
# test_batch (Avg. Loss 1.760, Accuracy 37.6): 100%|██████████| 100/100 [00:00<00:00, 134.06it/s]

# %% [markdown]
# Note that you should get better train/test accuracy with Momentum and RMSProp than Vanilla.

# %% [markdown]
# ## Dropout Regularization
# <a id=part2_6></a>

# %% [markdown]
# [Dropout](http://jmlr.org/papers/volume15/srivastava14a.old/srivastava14a.pdf) is a useful technique to improve generalization of deep models.
#
# The idea is simple: during the forward pass drop, i.e. set to to zero, the activation of each neuron, with a probability of $p$. For example, if $p=0.5$ this means we drop half the activations on average.
#
# There are a few important things to note about dropout:
# 1. It is only performed during training. When testing our model the dropout layers should be a no-op.
# 1. In the backward pass, gradients are only propagated back into neurons that weren't dropped during the forward pass.
# 1. During testing, the activations must be scaled since the expected value of each neuron during the training phase is now $1-p$ times it's original expectation. Thus, we need to scale the test-time activations by $1-p$ to match. Equivalently, we can scale the train time activations by $1/(1-p)$.

# %% [markdown]
# **TODO**: Complete the implementation of the `Dropout` class in the `hw2/blocks.py` module.

# %%
from hw2.grad_compare import compare_block_to_torch

# Check architecture of MLP with dropout layers
mlp_dropout = models.MLP(in_features, num_classes, [50]*3, dropout=0.6)
print(mlp_dropout)
test.assertEqual(len(mlp_dropout.sequence), 10)
for b1, b2 in zip(mlp_dropout.sequence, mlp_dropout.sequence[1:]):
    if str(b1) == 'relu':
        test.assertTrue(str(b2).startswith('Dropout'))
test.assertTrue(str(mlp_dropout.sequence[-1]).startswith('Linear'))

# Test end-to-end gradient in train and test modes.
mlp_dropout.train(True)
for diff in compare_block_to_torch(mlp_dropout, torch.randn(500, in_features)):
    test.assertLess(diff, 1e-2)
    
mlp_dropout.train(False)
for diff in compare_block_to_torch(mlp_dropout, torch.randn(500, in_features)):
    test.assertLess(diff, 1e-2)
# Out:
# MLP, Sequential
# 	[0] Linear(3072, 50)
# 	[1] ReLU
# 	[2] Dropout(p=0.6)
# 	[3] Linear(50, 50)
# 	[4] ReLU
# 	[5] Dropout(p=0.6)
# 	[6] Linear(50, 50)
# 	[7] ReLU
# 	[8] Dropout(p=0.6)
# 	[9] Linear(50, 10)
#
# Comparing gradients...
# input    diff=0.000
# param#01 diff=0.000
# param#02 diff=0.000
# param#03 diff=0.000
# param#04 diff=0.000
# param#05 diff=0.000
# param#06 diff=0.000
# param#07 diff=0.000
# param#08 diff=0.000
# Comparing gradients...
# input    diff=0.000
# param#01 diff=0.000
# param#02 diff=0.000
# param#03 diff=0.000
# param#04 diff=0.000
# param#05 diff=0.000
# param#06 diff=0.000
# param#07 diff=0.000
# param#08 diff=0.000

# %% [markdown]
# To see whether dropout really improves generalization, let's take a small training set
# (small enough to overfit) and a large test set and check whether we get less overfitting and
# perhaps improved test-set accuracy when using dropout.

# %%
# Define a small set from CIFAR-10, but take a larger test set since we want to test generalization
batch_size = 10
max_batches = 40
in_features = 3*32*32
num_classes = 10
dl_train = torch.utils.data.DataLoader(ds_train, batch_size, shuffle=False)
dl_test = torch.utils.data.DataLoader(ds_test, batch_size*2, shuffle=False)

# %% [markdown]
# **TODO**:
# Tweak the hyperparameters for this section in the `part2_dropout_hp()` function in the `hw2/answers.py` module. Try to set them so that the first model (with `dropout`=0) overfits. You can disable the other dropout options until you tune the hyperparameters. We can then see the effect of dropout for generalization.

# %%
# Get hyperparameters
hp = answers.part2_dropout_hp()
hidden_features = [400] * 1
num_epochs = 30

# %%
torch.manual_seed(seed)
fig=None
for dropout in [0, 0.4, 0.8]:
# for dropout in [0]:
    model = models.MLP(in_features, num_classes, hidden_features, wstd=hp['wstd'], dropout=dropout)
    loss_fn = blocks.CrossEntropyLoss()
    optimizer = optimizers.MomentumSGD(model.params(), learn_rate=hp['lr'], reg=0)

    print('*** Training with dropout=', dropout)
    trainer = training.BlocksTrainer(model, loss_fn, optimizer)
    fit_res_dropout = trainer.fit(dl_train, dl_test, num_epochs, max_batches=max_batches, print_every=6)
    fig, axes = plot_fit(fit_res_dropout, fig=fig, legend=f'dropout={dropout}', log_loss=True)
# Out:
# *** Training with dropout= 0
# --- EPOCH 1/80 ---
# train_batch (Avg. Loss 3.765, Accuracy 13.0): 100%|██████████| 40/40 [00:00<00:00, 45.51it/s]
# test_batch (Avg. Loss 2.717, Accuracy 17.0): 100%|██████████| 40/40 [00:00<00:00, 183.10it/s]
# train_batch (Avg. Loss 2.302, Accuracy 26.0): 100%|██████████| 40/40 [00:00<00:00, 43.29it/s]
# test_batch (Avg. Loss 2.566, Accuracy 20.1): 100%|██████████| 40/40 [00:00<00:00, 187.81it/s]
# train_batch (Avg. Loss 1.961, Accuracy 35.5): 100%|██████████| 40/40 [00:00<00:00, 46.45it/s]
# test_batch (Avg. Loss 2.676, Accuracy 20.9): 100%|██████████| 40/40 [00:00<00:00, 183.50it/s]
# train_batch (Avg. Loss 1.748, Accuracy 38.5): 100%|██████████| 40/40 [00:00<00:00, 46.46it/s]
# test_batch (Avg. Loss 2.609, Accuracy 19.9): 100%|██████████| 40/40 [00:00<00:00, 153.87it/s]
# train_batch (Avg. Loss 1.600, Accuracy 48.0): 100%|██████████| 40/40 [00:00<00:00, 46.68it/s]
# test_batch (Avg. Loss 2.513, Accuracy 20.6): 100%|██████████| 40/40 [00:00<00:00, 186.07it/s]
# train_batch (Avg. Loss 1.454, Accuracy 52.0): 100%|██████████| 40/40 [00:00<00:00, 46.35it/s]
# test_batch (Avg. Loss 2.456, Accuracy 21.4): 100%|██████████| 40/40 [00:00<00:00, 151.53it/s]
# --- EPOCH 7/80 ---
# train_batch (Avg. Loss 1.340, Accuracy 57.0): 100%|██████████| 40/40 [00:00<00:00, 45.15it/s]
# test_batch (Avg. Loss 2.431, Accuracy 20.9): 100%|██████████| 40/40 [00:00<00:00, 183.53it/s]
# train_batch (Avg. Loss 1.239, Accuracy 60.0): 100%|██████████| 40/40 [00:00<00:00, 44.34it/s]
# test_batch (Avg. Loss 2.415, Accuracy 21.2): 100%|██████████| 40/40 [00:00<00:00, 126.57it/s]
# train_batch (Avg. Loss 1.148, Accuracy 63.0): 100%|██████████| 40/40 [00:00<00:00, 46.12it/s]
# test_batch (Avg. Loss 2.421, Accuracy 21.0): 100%|██████████| 40/40 [00:00<00:00, 185.35it/s]
# train_batch (Avg. Loss 1.069, Accuracy 66.2): 100%|██████████| 40/40 [00:00<00:00, 45.82it/s]
# test_batch (Avg. Loss 2.435, Accuracy 21.9): 100%|██████████| 40/40 [00:00<00:00, 189.60it/s]
# train_batch (Avg. Loss 1.003, Accuracy 70.0): 100%|██████████| 40/40 [00:00<00:00, 43.93it/s]
# test_batch (Avg. Loss 2.447, Accuracy 21.2): 100%|██████████| 40/40 [00:00<00:00, 185.68it/s]
# train_batch (Avg. Loss 0.942, Accuracy 74.8): 100%|██████████| 40/40 [00:00<00:00, 46.79it/s]
# test_batch (Avg. Loss 2.458, Accuracy 21.5): 100%|██████████| 40/40 [00:00<00:00, 186.92it/s]
# --- EPOCH 13/80 ---
# train_batch (Avg. Loss 0.889, Accuracy 76.8): 100%|██████████| 40/40 [00:00<00:00, 43.58it/s]
# test_batch (Avg. Loss 2.463, Accuracy 21.4): 100%|██████████| 40/40 [00:00<00:00, 184.37it/s]
# train_batch (Avg. Loss 0.841, Accuracy 78.2): 100%|██████████| 40/40 [00:00<00:00, 45.71it/s]
# test_batch (Avg. Loss 2.466, Accuracy 21.2): 100%|██████████| 40/40 [00:00<00:00, 187.84it/s]
# train_batch (Avg. Loss 0.798, Accuracy 79.8): 100%|██████████| 40/40 [00:00<00:00, 43.52it/s]
# test_batch (Avg. Loss 2.470, Accuracy 21.5): 100%|██████████| 40/40 [00:00<00:00, 174.67it/s]
# train_batch (Avg. Loss 0.762, Accuracy 81.8): 100%|██████████| 40/40 [00:00<00:00, 45.48it/s]
# test_batch (Avg. Loss 2.471, Accuracy 21.1): 100%|██████████| 40/40 [00:00<00:00, 187.85it/s]
# train_batch (Avg. Loss 0.724, Accuracy 83.5): 100%|██████████| 40/40 [00:00<00:00, 46.10it/s]
# test_batch (Avg. Loss 2.469, Accuracy 20.9): 100%|██████████| 40/40 [00:00<00:00, 151.86it/s]
# train_batch (Avg. Loss 0.695, Accuracy 84.5): 100%|██████████| 40/40 [00:00<00:00, 45.77it/s]
# test_batch (Avg. Loss 2.467, Accuracy 21.5): 100%|██████████| 40/40 [00:00<00:00, 179.36it/s]
# --- EPOCH 19/80 ---
# train_batch (Avg. Loss 0.667, Accuracy 85.0): 100%|██████████| 40/40 [00:00<00:00, 45.10it/s]
# test_batch (Avg. Loss 2.482, Accuracy 21.2): 100%|██████████| 40/40 [00:00<00:00, 186.03it/s]
# train_batch (Avg. Loss 0.641, Accuracy 85.8): 100%|██████████| 40/40 [00:00<00:00, 43.86it/s]
# test_batch (Avg. Loss 2.480, Accuracy 22.1): 100%|██████████| 40/40 [00:00<00:00, 183.26it/s]
# train_batch (Avg. Loss 0.615, Accuracy 87.2): 100%|██████████| 40/40 [00:00<00:00, 45.15it/s]
# test_batch (Avg. Loss 2.506, Accuracy 22.9): 100%|██████████| 40/40 [00:00<00:00, 186.12it/s]
# train_batch (Avg. Loss 0.596, Accuracy 87.8): 100%|██████████| 40/40 [00:00<00:00, 44.64it/s]
# test_batch (Avg. Loss 2.524, Accuracy 23.2): 100%|██████████| 40/40 [00:00<00:00, 150.42it/s]
# train_batch (Avg. Loss 0.576, Accuracy 87.8): 100%|██████████| 40/40 [00:00<00:00, 44.79it/s]
# test_batch (Avg. Loss 2.557, Accuracy 24.0): 100%|██████████| 40/40 [00:00<00:00, 182.66it/s]
# train_batch (Avg. Loss 0.557, Accuracy 88.5): 100%|██████████| 40/40 [00:00<00:00, 45.56it/s]
# test_batch (Avg. Loss 2.583, Accuracy 24.6): 100%|██████████| 40/40 [00:00<00:00, 184.32it/s]
# --- EPOCH 25/80 ---
# train_batch (Avg. Loss 0.533, Accuracy 89.5): 100%|██████████| 40/40 [00:00<00:00, 43.10it/s]
# test_batch (Avg. Loss 2.620, Accuracy 25.5): 100%|██████████| 40/40 [00:00<00:00, 181.88it/s]
# train_batch (Avg. Loss 0.514, Accuracy 89.8): 100%|██████████| 40/40 [00:00<00:00, 45.11it/s]
# test_batch (Avg. Loss 2.646, Accuracy 24.5): 100%|██████████| 40/40 [00:00<00:00, 182.68it/s]
# train_batch (Avg. Loss 0.495, Accuracy 90.5): 100%|██████████| 40/40 [00:00<00:00, 42.91it/s]
# test_batch (Avg. Loss 2.674, Accuracy 24.5): 100%|██████████| 40/40 [00:00<00:00, 183.80it/s]
# train_batch (Avg. Loss 0.475, Accuracy 91.5): 100%|██████████| 40/40 [00:00<00:00, 45.60it/s]
# test_batch (Avg. Loss 2.684, Accuracy 25.1): 100%|██████████| 40/40 [00:00<00:00, 183.49it/s]
# train_batch (Avg. Loss 0.454, Accuracy 92.2): 100%|██████████| 40/40 [00:00<00:00, 42.78it/s]
# test_batch (Avg. Loss 2.694, Accuracy 25.4): 100%|██████████| 40/40 [00:00<00:00, 184.87it/s]
# train_batch (Avg. Loss 0.437, Accuracy 92.5): 100%|██████████| 40/40 [00:00<00:00, 45.27it/s]
# test_batch (Avg. Loss 2.698, Accuracy 25.2): 100%|██████████| 40/40 [00:00<00:00, 184.22it/s]
# --- EPOCH 31/80 ---
# train_batch (Avg. Loss 0.419, Accuracy 93.0): 100%|██████████| 40/40 [00:00<00:00, 45.14it/s]
# test_batch (Avg. Loss 2.701, Accuracy 25.8): 100%|██████████| 40/40 [00:00<00:00, 155.24it/s]
# train_batch (Avg. Loss 0.400, Accuracy 93.5): 100%|██████████| 40/40 [00:00<00:00, 45.45it/s]
# test_batch (Avg. Loss 2.707, Accuracy 25.2): 100%|██████████| 40/40 [00:00<00:00, 182.68it/s]
# train_batch (Avg. Loss 0.384, Accuracy 94.0): 100%|██████████| 40/40 [00:00<00:00, 44.68it/s]
# test_batch (Avg. Loss 2.711, Accuracy 25.1): 100%|██████████| 40/40 [00:00<00:00, 155.81it/s]
# train_batch (Avg. Loss 0.369, Accuracy 95.0): 100%|██████████| 40/40 [00:00<00:00, 45.51it/s]
# test_batch (Avg. Loss 2.715, Accuracy 24.5): 100%|██████████| 40/40 [00:00<00:00, 185.74it/s]
# train_batch (Avg. Loss 0.352, Accuracy 95.8): 100%|██████████| 40/40 [00:00<00:00, 42.38it/s]
# test_batch (Avg. Loss 2.713, Accuracy 24.0): 100%|██████████| 40/40 [00:00<00:00, 193.24it/s]
# train_batch (Avg. Loss 0.336, Accuracy 96.2): 100%|██████████| 40/40 [00:00<00:00, 43.43it/s]
# test_batch (Avg. Loss 2.711, Accuracy 24.0): 100%|██████████| 40/40 [00:00<00:00, 185.78it/s]
# --- EPOCH 37/80 ---
# train_batch (Avg. Loss 0.321, Accuracy 96.5): 100%|██████████| 40/40 [00:00<00:00, 45.30it/s]
# test_batch (Avg. Loss 2.703, Accuracy 24.1): 100%|██████████| 40/40 [00:00<00:00, 186.41it/s]
# train_batch (Avg. Loss 0.305, Accuracy 97.2): 100%|██████████| 40/40 [00:00<00:00, 45.04it/s]
# test_batch (Avg. Loss 2.698, Accuracy 24.5): 100%|██████████| 40/40 [00:00<00:00, 186.00it/s]
# train_batch (Avg. Loss 0.293, Accuracy 97.5): 100%|██████████| 40/40 [00:00<00:00, 42.68it/s]
# test_batch (Avg. Loss 2.701, Accuracy 24.8): 100%|██████████| 40/40 [00:00<00:00, 186.10it/s]
# train_batch (Avg. Loss 0.280, Accuracy 98.0): 100%|██████████| 40/40 [00:00<00:00, 45.51it/s]
# test_batch (Avg. Loss 2.702, Accuracy 24.9): 100%|██████████| 40/40 [00:00<00:00, 187.45it/s]
# train_batch (Avg. Loss 0.269, Accuracy 98.2): 100%|██████████| 40/40 [00:00<00:00, 43.64it/s]
# test_batch (Avg. Loss 2.691, Accuracy 24.9): 100%|██████████| 40/40 [00:00<00:00, 185.79it/s]
# train_batch (Avg. Loss 0.261, Accuracy 98.2): 100%|██████████| 40/40 [00:00<00:00, 45.78it/s]
# test_batch (Avg. Loss 2.701, Accuracy 25.0): 100%|██████████| 40/40 [00:00<00:00, 189.62it/s]
# --- EPOCH 43/80 ---
# train_batch (Avg. Loss 0.252, Accuracy 98.8): 100%|██████████| 40/40 [00:00<00:00, 42.33it/s]
# test_batch (Avg. Loss 2.703, Accuracy 24.5): 100%|██████████| 40/40 [00:00<00:00, 135.60it/s]
# train_batch (Avg. Loss 0.244, Accuracy 99.0): 100%|██████████| 40/40 [00:00<00:00, 43.76it/s]
# test_batch (Avg. Loss 2.716, Accuracy 24.5): 100%|██████████| 40/40 [00:00<00:00, 185.20it/s]
# train_batch (Avg. Loss 0.239, Accuracy 99.2): 100%|██████████| 40/40 [00:00<00:00, 43.52it/s]
# test_batch (Avg. Loss 2.730, Accuracy 24.9): 100%|██████████| 40/40 [00:00<00:00, 140.65it/s]
# train_batch (Avg. Loss 0.231, Accuracy 99.5): 100%|██████████| 40/40 [00:00<00:00, 44.17it/s]
# test_batch (Avg. Loss 2.753, Accuracy 25.0): 100%|██████████| 40/40 [00:00<00:00, 159.39it/s]
# train_batch (Avg. Loss 0.224, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 43.29it/s]
# test_batch (Avg. Loss 2.776, Accuracy 24.5): 100%|██████████| 40/40 [00:00<00:00, 152.02it/s]
# train_batch (Avg. Loss 0.217, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 45.51it/s]
# test_batch (Avg. Loss 2.808, Accuracy 25.2): 100%|██████████| 40/40 [00:00<00:00, 150.42it/s]
# --- EPOCH 49/80 ---
# train_batch (Avg. Loss 0.211, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 45.48it/s]
# test_batch (Avg. Loss 2.836, Accuracy 24.8): 100%|██████████| 40/40 [00:00<00:00, 187.22it/s]
# train_batch (Avg. Loss 0.204, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 44.95it/s]
# test_batch (Avg. Loss 2.872, Accuracy 24.6): 100%|██████████| 40/40 [00:00<00:00, 149.26it/s]
# train_batch (Avg. Loss 0.198, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 45.61it/s]
# test_batch (Avg. Loss 2.901, Accuracy 24.0): 100%|██████████| 40/40 [00:00<00:00, 186.06it/s]
# train_batch (Avg. Loss 0.192, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 45.76it/s]
# test_batch (Avg. Loss 2.931, Accuracy 24.0): 100%|██████████| 40/40 [00:00<00:00, 185.24it/s]
# train_batch (Avg. Loss 0.186, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 45.61it/s]
# test_batch (Avg. Loss 2.948, Accuracy 24.4): 100%|██████████| 40/40 [00:00<00:00, 184.96it/s]
# train_batch (Avg. Loss 0.181, Accuracy 99.8): 100%|██████████| 40/40 [00:01<00:00, 38.16it/s]
# test_batch (Avg. Loss 2.977, Accuracy 24.2): 100%|██████████| 40/40 [00:00<00:00, 134.85it/s]
# --- EPOCH 55/80 ---
# train_batch (Avg. Loss 0.176, Accuracy 99.8): 100%|██████████| 40/40 [00:01<00:00, 38.53it/s]
# test_batch (Avg. Loss 2.990, Accuracy 24.8): 100%|██████████| 40/40 [00:00<00:00, 190.35it/s]
# train_batch (Avg. Loss 0.173, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 43.54it/s]
# test_batch (Avg. Loss 3.000, Accuracy 24.5): 100%|██████████| 40/40 [00:00<00:00, 186.97it/s]
# train_batch (Avg. Loss 0.168, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 40.86it/s]
# test_batch (Avg. Loss 3.003, Accuracy 24.9): 100%|██████████| 40/40 [00:00<00:00, 187.35it/s]
# train_batch (Avg. Loss 0.162, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 45.15it/s]
# test_batch (Avg. Loss 3.021, Accuracy 24.8): 100%|██████████| 40/40 [00:00<00:00, 153.83it/s]
# train_batch (Avg. Loss 0.158, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 44.84it/s]
# test_batch (Avg. Loss 3.022, Accuracy 24.8): 100%|██████████| 40/40 [00:00<00:00, 188.67it/s]
# train_batch (Avg. Loss 0.154, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 45.40it/s]
# test_batch (Avg. Loss 3.027, Accuracy 25.1): 100%|██████████| 40/40 [00:00<00:00, 185.18it/s]
# --- EPOCH 61/80 ---
# train_batch (Avg. Loss 0.150, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 43.29it/s]
# test_batch (Avg. Loss 3.041, Accuracy 24.8): 100%|██████████| 40/40 [00:00<00:00, 189.54it/s]
# train_batch (Avg. Loss 0.145, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 45.77it/s]
# test_batch (Avg. Loss 3.043, Accuracy 24.6): 100%|██████████| 40/40 [00:00<00:00, 185.17it/s]
# train_batch (Avg. Loss 0.141, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 43.62it/s]
# test_batch (Avg. Loss 3.063, Accuracy 24.1): 100%|██████████| 40/40 [00:00<00:00, 184.25it/s]
# train_batch (Avg. Loss 0.137, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 45.25it/s]
# test_batch (Avg. Loss 3.072, Accuracy 24.8): 100%|██████████| 40/40 [00:00<00:00, 189.30it/s]
# train_batch (Avg. Loss 0.133, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 42.65it/s]
# test_batch (Avg. Loss 3.091, Accuracy 24.9): 100%|██████████| 40/40 [00:00<00:00, 189.17it/s]
# train_batch (Avg. Loss 0.130, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 45.90it/s]
# test_batch (Avg. Loss 3.104, Accuracy 24.8): 100%|██████████| 40/40 [00:00<00:00, 184.35it/s]
# --- EPOCH 67/80 ---
# train_batch (Avg. Loss 0.126, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 43.27it/s]
# test_batch (Avg. Loss 3.127, Accuracy 24.8): 100%|██████████| 40/40 [00:00<00:00, 186.09it/s]
# train_batch (Avg. Loss 0.123, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 45.09it/s]
# test_batch (Avg. Loss 3.145, Accuracy 24.9): 100%|██████████| 40/40 [00:00<00:00, 188.69it/s]
# train_batch (Avg. Loss 0.119, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 43.42it/s]
# test_batch (Avg. Loss 3.168, Accuracy 25.1): 100%|██████████| 40/40 [00:00<00:00, 184.56it/s]
# train_batch (Avg. Loss 0.116, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 45.25it/s]
# test_batch (Avg. Loss 3.179, Accuracy 25.1): 100%|██████████| 40/40 [00:00<00:00, 184.37it/s]
# train_batch (Avg. Loss 0.112, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 44.79it/s]
# test_batch (Avg. Loss 3.207, Accuracy 25.2): 100%|██████████| 40/40 [00:00<00:00, 155.67it/s]
# train_batch (Avg. Loss 0.109, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 44.49it/s]
# test_batch (Avg. Loss 3.204, Accuracy 25.2): 100%|██████████| 40/40 [00:00<00:00, 184.75it/s]
# --- EPOCH 73/80 ---
# train_batch (Avg. Loss 0.106, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 45.30it/s]
# test_batch (Avg. Loss 3.220, Accuracy 25.1): 100%|██████████| 40/40 [00:00<00:00, 184.40it/s]
# train_batch (Avg. Loss 0.104, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 42.87it/s]
# test_batch (Avg. Loss 3.221, Accuracy 25.4): 100%|██████████| 40/40 [00:00<00:00, 183.46it/s]
# train_batch (Avg. Loss 0.101, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 45.25it/s]
# test_batch (Avg. Loss 3.227, Accuracy 25.5): 100%|██████████| 40/40 [00:00<00:00, 186.58it/s]
# train_batch (Avg. Loss 0.098, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 43.83it/s]
# test_batch (Avg. Loss 3.224, Accuracy 25.6): 100%|██████████| 40/40 [00:00<00:00, 185.23it/s]
# train_batch (Avg. Loss 0.095, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 45.66it/s]
# test_batch (Avg. Loss 3.211, Accuracy 25.5): 100%|██████████| 40/40 [00:00<00:00, 183.47it/s]
# train_batch (Avg. Loss 0.092, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 42.50it/s]
# test_batch (Avg. Loss 3.212, Accuracy 26.5): 100%|██████████| 40/40 [00:00<00:00, 177.81it/s]
# --- EPOCH 79/80 ---
# train_batch (Avg. Loss 0.089, Accuracy 100.0): 100%|██████████| 40/40 [00:00<00:00, 45.14it/s]
# test_batch (Avg. Loss 3.183, Accuracy 26.4): 100%|██████████| 40/40 [00:00<00:00, 177.83it/s]
# --- EPOCH 80/80 ---
# train_batch (Avg. Loss 0.086, Accuracy 100.0): 100%|██████████| 40/40 [00:01<00:00, 38.78it/s]
# test_batch (Avg. Loss 3.171, Accuracy 26.5): 100%|██████████| 40/40 [00:00<00:00, 182.23it/s]
# *** Training with dropout= 0.4
# --- EPOCH 1/80 ---
# train_batch (Avg. Loss 3.711, Accuracy 10.2): 100%|██████████| 40/40 [00:00<00:00, 43.62it/s]
# test_batch (Avg. Loss 2.517, Accuracy 15.1): 100%|██████████| 40/40 [00:00<00:00, 179.42it/s]
# train_batch (Avg. Loss 2.704, Accuracy 15.2): 100%|██████████| 40/40 [00:00<00:00, 41.32it/s]
# test_batch (Avg. Loss 2.359, Accuracy 17.0): 100%|██████████| 40/40 [00:00<00:00, 184.34it/s]
# train_batch (Avg. Loss 2.327, Accuracy 25.2): 100%|██████████| 40/40 [00:00<00:00, 43.72it/s]
# test_batch (Avg. Loss 2.248, Accuracy 18.8): 100%|██████████| 40/40 [00:00<00:00, 185.19it/s]
# train_batch (Avg. Loss 2.051, Accuracy 29.5): 100%|██████████| 40/40 [00:00<00:00, 42.15it/s]
# test_batch (Avg. Loss 2.202, Accuracy 21.5): 100%|██████████| 40/40 [00:00<00:00, 182.66it/s]
# train_batch (Avg. Loss 1.983, Accuracy 27.0): 100%|██████████| 40/40 [00:00<00:00, 44.58it/s]
# test_batch (Avg. Loss 2.153, Accuracy 24.0): 100%|██████████| 40/40 [00:00<00:00, 186.27it/s]
# train_batch (Avg. Loss 1.880, Accuracy 35.0): 100%|██████████| 40/40 [00:00<00:00, 43.86it/s]
# test_batch (Avg. Loss 2.121, Accuracy 23.8): 100%|██████████| 40/40 [00:00<00:00, 160.98it/s]
# --- EPOCH 7/80 ---
# train_batch (Avg. Loss 1.834, Accuracy 32.5): 100%|██████████| 40/40 [00:00<00:00, 45.04it/s]
# test_batch (Avg. Loss 2.103, Accuracy 26.1): 100%|██████████| 40/40 [00:00<00:00, 178.58it/s]
# train_batch (Avg. Loss 1.799, Accuracy 34.2): 100%|██████████| 40/40 [00:00<00:00, 42.96it/s]
# test_batch (Avg. Loss 2.100, Accuracy 25.8): 100%|██████████| 40/40 [00:00<00:00, 183.51it/s]
# train_batch (Avg. Loss 1.754, Accuracy 34.0): 100%|██████████| 40/40 [00:00<00:00, 44.69it/s]
# test_batch (Avg. Loss 2.088, Accuracy 26.5): 100%|██████████| 40/40 [00:00<00:00, 186.90it/s]
# train_batch (Avg. Loss 1.673, Accuracy 39.2): 100%|██████████| 40/40 [00:00<00:00, 45.15it/s]
# test_batch (Avg. Loss 2.085, Accuracy 26.4): 100%|██████████| 40/40 [00:00<00:00, 150.11it/s]
# train_batch (Avg. Loss 1.618, Accuracy 42.0): 100%|██████████| 40/40 [00:00<00:00, 45.55it/s]
# test_batch (Avg. Loss 2.075, Accuracy 26.8): 100%|██████████| 40/40 [00:00<00:00, 183.55it/s]
# train_batch (Avg. Loss 1.584, Accuracy 43.8): 100%|██████████| 40/40 [00:00<00:00, 45.25it/s]
# test_batch (Avg. Loss 2.071, Accuracy 27.4): 100%|██████████| 40/40 [00:00<00:00, 156.26it/s]
# --- EPOCH 13/80 ---
# train_batch (Avg. Loss 1.605, Accuracy 42.8): 100%|██████████| 40/40 [00:00<00:00, 44.74it/s]
# test_batch (Avg. Loss 2.064, Accuracy 28.4): 100%|██████████| 40/40 [00:00<00:00, 184.13it/s]
# train_batch (Avg. Loss 1.512, Accuracy 47.8): 100%|██████████| 40/40 [00:00<00:00, 45.32it/s]
# test_batch (Avg. Loss 2.054, Accuracy 28.1): 100%|██████████| 40/40 [00:00<00:00, 152.09it/s]
# train_batch (Avg. Loss 1.485, Accuracy 49.2): 100%|██████████| 40/40 [00:00<00:00, 45.33it/s]
# test_batch (Avg. Loss 2.054, Accuracy 28.0): 100%|██████████| 40/40 [00:00<00:00, 151.52it/s]
# train_batch (Avg. Loss 1.449, Accuracy 48.8): 100%|██████████| 40/40 [00:00<00:00, 44.94it/s]
# test_batch (Avg. Loss 2.067, Accuracy 28.5): 100%|██████████| 40/40 [00:00<00:00, 178.56it/s]
# train_batch (Avg. Loss 1.417, Accuracy 55.0): 100%|██████████| 40/40 [00:00<00:00, 44.94it/s]
# test_batch (Avg. Loss 2.044, Accuracy 28.5): 100%|██████████| 40/40 [00:00<00:00, 149.82it/s]
# train_batch (Avg. Loss 1.391, Accuracy 52.5): 100%|██████████| 40/40 [00:00<00:00, 45.56it/s]
# test_batch (Avg. Loss 2.055, Accuracy 29.0): 100%|██████████| 40/40 [00:00<00:00, 180.17it/s]
# --- EPOCH 19/80 ---
# train_batch (Avg. Loss 1.396, Accuracy 53.0): 100%|██████████| 40/40 [00:00<00:00, 46.13it/s]
# test_batch (Avg. Loss 2.058, Accuracy 27.5): 100%|██████████| 40/40 [00:00<00:00, 180.60it/s]
# train_batch (Avg. Loss 1.351, Accuracy 54.0): 100%|██████████| 40/40 [00:00<00:00, 43.01it/s]
# test_batch (Avg. Loss 2.055, Accuracy 27.1): 100%|██████████| 40/40 [00:00<00:00, 183.51it/s]
# train_batch (Avg. Loss 1.290, Accuracy 61.2): 100%|██████████| 40/40 [00:00<00:00, 45.09it/s]
# test_batch (Avg. Loss 2.044, Accuracy 28.6): 100%|██████████| 40/40 [00:00<00:00, 183.50it/s]
# train_batch (Avg. Loss 1.379, Accuracy 52.2): 100%|██████████| 40/40 [00:00<00:00, 44.24it/s]
# test_batch (Avg. Loss 2.062, Accuracy 27.5): 100%|██████████| 40/40 [00:00<00:00, 184.37it/s]
# train_batch (Avg. Loss 1.305, Accuracy 57.2): 100%|██████████| 40/40 [00:00<00:00, 42.98it/s]
# test_batch (Avg. Loss 2.053, Accuracy 28.8): 100%|██████████| 40/40 [00:00<00:00, 185.68it/s]
# train_batch (Avg. Loss 1.265, Accuracy 56.8): 100%|██████████| 40/40 [00:00<00:00, 45.26it/s]
# test_batch (Avg. Loss 2.048, Accuracy 28.6): 100%|██████████| 40/40 [00:00<00:00, 184.36it/s]
# --- EPOCH 25/80 ---
# train_batch (Avg. Loss 1.241, Accuracy 58.8): 100%|██████████| 40/40 [00:00<00:00, 42.29it/s]
# test_batch (Avg. Loss 2.052, Accuracy 29.1): 100%|██████████| 40/40 [00:00<00:00, 141.85it/s]
# train_batch (Avg. Loss 1.230, Accuracy 59.2): 100%|██████████| 40/40 [00:00<00:00, 45.34it/s]
# test_batch (Avg. Loss 2.043, Accuracy 27.5): 100%|██████████| 40/40 [00:00<00:00, 179.79it/s]
# train_batch (Avg. Loss 1.200, Accuracy 62.2): 100%|██████████| 40/40 [00:00<00:00, 40.46it/s]
# test_batch (Avg. Loss 2.051, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 185.21it/s]
# train_batch (Avg. Loss 1.199, Accuracy 62.5): 100%|██████████| 40/40 [00:00<00:00, 45.10it/s]
# test_batch (Avg. Loss 2.058, Accuracy 27.5): 100%|██████████| 40/40 [00:00<00:00, 183.52it/s]
# train_batch (Avg. Loss 1.128, Accuracy 66.2): 100%|██████████| 40/40 [00:00<00:00, 43.14it/s]
# test_batch (Avg. Loss 2.068, Accuracy 27.6): 100%|██████████| 40/40 [00:00<00:00, 184.34it/s]
# train_batch (Avg. Loss 1.114, Accuracy 64.5): 100%|██████████| 40/40 [00:00<00:00, 44.93it/s]
# test_batch (Avg. Loss 2.069, Accuracy 27.1): 100%|██████████| 40/40 [00:00<00:00, 183.56it/s]
# --- EPOCH 31/80 ---
# train_batch (Avg. Loss 1.125, Accuracy 62.5): 100%|██████████| 40/40 [00:00<00:00, 43.25it/s]
# test_batch (Avg. Loss 2.070, Accuracy 28.9): 100%|██████████| 40/40 [00:00<00:00, 186.09it/s]
# train_batch (Avg. Loss 1.091, Accuracy 66.8): 100%|██████████| 40/40 [00:00<00:00, 44.85it/s]
# test_batch (Avg. Loss 2.049, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 176.99it/s]
# train_batch (Avg. Loss 1.092, Accuracy 65.2): 100%|██████████| 40/40 [00:00<00:00, 44.58it/s]
# test_batch (Avg. Loss 2.066, Accuracy 27.4): 100%|██████████| 40/40 [00:00<00:00, 152.22it/s]
# train_batch (Avg. Loss 1.079, Accuracy 64.5): 100%|██████████| 40/40 [00:00<00:00, 45.37it/s]
# test_batch (Avg. Loss 2.062, Accuracy 27.9): 100%|██████████| 40/40 [00:00<00:00, 182.11it/s]
# train_batch (Avg. Loss 1.060, Accuracy 64.8): 100%|██████████| 40/40 [00:00<00:00, 45.41it/s]
# test_batch (Avg. Loss 2.081, Accuracy 27.5): 100%|██████████| 40/40 [00:00<00:00, 177.75it/s]
# train_batch (Avg. Loss 1.027, Accuracy 68.2): 100%|██████████| 40/40 [00:00<00:00, 42.57it/s]
# test_batch (Avg. Loss 2.080, Accuracy 27.6): 100%|██████████| 40/40 [00:00<00:00, 187.42it/s]
# --- EPOCH 37/80 ---
# train_batch (Avg. Loss 0.963, Accuracy 71.0): 100%|██████████| 40/40 [00:00<00:00, 45.15it/s]
# test_batch (Avg. Loss 2.080, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 185.21it/s]
# train_batch (Avg. Loss 1.008, Accuracy 69.8): 100%|██████████| 40/40 [00:00<00:00, 42.63it/s]
# test_batch (Avg. Loss 2.078, Accuracy 26.5): 100%|██████████| 40/40 [00:00<00:00, 178.61it/s]
# train_batch (Avg. Loss 0.946, Accuracy 70.8): 100%|██████████| 40/40 [00:00<00:00, 42.92it/s]
# test_batch (Avg. Loss 2.064, Accuracy 29.0): 100%|██████████| 40/40 [00:00<00:00, 181.97it/s]
# train_batch (Avg. Loss 0.905, Accuracy 74.5): 100%|██████████| 40/40 [00:00<00:00, 42.11it/s]
# test_batch (Avg. Loss 2.085, Accuracy 26.9): 100%|██████████| 40/40 [00:00<00:00, 185.20it/s]
# train_batch (Avg. Loss 0.937, Accuracy 75.5): 100%|██████████| 40/40 [00:00<00:00, 45.33it/s]
# test_batch (Avg. Loss 2.096, Accuracy 26.9): 100%|██████████| 40/40 [00:00<00:00, 183.03it/s]
# train_batch (Avg. Loss 0.956, Accuracy 69.0): 100%|██████████| 40/40 [00:00<00:00, 43.05it/s]
# test_batch (Avg. Loss 2.082, Accuracy 29.2): 100%|██████████| 40/40 [00:00<00:00, 187.37it/s]
# --- EPOCH 43/80 ---
# train_batch (Avg. Loss 0.914, Accuracy 72.5): 100%|██████████| 40/40 [00:00<00:00, 45.15it/s]
# test_batch (Avg. Loss 2.085, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 184.58it/s]
# train_batch (Avg. Loss 0.900, Accuracy 71.0): 100%|██████████| 40/40 [00:00<00:00, 44.41it/s]
# test_batch (Avg. Loss 2.084, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 187.01it/s]
# train_batch (Avg. Loss 0.852, Accuracy 76.8): 100%|██████████| 40/40 [00:00<00:00, 43.09it/s]
# test_batch (Avg. Loss 2.113, Accuracy 26.9): 100%|██████████| 40/40 [00:00<00:00, 185.68it/s]
# train_batch (Avg. Loss 0.842, Accuracy 76.0): 100%|██████████| 40/40 [00:00<00:00, 45.00it/s]
# test_batch (Avg. Loss 2.103, Accuracy 28.1): 100%|██████████| 40/40 [00:00<00:00, 183.97it/s]
# train_batch (Avg. Loss 0.864, Accuracy 73.5): 100%|██████████| 40/40 [00:00<00:00, 42.79it/s]
# test_batch (Avg. Loss 2.106, Accuracy 26.9): 100%|██████████| 40/40 [00:00<00:00, 180.61it/s]
# train_batch (Avg. Loss 0.861, Accuracy 75.5): 100%|██████████| 40/40 [00:00<00:00, 44.84it/s]
# test_batch (Avg. Loss 2.101, Accuracy 26.5): 100%|██████████| 40/40 [00:00<00:00, 170.92it/s]
# --- EPOCH 49/80 ---
# train_batch (Avg. Loss 0.788, Accuracy 80.2): 100%|██████████| 40/40 [00:00<00:00, 42.87it/s]
# test_batch (Avg. Loss 2.117, Accuracy 28.5): 100%|██████████| 40/40 [00:00<00:00, 181.82it/s]
# train_batch (Avg. Loss 0.772, Accuracy 79.8): 100%|██████████| 40/40 [00:01<00:00, 39.00it/s]
# test_batch (Avg. Loss 2.119, Accuracy 27.5): 100%|██████████| 40/40 [00:00<00:00, 145.05it/s]
# train_batch (Avg. Loss 0.770, Accuracy 77.5): 100%|██████████| 40/40 [00:01<00:00, 34.65it/s]
# test_batch (Avg. Loss 2.120, Accuracy 27.4): 100%|██████████| 40/40 [00:00<00:00, 178.90it/s]
# train_batch (Avg. Loss 0.740, Accuracy 78.5): 100%|██████████| 40/40 [00:00<00:00, 41.24it/s]
# test_batch (Avg. Loss 2.124, Accuracy 26.8): 100%|██████████| 40/40 [00:00<00:00, 147.64it/s]
# train_batch (Avg. Loss 0.768, Accuracy 76.5): 100%|██████████| 40/40 [00:00<00:00, 44.43it/s]
# test_batch (Avg. Loss 2.136, Accuracy 27.0): 100%|██████████| 40/40 [00:00<00:00, 181.81it/s]
# train_batch (Avg. Loss 0.738, Accuracy 81.0): 100%|██████████| 40/40 [00:00<00:00, 40.87it/s]
# test_batch (Avg. Loss 2.132, Accuracy 27.2): 100%|██████████| 40/40 [00:00<00:00, 147.08it/s]
# --- EPOCH 55/80 ---
# train_batch (Avg. Loss 0.756, Accuracy 80.0): 100%|██████████| 40/40 [00:00<00:00, 44.84it/s]
# test_batch (Avg. Loss 2.133, Accuracy 27.1): 100%|██████████| 40/40 [00:00<00:00, 173.18it/s]
# train_batch (Avg. Loss 0.736, Accuracy 80.0): 100%|██████████| 40/40 [00:00<00:00, 41.66it/s]
# test_batch (Avg. Loss 2.144, Accuracy 26.5): 100%|██████████| 40/40 [00:00<00:00, 181.04it/s]
# train_batch (Avg. Loss 0.709, Accuracy 81.0): 100%|██████████| 40/40 [00:00<00:00, 42.71it/s]
# test_batch (Avg. Loss 2.136, Accuracy 26.8): 100%|██████████| 40/40 [00:00<00:00, 168.81it/s]
# train_batch (Avg. Loss 0.680, Accuracy 81.0): 100%|██████████| 40/40 [00:00<00:00, 42.24it/s]
# test_batch (Avg. Loss 2.157, Accuracy 27.5): 100%|██████████| 40/40 [00:00<00:00, 184.32it/s]
# train_batch (Avg. Loss 0.689, Accuracy 81.0): 100%|██████████| 40/40 [00:00<00:00, 44.39it/s]
# test_batch (Avg. Loss 2.174, Accuracy 27.0): 100%|██████████| 40/40 [00:00<00:00, 150.40it/s]
# train_batch (Avg. Loss 0.667, Accuracy 82.0): 100%|██████████| 40/40 [00:00<00:00, 45.32it/s]
# test_batch (Avg. Loss 2.172, Accuracy 27.8): 100%|██████████| 40/40 [00:00<00:00, 183.44it/s]
# --- EPOCH 61/80 ---
# train_batch (Avg. Loss 0.678, Accuracy 83.5): 100%|██████████| 40/40 [00:00<00:00, 45.36it/s]
# test_batch (Avg. Loss 2.152, Accuracy 27.2): 100%|██████████| 40/40 [00:00<00:00, 150.64it/s]
# train_batch (Avg. Loss 0.614, Accuracy 87.5): 100%|██████████| 40/40 [00:00<00:00, 45.14it/s]
# test_batch (Avg. Loss 2.193, Accuracy 27.9): 100%|██████████| 40/40 [00:00<00:00, 166.09it/s]
# train_batch (Avg. Loss 0.629, Accuracy 85.0): 100%|██████████| 40/40 [00:00<00:00, 45.24it/s]
# test_batch (Avg. Loss 2.163, Accuracy 26.1): 100%|██████████| 40/40 [00:00<00:00, 152.43it/s]
# train_batch (Avg. Loss 0.606, Accuracy 84.5): 100%|██████████| 40/40 [00:00<00:00, 45.05it/s]
# test_batch (Avg. Loss 2.182, Accuracy 26.2): 100%|██████████| 40/40 [00:00<00:00, 174.38it/s]
# train_batch (Avg. Loss 0.644, Accuracy 80.5): 100%|██████████| 40/40 [00:00<00:00, 42.21it/s]
# test_batch (Avg. Loss 2.179, Accuracy 27.2): 100%|██████████| 40/40 [00:00<00:00, 182.66it/s]
# train_batch (Avg. Loss 0.635, Accuracy 82.5): 100%|██████████| 40/40 [00:00<00:00, 42.87it/s]
# test_batch (Avg. Loss 2.178, Accuracy 28.0): 100%|██████████| 40/40 [00:00<00:00, 186.05it/s]
# --- EPOCH 67/80 ---
# train_batch (Avg. Loss 0.600, Accuracy 86.0): 100%|██████████| 40/40 [00:00<00:00, 45.38it/s]
# test_batch (Avg. Loss 2.189, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 187.65it/s]
# train_batch (Avg. Loss 0.584, Accuracy 86.8): 100%|██████████| 40/40 [00:00<00:00, 43.82it/s]
# test_batch (Avg. Loss 2.210, Accuracy 26.2): 100%|██████████| 40/40 [00:00<00:00, 167.96it/s]
# train_batch (Avg. Loss 0.575, Accuracy 85.5): 100%|██████████| 40/40 [00:00<00:00, 43.66it/s]
# test_batch (Avg. Loss 2.188, Accuracy 27.8): 100%|██████████| 40/40 [00:00<00:00, 179.60it/s]
# train_batch (Avg. Loss 0.566, Accuracy 86.0): 100%|██████████| 40/40 [00:00<00:00, 44.05it/s]
# test_batch (Avg. Loss 2.210, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 184.39it/s]
# train_batch (Avg. Loss 0.563, Accuracy 87.8): 100%|██████████| 40/40 [00:01<00:00, 39.09it/s]
# test_batch (Avg. Loss 2.211, Accuracy 27.1): 100%|██████████| 40/40 [00:00<00:00, 127.85it/s]
# train_batch (Avg. Loss 0.577, Accuracy 87.0): 100%|██████████| 40/40 [00:00<00:00, 43.85it/s]
# test_batch (Avg. Loss 2.193, Accuracy 27.5): 100%|██████████| 40/40 [00:00<00:00, 185.20it/s]
# --- EPOCH 73/80 ---
# train_batch (Avg. Loss 0.568, Accuracy 87.2): 100%|██████████| 40/40 [00:00<00:00, 42.95it/s]
# test_batch (Avg. Loss 2.201, Accuracy 27.4): 100%|██████████| 40/40 [00:00<00:00, 185.56it/s]
# train_batch (Avg. Loss 0.552, Accuracy 87.8): 100%|██████████| 40/40 [00:01<00:00, 34.54it/s]
# test_batch (Avg. Loss 2.187, Accuracy 27.2): 100%|██████████| 40/40 [00:00<00:00, 124.25it/s]
# train_batch (Avg. Loss 0.541, Accuracy 88.0): 100%|██████████| 40/40 [00:01<00:00, 38.92it/s]
# test_batch (Avg. Loss 2.214, Accuracy 27.6): 100%|██████████| 40/40 [00:00<00:00, 173.23it/s]
# train_batch (Avg. Loss 0.510, Accuracy 88.5): 100%|██████████| 40/40 [00:00<00:00, 41.24it/s]
# test_batch (Avg. Loss 2.218, Accuracy 26.5): 100%|██████████| 40/40 [00:00<00:00, 146.00it/s]
# train_batch (Avg. Loss 0.527, Accuracy 86.5): 100%|██████████| 40/40 [00:01<00:00, 39.72it/s]
# test_batch (Avg. Loss 2.224, Accuracy 27.6): 100%|██████████| 40/40 [00:00<00:00, 180.22it/s]
# train_batch (Avg. Loss 0.496, Accuracy 90.2): 100%|██████████| 40/40 [00:00<00:00, 40.56it/s]
# test_batch (Avg. Loss 2.222, Accuracy 26.9): 100%|██████████| 40/40 [00:00<00:00, 147.63it/s]
# --- EPOCH 79/80 ---
# train_batch (Avg. Loss 0.503, Accuracy 89.8): 100%|██████████| 40/40 [00:00<00:00, 42.96it/s]
# test_batch (Avg. Loss 2.232, Accuracy 27.4): 100%|██████████| 40/40 [00:00<00:00, 184.35it/s]
# --- EPOCH 80/80 ---
# train_batch (Avg. Loss 0.493, Accuracy 90.0): 100%|██████████| 40/40 [00:00<00:00, 45.20it/s]
# test_batch (Avg. Loss 2.226, Accuracy 28.9): 100%|██████████| 40/40 [00:00<00:00, 162.60it/s]
# *** Training with dropout= 0.8
# --- EPOCH 1/80 ---
# train_batch (Avg. Loss 3.193, Accuracy 9.5): 100%|██████████| 40/40 [00:00<00:00, 44.35it/s]
# test_batch (Avg. Loss 2.333, Accuracy 9.8): 100%|██████████| 40/40 [00:00<00:00, 187.80it/s]
# train_batch (Avg. Loss 2.673, Accuracy 12.5): 100%|██████████| 40/40 [00:00<00:00, 46.67it/s]
# test_batch (Avg. Loss 2.274, Accuracy 13.1): 100%|██████████| 40/40 [00:00<00:00, 194.63it/s]
# train_batch (Avg. Loss 2.500, Accuracy 11.8): 100%|██████████| 40/40 [00:00<00:00, 41.64it/s]
# test_batch (Avg. Loss 2.267, Accuracy 13.4): 100%|██████████| 40/40 [00:00<00:00, 180.98it/s]
# train_batch (Avg. Loss 2.445, Accuracy 12.5): 100%|██████████| 40/40 [00:00<00:00, 45.92it/s]
# test_batch (Avg. Loss 2.234, Accuracy 15.2): 100%|██████████| 40/40 [00:00<00:00, 125.81it/s]
# train_batch (Avg. Loss 2.295, Accuracy 16.5): 100%|██████████| 40/40 [00:00<00:00, 41.62it/s]
# test_batch (Avg. Loss 2.225, Accuracy 13.8): 100%|██████████| 40/40 [00:00<00:00, 180.20it/s]
# train_batch (Avg. Loss 2.248, Accuracy 17.8): 100%|██████████| 40/40 [00:00<00:00, 44.25it/s]
# test_batch (Avg. Loss 2.211, Accuracy 16.4): 100%|██████████| 40/40 [00:00<00:00, 196.08it/s]
# --- EPOCH 7/80 ---
# train_batch (Avg. Loss 2.222, Accuracy 16.8): 100%|██████████| 40/40 [00:01<00:00, 34.07it/s]
# test_batch (Avg. Loss 2.208, Accuracy 17.9): 100%|██████████| 40/40 [00:00<00:00, 181.82it/s]
# train_batch (Avg. Loss 2.194, Accuracy 22.0): 100%|██████████| 40/40 [00:00<00:00, 42.28it/s]
# test_batch (Avg. Loss 2.206, Accuracy 14.8): 100%|██████████| 40/40 [00:00<00:00, 199.51it/s]
# train_batch (Avg. Loss 2.152, Accuracy 23.2): 100%|██████████| 40/40 [00:00<00:00, 47.82it/s]
# test_batch (Avg. Loss 2.196, Accuracy 15.4): 100%|██████████| 40/40 [00:00<00:00, 191.86it/s]
# train_batch (Avg. Loss 2.152, Accuracy 20.0): 100%|██████████| 40/40 [00:00<00:00, 52.74it/s]
# test_batch (Avg. Loss 2.184, Accuracy 17.0): 100%|██████████| 40/40 [00:00<00:00, 228.65it/s]
# train_batch (Avg. Loss 2.139, Accuracy 23.5): 100%|██████████| 40/40 [00:00<00:00, 51.90it/s]
# test_batch (Avg. Loss 2.172, Accuracy 19.4): 100%|██████████| 40/40 [00:00<00:00, 222.82it/s]
# train_batch (Avg. Loss 2.154, Accuracy 21.5): 100%|██████████| 40/40 [00:00<00:00, 48.56it/s]
# test_batch (Avg. Loss 2.170, Accuracy 17.6): 100%|██████████| 40/40 [00:00<00:00, 205.40it/s]
# --- EPOCH 13/80 ---
# train_batch (Avg. Loss 2.121, Accuracy 23.2): 100%|██████████| 40/40 [00:00<00:00, 51.65it/s]
# test_batch (Avg. Loss 2.165, Accuracy 20.1): 100%|██████████| 40/40 [00:00<00:00, 134.13it/s]
# train_batch (Avg. Loss 2.111, Accuracy 22.5): 100%|██████████| 40/40 [00:01<00:00, 32.06it/s]
# test_batch (Avg. Loss 2.160, Accuracy 20.4): 100%|██████████| 40/40 [00:00<00:00, 149.65it/s]
# train_batch (Avg. Loss 2.101, Accuracy 24.5): 100%|██████████| 40/40 [00:00<00:00, 46.20it/s]
# test_batch (Avg. Loss 2.149, Accuracy 20.2): 100%|██████████| 40/40 [00:00<00:00, 195.64it/s]
# train_batch (Avg. Loss 2.070, Accuracy 22.8): 100%|██████████| 40/40 [00:00<00:00, 47.35it/s]
# test_batch (Avg. Loss 2.144, Accuracy 20.9): 100%|██████████| 40/40 [00:00<00:00, 192.82it/s]
# train_batch (Avg. Loss 2.072, Accuracy 23.8): 100%|██████████| 40/40 [00:00<00:00, 47.14it/s]
# test_batch (Avg. Loss 2.141, Accuracy 20.1): 100%|██████████| 40/40 [00:00<00:00, 193.75it/s]
# train_batch (Avg. Loss 2.127, Accuracy 24.0): 100%|██████████| 40/40 [00:00<00:00, 48.03it/s]
# test_batch (Avg. Loss 2.136, Accuracy 22.0): 100%|██████████| 40/40 [00:00<00:00, 193.75it/s]
# --- EPOCH 19/80 ---
# train_batch (Avg. Loss 2.065, Accuracy 28.0): 100%|██████████| 40/40 [00:00<00:00, 45.05it/s]
# test_batch (Avg. Loss 2.132, Accuracy 21.9): 100%|██████████| 40/40 [00:00<00:00, 184.83it/s]
# train_batch (Avg. Loss 2.088, Accuracy 24.5): 100%|██████████| 40/40 [00:00<00:00, 46.53it/s]
# test_batch (Avg. Loss 2.127, Accuracy 22.6): 100%|██████████| 40/40 [00:00<00:00, 189.19it/s]
# train_batch (Avg. Loss 2.080, Accuracy 23.2): 100%|██████████| 40/40 [00:00<00:00, 42.46it/s]
# test_batch (Avg. Loss 2.124, Accuracy 22.5): 100%|██████████| 40/40 [00:00<00:00, 156.06it/s]
# train_batch (Avg. Loss 2.017, Accuracy 27.8): 100%|██████████| 40/40 [00:00<00:00, 42.84it/s]
# test_batch (Avg. Loss 2.110, Accuracy 24.8): 100%|██████████| 40/40 [00:00<00:00, 192.82it/s]
# train_batch (Avg. Loss 2.010, Accuracy 28.5): 100%|██████████| 40/40 [00:00<00:00, 44.91it/s]
# test_batch (Avg. Loss 2.108, Accuracy 24.2): 100%|██████████| 40/40 [00:00<00:00, 182.58it/s]
# train_batch (Avg. Loss 1.983, Accuracy 28.0): 100%|██████████| 40/40 [00:00<00:00, 42.67it/s]
# test_batch (Avg. Loss 2.107, Accuracy 23.6): 100%|██████████| 40/40 [00:00<00:00, 189.18it/s]
# --- EPOCH 25/80 ---
# train_batch (Avg. Loss 2.009, Accuracy 30.0): 100%|██████████| 40/40 [00:00<00:00, 45.30it/s]
# test_batch (Avg. Loss 2.101, Accuracy 23.9): 100%|██████████| 40/40 [00:00<00:00, 174.38it/s]
# train_batch (Avg. Loss 2.015, Accuracy 28.2): 100%|██████████| 40/40 [00:01<00:00, 39.61it/s]
# test_batch (Avg. Loss 2.094, Accuracy 24.0): 100%|██████████| 40/40 [00:00<00:00, 151.06it/s]
# train_batch (Avg. Loss 2.005, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 42.11it/s]
# test_batch (Avg. Loss 2.092, Accuracy 25.1): 100%|██████████| 40/40 [00:00<00:00, 179.85it/s]
# train_batch (Avg. Loss 1.961, Accuracy 31.8): 100%|██████████| 40/40 [00:01<00:00, 35.65it/s]
# test_batch (Avg. Loss 2.084, Accuracy 25.5): 100%|██████████| 40/40 [00:00<00:00, 186.54it/s]
# train_batch (Avg. Loss 1.965, Accuracy 28.5): 100%|██████████| 40/40 [00:00<00:00, 45.73it/s]
# test_batch (Avg. Loss 2.078, Accuracy 27.1): 100%|██████████| 40/40 [00:00<00:00, 128.55it/s]
# train_batch (Avg. Loss 1.985, Accuracy 29.8): 100%|██████████| 40/40 [00:00<00:00, 43.82it/s]
# test_batch (Avg. Loss 2.075, Accuracy 26.1): 100%|██████████| 40/40 [00:00<00:00, 146.91it/s]
# --- EPOCH 31/80 ---
# train_batch (Avg. Loss 1.957, Accuracy 30.0): 100%|██████████| 40/40 [00:00<00:00, 41.20it/s]
# test_batch (Avg. Loss 2.078, Accuracy 25.9): 100%|██████████| 40/40 [00:00<00:00, 179.05it/s]
# train_batch (Avg. Loss 1.943, Accuracy 30.5): 100%|██████████| 40/40 [00:00<00:00, 41.39it/s]
# test_batch (Avg. Loss 2.074, Accuracy 26.9): 100%|██████████| 40/40 [00:00<00:00, 166.42it/s]
# train_batch (Avg. Loss 1.943, Accuracy 28.8): 100%|██████████| 40/40 [00:01<00:00, 34.57it/s]
# test_batch (Avg. Loss 2.065, Accuracy 26.8): 100%|██████████| 40/40 [00:00<00:00, 159.79it/s]
# train_batch (Avg. Loss 1.989, Accuracy 28.0): 100%|██████████| 40/40 [00:01<00:00, 37.03it/s]
# test_batch (Avg. Loss 2.075, Accuracy 25.5): 100%|██████████| 40/40 [00:00<00:00, 112.34it/s]
# train_batch (Avg. Loss 1.952, Accuracy 32.2): 100%|██████████| 40/40 [00:01<00:00, 31.78it/s]
# test_batch (Avg. Loss 2.064, Accuracy 27.2): 100%|██████████| 40/40 [00:00<00:00, 148.97it/s]
# train_batch (Avg. Loss 1.941, Accuracy 32.2): 100%|██████████| 40/40 [00:00<00:00, 40.11it/s]
# test_batch (Avg. Loss 2.062, Accuracy 27.1): 100%|██████████| 40/40 [00:00<00:00, 153.08it/s]
# --- EPOCH 37/80 ---
# train_batch (Avg. Loss 1.925, Accuracy 31.2): 100%|██████████| 40/40 [00:01<00:00, 37.66it/s]
# test_batch (Avg. Loss 2.056, Accuracy 27.6): 100%|██████████| 40/40 [00:00<00:00, 128.55it/s]
# train_batch (Avg. Loss 1.864, Accuracy 35.0): 100%|██████████| 40/40 [00:01<00:00, 39.75it/s]
# test_batch (Avg. Loss 2.057, Accuracy 27.1): 100%|██████████| 40/40 [00:00<00:00, 157.90it/s]
# train_batch (Avg. Loss 1.934, Accuracy 32.2): 100%|██████████| 40/40 [00:01<00:00, 37.77it/s]
# test_batch (Avg. Loss 2.058, Accuracy 27.9): 100%|██████████| 40/40 [00:00<00:00, 160.43it/s]
# train_batch (Avg. Loss 1.905, Accuracy 32.2): 100%|██████████| 40/40 [00:01<00:00, 37.77it/s]
# test_batch (Avg. Loss 2.056, Accuracy 27.4): 100%|██████████| 40/40 [00:00<00:00, 148.00it/s]
# train_batch (Avg. Loss 1.918, Accuracy 33.5): 100%|██████████| 40/40 [00:01<00:00, 39.01it/s]
# test_batch (Avg. Loss 2.052, Accuracy 28.4): 100%|██████████| 40/40 [00:00<00:00, 126.92it/s]
# train_batch (Avg. Loss 1.845, Accuracy 40.2): 100%|██████████| 40/40 [00:01<00:00, 36.10it/s]
# test_batch (Avg. Loss 2.045, Accuracy 27.8): 100%|██████████| 40/40 [00:00<00:00, 161.72it/s]
# --- EPOCH 43/80 ---
# train_batch (Avg. Loss 1.905, Accuracy 32.2): 100%|██████████| 40/40 [00:01<00:00, 39.95it/s]
# test_batch (Avg. Loss 2.049, Accuracy 26.1): 100%|██████████| 40/40 [00:00<00:00, 121.17it/s]
# train_batch (Avg. Loss 1.877, Accuracy 35.2): 100%|██████████| 40/40 [00:01<00:00, 39.28it/s]
# test_batch (Avg. Loss 2.045, Accuracy 26.6): 100%|██████████| 40/40 [00:00<00:00, 144.79it/s]
# train_batch (Avg. Loss 1.931, Accuracy 29.2): 100%|██████████| 40/40 [00:01<00:00, 36.93it/s]
# test_batch (Avg. Loss 2.038, Accuracy 27.9): 100%|██████████| 40/40 [00:00<00:00, 154.85it/s]
# train_batch (Avg. Loss 1.844, Accuracy 37.0): 100%|██████████| 40/40 [00:01<00:00, 35.12it/s]
# test_batch (Avg. Loss 2.039, Accuracy 28.4): 100%|██████████| 40/40 [00:00<00:00, 162.38it/s]
# train_batch (Avg. Loss 1.850, Accuracy 35.8): 100%|██████████| 40/40 [00:01<00:00, 37.59it/s]
# test_batch (Avg. Loss 2.038, Accuracy 27.6): 100%|██████████| 40/40 [00:00<00:00, 105.82it/s]
# train_batch (Avg. Loss 1.894, Accuracy 33.2): 100%|██████████| 40/40 [00:01<00:00, 35.40it/s]
# test_batch (Avg. Loss 2.035, Accuracy 28.1): 100%|██████████| 40/40 [00:00<00:00, 130.22it/s]
# --- EPOCH 49/80 ---
# train_batch (Avg. Loss 1.857, Accuracy 38.0): 100%|██████████| 40/40 [00:01<00:00, 25.04it/s]
# test_batch (Avg. Loss 2.032, Accuracy 28.1): 100%|██████████| 40/40 [00:00<00:00, 156.06it/s]
# train_batch (Avg. Loss 1.853, Accuracy 34.8): 100%|██████████| 40/40 [00:01<00:00, 36.66it/s]
# test_batch (Avg. Loss 2.037, Accuracy 26.9): 100%|██████████| 40/40 [00:00<00:00, 121.54it/s]
# train_batch (Avg. Loss 1.827, Accuracy 33.8): 100%|██████████| 40/40 [00:01<00:00, 33.69it/s]
# test_batch (Avg. Loss 2.030, Accuracy 27.0): 100%|██████████| 40/40 [00:00<00:00, 95.95it/s]
# train_batch (Avg. Loss 1.809, Accuracy 35.5): 100%|██████████| 40/40 [00:02<00:00, 19.73it/s]
# test_batch (Avg. Loss 2.024, Accuracy 27.6): 100%|██████████| 40/40 [00:00<00:00, 97.82it/s]
# train_batch (Avg. Loss 1.815, Accuracy 38.2): 100%|██████████| 40/40 [00:01<00:00, 21.71it/s]
# test_batch (Avg. Loss 2.021, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 103.90it/s]
# train_batch (Avg. Loss 1.817, Accuracy 38.5): 100%|██████████| 40/40 [00:01<00:00, 27.58it/s]
# test_batch (Avg. Loss 2.020, Accuracy 28.1): 100%|██████████| 40/40 [00:00<00:00, 135.50it/s]
# --- EPOCH 55/80 ---
# train_batch (Avg. Loss 1.814, Accuracy 33.8): 100%|██████████| 40/40 [00:01<00:00, 33.26it/s]
# test_batch (Avg. Loss 2.024, Accuracy 28.6): 100%|██████████| 40/40 [00:00<00:00, 115.92it/s]
# train_batch (Avg. Loss 1.770, Accuracy 39.2): 100%|██████████| 40/40 [00:01<00:00, 38.49it/s]
# test_batch (Avg. Loss 2.009, Accuracy 28.8): 100%|██████████| 40/40 [00:00<00:00, 145.84it/s]
# train_batch (Avg. Loss 1.799, Accuracy 39.0): 100%|██████████| 40/40 [00:01<00:00, 34.59it/s]
# test_batch (Avg. Loss 2.019, Accuracy 28.1): 100%|██████████| 40/40 [00:00<00:00, 152.50it/s]
# train_batch (Avg. Loss 1.782, Accuracy 36.2): 100%|██████████| 40/40 [00:01<00:00, 39.09it/s]
# test_batch (Avg. Loss 2.014, Accuracy 28.6): 100%|██████████| 40/40 [00:00<00:00, 154.85it/s]
# train_batch (Avg. Loss 1.727, Accuracy 37.2): 100%|██████████| 40/40 [00:01<00:00, 35.00it/s]
# test_batch (Avg. Loss 2.012, Accuracy 29.2): 100%|██████████| 40/40 [00:00<00:00, 123.41it/s]
# train_batch (Avg. Loss 1.779, Accuracy 36.0): 100%|██████████| 40/40 [00:01<00:00, 39.44it/s]
# test_batch (Avg. Loss 2.015, Accuracy 27.8): 100%|██████████| 40/40 [00:00<00:00, 153.67it/s]
# --- EPOCH 61/80 ---
# train_batch (Avg. Loss 1.801, Accuracy 37.8): 100%|██████████| 40/40 [00:01<00:00, 38.62it/s]
# test_batch (Avg. Loss 2.013, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 148.00it/s]
# train_batch (Avg. Loss 1.790, Accuracy 35.5): 100%|██████████| 40/40 [00:01<00:00, 39.40it/s]
# test_batch (Avg. Loss 2.010, Accuracy 28.8): 100%|██████████| 40/40 [00:00<00:00, 144.27it/s]
# train_batch (Avg. Loss 1.765, Accuracy 36.5): 100%|██████████| 40/40 [00:01<00:00, 38.32it/s]
# test_batch (Avg. Loss 2.003, Accuracy 29.0): 100%|██████████| 40/40 [00:00<00:00, 131.07it/s]
# train_batch (Avg. Loss 1.756, Accuracy 42.0): 100%|██████████| 40/40 [00:01<00:00, 39.38it/s]
# test_batch (Avg. Loss 2.008, Accuracy 27.8): 100%|██████████| 40/40 [00:00<00:00, 145.84it/s]
# train_batch (Avg. Loss 1.772, Accuracy 35.5): 100%|██████████| 40/40 [00:01<00:00, 36.49it/s]
# test_batch (Avg. Loss 2.008, Accuracy 28.5): 100%|██████████| 40/40 [00:00<00:00, 151.92it/s]
# train_batch (Avg. Loss 1.734, Accuracy 43.0): 100%|██████████| 40/40 [00:01<00:00, 39.43it/s]
# test_batch (Avg. Loss 2.010, Accuracy 27.6): 100%|██████████| 40/40 [00:00<00:00, 122.28it/s]
# --- EPOCH 67/80 ---
# train_batch (Avg. Loss 1.820, Accuracy 35.2): 100%|██████████| 40/40 [00:01<00:00, 36.90it/s]
# test_batch (Avg. Loss 2.004, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 152.50it/s]
# train_batch (Avg. Loss 1.794, Accuracy 37.2): 100%|██████████| 40/40 [00:01<00:00, 37.02it/s]
# test_batch (Avg. Loss 2.004, Accuracy 28.1): 100%|██████████| 40/40 [00:00<00:00, 153.08it/s]
# train_batch (Avg. Loss 1.739, Accuracy 37.5): 100%|██████████| 40/40 [00:01<00:00, 38.27it/s]
# test_batch (Avg. Loss 2.002, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 150.78it/s]
# train_batch (Avg. Loss 1.728, Accuracy 39.8): 100%|██████████| 40/40 [00:01<00:00, 39.45it/s]
# test_batch (Avg. Loss 2.001, Accuracy 29.1): 100%|██████████| 40/40 [00:00<00:00, 148.00it/s]
# train_batch (Avg. Loss 1.757, Accuracy 40.0): 100%|██████████| 40/40 [00:00<00:00, 40.01it/s]
# test_batch (Avg. Loss 2.001, Accuracy 28.6): 100%|██████████| 40/40 [00:00<00:00, 130.22it/s]
# train_batch (Avg. Loss 1.736, Accuracy 38.8): 100%|██████████| 40/40 [00:01<00:00, 37.85it/s]
# test_batch (Avg. Loss 2.005, Accuracy 28.6): 100%|██████████| 40/40 [00:00<00:00, 125.27it/s]
# --- EPOCH 73/80 ---
# train_batch (Avg. Loss 1.696, Accuracy 39.8): 100%|██████████| 40/40 [00:01<00:00, 39.67it/s]
# test_batch (Avg. Loss 2.007, Accuracy 28.4): 100%|██████████| 40/40 [00:00<00:00, 145.32it/s]
# train_batch (Avg. Loss 1.694, Accuracy 40.5): 100%|██████████| 40/40 [00:01<00:00, 39.28it/s]
# test_batch (Avg. Loss 1.997, Accuracy 28.0): 100%|██████████| 40/40 [00:00<00:00, 153.08it/s]
# train_batch (Avg. Loss 1.698, Accuracy 41.8): 100%|██████████| 40/40 [00:01<00:00, 39.30it/s]
# test_batch (Avg. Loss 1.989, Accuracy 29.1): 100%|██████████| 40/40 [00:00<00:00, 151.92it/s]
# train_batch (Avg. Loss 1.645, Accuracy 43.2): 100%|██████████| 40/40 [00:01<00:00, 37.03it/s]
# test_batch (Avg. Loss 1.989, Accuracy 29.4): 100%|██████████| 40/40 [00:00<00:00, 147.99it/s]
# train_batch (Avg. Loss 1.705, Accuracy 40.5): 100%|██████████| 40/40 [00:01<00:00, 39.21it/s]
# test_batch (Avg. Loss 1.993, Accuracy 27.5): 100%|██████████| 40/40 [00:00<00:00, 154.85it/s]
# train_batch (Avg. Loss 1.658, Accuracy 42.0): 100%|██████████| 40/40 [00:01<00:00, 39.21it/s]
# test_batch (Avg. Loss 1.993, Accuracy 29.0): 100%|██████████| 40/40 [00:00<00:00, 147.99it/s]
# --- EPOCH 79/80 ---
# train_batch (Avg. Loss 1.675, Accuracy 41.2): 100%|██████████| 40/40 [00:01<00:00, 37.40it/s]
# test_batch (Avg. Loss 1.991, Accuracy 28.8): 100%|██████████| 40/40 [00:00<00:00, 145.31it/s]
# --- EPOCH 80/80 ---
# train_batch (Avg. Loss 1.701, Accuracy 41.0): 100%|██████████| 40/40 [00:01<00:00, 39.11it/s]
# test_batch (Avg. Loss 1.990, Accuracy 29.5): 100%|██████████| 40/40 [00:00<00:00, 148.00it/s]

# %% [markdown]
# ## Questions
# <a id=part2_7></a>

# %% [markdown]
# **TODO** Answer the following questions. Write your answers in the appropriate variables in the module `hw2/answers.py`.

# %%
from helpers.answers import display_answer
import hw2.answers

# %% [markdown]
# ### Question 1
#
# Regarding the graphs you got for the three dropout configurations:
#
# 1. Explain the graphs of no-dropout vs dropout. Do they match what you expected to see?
#     - If yes, explain why and provide examples based on the graphs.
#     - If no, explain what you think the problem is and what should be modified to fix it.
#
# 2. Compare the low-dropout setting to the high-dropout setting and explain based on your graphs.

# %%
display_answer(hw2.answers.part2_q1)
# Out:
# **Your answer:**
# 1. They mostly match what we expected to see.
# We trained the model without dropout until it overfits - achieving near perfect results on the training set but
# only about 20% for the test set.
# As expected, dropout helps us to avoid overfitting with 30 epochs - as soon as we turned on dropout (with both
# probability values) the model improves on the test set (it overfits less w.r.t the training set).
# Seeing as dropout aims to reach a more sparse representation of the data, I think running with more epochs and dropout parameters
# would be interesting to check how changing the dropout value affects convergence rate and the achieved test set accuracy.
# 2. Dropout with 0.4 achieved better result compared to the 0.8 one for 30 epochs.
# Intuitively, since higher dropout means we use less of our data, we should require more epochs when increasing it.
# Here both models train for the same amount of epochs so it makes sense that the 0.4 one got better results.
# Given enough epochs its possible that 0.8 dropout model could pull ahead of the 0.4 one in terms of test set accuracy.
# We tried this expriment with 80 epochs and indeed in our case the model with 0.8 dropout got the best test set accuracy.

# %% [markdown]
# ### Question 2
#
# When training a model with the cross-entropy loss function, is it possible for the test loss to **increase** for a few epochs while the test accuracy also **increases**?
#
# If it's possible explain how, if it's not explain why not.

# %%
display_answer(hw2.answers.part2_q2)
# Out:
# **Your answer:**
# Yes, its possible. The Cross Entropy loss receives as arguments the class scores $\hat{y}$ and the real labels $y$.
# In order to increase the loss, the score of the right class (denoted $x_y$) needs to decrease. Note that the sum-log-exp
# term weights the same whether $x_y$ is the right class or not.
# In order to increase the test accuracy, we need more samples such that $x_y$ is the maximum class score.
# Both can happen simultaneously - the score of the right class can decrease while still remaining the maximum score,
# or it can decrease and then become the maximum score (because other classes decreased further).
# In conclusion, this can happen - especially at the first few epochs before convergance is achieved.
