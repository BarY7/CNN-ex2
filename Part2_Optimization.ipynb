# %% [markdown]
# $$
# \newcommand{\mat}[1]{\boldsymbol {#1}}
# \newcommand{\mattr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\matinv}[1]{\boldsymbol {#1}^{-1}}
# \newcommand{\vec}[1]{\boldsymbol {#1}}
# \newcommand{\vectr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\rvar}[1]{\mathrm {#1}}
# \newcommand{\rvec}[1]{\boldsymbol{\mathrm{#1}}}
# \newcommand{\diag}{\mathop{\mathrm {diag}}}
# \newcommand{\set}[1]{\mathbb {#1}}
# \newcommand{\norm}[1]{\left\lVert#1\right\rVert}
# \newcommand{\pderiv}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\bb}[1]{\boldsymbol{#1}}
# $$
# # Part 2: Optimization and Training
# <a id=part2></a>

# %% [markdown]
# In this part we will learn how to implement optimization algorithms for deep networks. Additionally, we'll learn how to write training loops and implement a modular model trainer.
# We'll use our optimizers and training code to test a few configurations for classifying images with an MLP model.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import unittest
import torch
import torchvision
import torchvision.transforms as tvtf

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

seed = 42

plt.rcParams.update({'font.size': 12})
test = unittest.TestCase()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Implementing Optimization Algorithms
# <a id=part2_1></a>

# %% [markdown]
# In the context of deep learning, an optimization algorithm is some method of iteratively updating model parameters so that the loss converges toward some local minimum (which we hope will be good enough).
#
# Gradient descent-based methods are by far the most popular algorithms for optimization of neural network parameters.
# However the high-dimensional loss-surfaces we encounter in deep learning applications are highly non-convex.
# They may be riddled with local minima, saddle points, large plateaus and a host of very challenging "terrain" for gradient-based optimization.
# This gave rise to many different methods of performing the parameter updates based on the loss gradients,
# aiming to tackle these optimization challenges.
#
# The most basic gradient-based update rule can be written as,
#
# $$
# \vec{\theta} \leftarrow \vec{\theta} - \eta \nabla_{\vec{\theta}} L(\vec{\theta}; \mathcal{D})
# $$
#
# where $\mathcal{D} = \left\{ (\vec{x}^i, \vec{y}^i) \right\}_{i=1}^{M}$ is our training dataset or part of it. Specifically, if we have in total $N$ training samples, then
# - If $M=N$ this is known as regular gradient descent. If the dataset does not fit in memory it becomes infeasible to compute.
# - If $M=1$, the loss is computed w.r.t. a single different sample each time. This is known as stochastic gradient descent.
# - If $1<M<N$ this is known as stochastic mini-batch gradient descent. This is the most commonly-used option.
#
# The intuition behind gradient descent is simple: since the gradient of a multivariate function points to the direction of steepest ascent ("uphill"), we move in the opposite direction. A small step size $\eta$ known as the **learning rate** is required since, as with any derivative, the gradient's value is only accurate close to the point it was evaluated at (the current value of $\vec{\theta}$).
#
# <img src="imgs/sgd2d.png" width="600" />
#
# The idea behind the stochastic versions is that by constantly changing the samples we compute the loss with,
# we get a dynamic error surface, i.e. it's different for each set of training samples.
# This is thought to generally improve the optimization since it may help the optimizer get out of flat regions or sharp local minima since these features may disappear in the loss surface of subsequent batches. The image below illustrates this. The different lines are different 1-dimensional losses for different training set-samples.
#
# <img src="imgs/sgd1d.png" width="600" />

# %% [markdown]
# Deep learning frameworks generally provide implementations of various gradient-based optimization algorithms.
# Here we'll implement our own optimization module from scratch, this time keeping a similar API to the PyTorch `optim` package.
#
# We define a base `Optimizer` class. An optimizer holds a set of parameter tensors (these are the trainable parameters of some model) and maintains internal state. It may be used as follows:
# - After the forward pass has been performed the optimizer's `zero_grad()` function is invoked to clear the parameter gradients computed by previous iterations.
# - After the backward pass has been performed, and gradients have been calculated for these parameters, the optimizer's `step()` function is invoked in order to update the value of each parameter based on it's gradient.
#
# The exact method of update is implementation-specific for each optimizer and may depend on it's internal state. In addition, adding the regularization penalty to the gradient is handled by the optimizer since it only depends on the parameter values (and not the data).

# %% [markdown]
# Here's the API of our `Optimizer`:

# %%
import hw2.optimizers as optimizers
help(optimizers.Optimizer)
# Out:
# Help on class Optimizer in module hw2.optimizers:
#
# class Optimizer(abc.ABC)
#  |  Optimizer(params)
#  |
#  |  Base class for optimizers.
#  |
#  |  Method resolution order:
#  |      Optimizer
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, params)
#  |      :param params: A sequence of model parameters to optimize. Can be a
#  |      list of (param,grad) tuples as returned by the Blocks, or a list of
#  |      pytorch tensors in which case the grad will be taken from them.
#  |
#  |  step(self)
#  |      Updates all the registered parameter values based on their gradients.
#  |
#  |  zero_grad(self)
#  |      Sets the gradient of the optimized parameters to zero (in place).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  params
#  |      :return: A sequence of parameter tuples, each tuple containing
#  |      (param_data, param_grad). The data should be updated in-place
#  |      according to the grad.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset({'step'})

# %% [markdown]
# ## Vanilla SGD with Regularization
# <a id=part2_2></a>

# %% [markdown]
# Let's start by implementing the simplest gradient based optimizer. The update rule will be exacly as stated above, but we'll also add a L2-regularization term to the gradient. Remember that in the **loss function**, the L2 regularization term is expressed by
#
# $$R(\vec{\theta}) = \frac{1}{2}\lambda||\vec{\theta}||^2_2.$$

# %% [markdown]
# **TODO**: Complete the implementation of the `VanillaSGD` class in the `hw2/optimizers.py` module.

# %%
# Test VanillaSGD
torch.manual_seed(42)
p = torch.randn(500, 10)
dp = torch.randn(*p.shape)*2
params = [(p, dp)]

vsgd = optimizers.VanillaSGD(params, learn_rate=0.5, reg=0.1)
vsgd.step()

expected_p = torch.load('tests/assets/expected_vsgd.pt')
diff = torch.norm(p-expected_p).item()
print(f'diff={diff}')
test.assertLess(diff, 1e-3)
# Out:
# diff=0.0

# %% [markdown]
# ## Training
# <a id=part2_3></a>

# %% [markdown]
# Now that we can build a model and loss function, compute their gradients and we have an optimizer, we can finally do some training!
#
# In the spirit of more modular software design, we'll implement a class that will aid us in automating the repetitive training loop code that we usually write over and over again. This will be useful for both training our `Block`-based models and also later for training PyTorch `nn.Module`s.
#
# Here's our `Trainer` API:

# %%
import hw2.training as training
help(training.Trainer)
# Out:
# Help on class Trainer in module hw2.training:
#
# class Trainer(abc.ABC)
#  |  Trainer(model, loss_fn, optimizer, device=None)
#  |
#  |  A class abstracting the various tasks of training models.
#  |  Provides methods at multiple levels of granularity:
#  |  - Multiple epochs (fit)
#  |  - Single epoch (train_epoch/test_epoch)
#  |  - Single batch (train_batch/test_batch)
#  |
#  |  Method resolution order:
#  |      Trainer
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, model, loss_fn, optimizer, device=None)
#  |      Initialize the trainer.
#  |      :param model: Instance of the model to train.
#  |      :param loss_fn: The loss function to evaluate with.
#  |      :param optimizer: The optimizer to train with.
#  |      :param device: torch.device to run training on (CPU or GPU).
#  |
#  |  fit(self, dl_train: torch.utils.data.dataloader.DataLoader, dl_test: torch.utils.data.dataloader.DataLoader, num_epochs, checkpoints: str = None, early_stopping: int = None, print_every=1, **kw) -> helpers.train_results.FitResult
#  |      Trains the model for multiple epochs with a given training set,
#  |      and calculates validation loss over a given validation set.
#  |      :param dl_train: Dataloader for the training set.
#  |      :param dl_test: Dataloader for the test set.
#  |      :param num_epochs: Number of epochs to train for.
#  |      :param checkpoints: Whether to save model to file every time the
#  |          test set accuracy improves. Should be a string containing a
#  |          filename without extension.
#  |      :param early_stopping: Whether to stop training early if there is no
#  |          test loss improvement for this number of epochs.
#  |      :param print_every: Print progress every this number of epochs.
#  |      :return: A FitResult object containing train and test losses per epoch.
#  |
#  |  test_batch(self, batch) -> helpers.train_results.BatchResult
#  |      Runs a single batch forward through the model and calculates loss.
#  |      :param batch: A single batch of data  from a data loader (might
#  |          be a tuple of data and labels or anything else depending on
#  |          the underlying dataset.
#  |      :return: A BatchResult containing the value of the loss function and
#  |          the number of correctly classified samples in the batch.
#  |
#  |  test_epoch(self, dl_test: torch.utils.data.dataloader.DataLoader, **kw) -> helpers.train_results.EpochResult
#  |      Evaluate model once over a test set (single epoch).
#  |      :param dl_test: DataLoader for the test set.
#  |      :param kw: Keyword args supported by _foreach_batch.
#  |      :return: An EpochResult for the epoch.
#  |
#  |  train_batch(self, batch) -> helpers.train_results.BatchResult
#  |      Runs a single batch forward through the model, calculates loss,
#  |      preforms back-propagation and uses the optimizer to update weights.
#  |      :param batch: A single batch of data  from a data loader (might
#  |          be a tuple of data and labels or anything else depending on
#  |          the underlying dataset.
#  |      :return: A BatchResult containing the value of the loss function and
#  |          the number of correctly classified samples in the batch.
#  |
#  |  train_epoch(self, dl_train: torch.utils.data.dataloader.DataLoader, **kw) -> helpers.train_results.EpochResult
#  |      Train once over a training set (single epoch).
#  |      :param dl_train: DataLoader for the training set.
#  |      :param kw: Keyword args supported by _foreach_batch.
#  |      :return: An EpochResult for the epoch.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset({'test_batch', 'train_batch'})

# %% [markdown]
# The `Trainer` class splits the task of training (and evaluating) models into three conceptual levels,
# - Multiple epochs - the `fit` method, which returns a `FitResult` containing losses and accuracies for all epochs.
# - Single epoch - the `train_epoch` and `test_epoch` methods, which return an `EpochResult` containing losses per batch and the single accuracy result of the epoch.
# - Single batch - the `train_batch` and `test_batch` methods, which return a `BatchResult` containing a single loss and the number of correctly classified samples in the batch.
#
# It implements the first two levels. Inheriting classes are expected to implement the single-batch level methods since these are model and/or task specific.

# %% [markdown]
# The first thing we should do in order to verify our model, gradient calculations and optimizer implementation is to try to overfit a large model (many parameters) to a small dataset (few images). This will show us that things are working properly.
#
# Let's begin by loading the CIFAR-10 dataset.

# %% [markdown]
# Note: If you enconter an [SSL: CERTIFICATE_VERIFY_FAILED], uncomment the below lines and run them.

# %%
import ssl 
ssl._create_default_https_context = ssl._create_unverified_context

# %%
data_dir = os.path.join(os.getcwd(), '.pytorch-datasets')
ds_train = torchvision.datasets.CIFAR10(root=data_dir, download=True, train=True, transform=tvtf.ToTensor())
ds_test = torchvision.datasets.CIFAR10(root=data_dir, download=True, train=False, transform=tvtf.ToTensor())

print(f'Train: {len(ds_train)} samples')
print(f'Test: {len(ds_test)} samples')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Train: 50000 samples
# Test: 10000 samples

# %% [markdown]
# Now, let's implement just a small part of our training logic since that's what we need right now.

# %% [markdown]
# **TODO**:
# 1. Complete the implementation of the `train_batch()` method in the `BlocksTrainer` class within the `hw2/training.py` module.
# 1. Update the hyperparameter values in the `part2_overfit_hp()` function in the `hw2/answers.py` module. Tweak the hyperparameter values until your model overfits a small number of samples in the block below. You should get 100% accuracy within a few epochs.

# %%
import hw2.blocks as blocks
import hw2.models as models
import hw2.answers as answers
from torch.utils.data import DataLoader

# Overfit to a very small dataset of 20 samples
batch_size = 10
max_batches = 2
dl_train = torch.utils.data.DataLoader(ds_train, batch_size, shuffle=False)

# Get hyperparameters
hp = answers.part2_overfit_hp()

torch.manual_seed(seed)

# Build a model and loss using our custom MLP and CE implementations
model = models.MLP(3*32*32, num_classes=10, hidden_features=[128]*3, wstd=hp['wstd'])
loss_fn = blocks.CrossEntropyLoss()

# Use our custom optimizer
optimizer = optimizers.VanillaSGD(model.params(), learn_rate=hp['lr'], reg=hp['reg'])

# Run training over small dataset multiple times
trainer = training.BlocksTrainer(model, loss_fn, optimizer)
best_acc = 0
for i in range(20):
    res = trainer.train_epoch(dl_train, max_batches=max_batches)
    best_acc = res.accuracy if res.accuracy > best_acc else best_acc
    
test.assertGreaterEqual(best_acc, 98)
# Out:
# train_batch (Avg. Loss 9.644, Accuracy 20.0): 100%|██████████| 2/2 [00:00<00:00, 142.82it/s]
# train_batch (Avg. Loss 24.673, Accuracy 15.0): 100%|██████████| 2/2 [00:00<00:00, 142.83it/s]
# train_batch (Avg. Loss 2.899, Accuracy 30.0): 100%|██████████| 2/2 [00:00<00:00, 133.30it/s]
# train_batch (Avg. Loss 1.463, Accuracy 55.0): 100%|██████████| 2/2 [00:00<00:00, 142.83it/s]
# train_batch (Avg. Loss 0.870, Accuracy 75.0): 100%|██████████| 2/2 [00:00<00:00, 124.96it/s]
# train_batch (Avg. Loss 0.549, Accuracy 95.0): 100%|██████████| 2/2 [00:00<00:00, 117.63it/s]
# train_batch (Avg. Loss 0.355, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 124.97it/s]
# train_batch (Avg. Loss 0.257, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 124.97it/s]
# train_batch (Avg. Loss 0.188, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 133.31it/s]
# train_batch (Avg. Loss 0.150, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 133.31it/s]
# train_batch (Avg. Loss 0.124, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 124.97it/s]
# train_batch (Avg. Loss 0.104, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 133.33it/s]
# train_batch (Avg. Loss 0.091, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 124.97it/s]
# train_batch (Avg. Loss 0.080, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 124.97it/s]
# train_batch (Avg. Loss 0.071, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 124.97it/s]
# train_batch (Avg. Loss 0.064, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 133.31it/s]
# train_batch (Avg. Loss 0.059, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 124.97it/s]
# train_batch (Avg. Loss 0.054, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 142.83it/s]
# train_batch (Avg. Loss 0.050, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 124.97it/s]
# train_batch (Avg. Loss 0.047, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 124.98it/s]

# %% [markdown]
# Now that we know training works, let's try to fit a model to a bit more data for a few epochs, to see how well we're doing. First, we need a function to plot the FitResults object.

# %%
from helpers.plot import plot_fit
plot_fit?

# %% [markdown]
# **TODO**:
# 1. Complete the implementation of the `test_batch()` method in the `BlocksTrainer` class within the `hw2/training.py` module.
# 1. Implement the `fit()` method of the `Trainer` class within the `hw2/training.py` module.
# 1. Tweak the hyperparameters for this section in the `part2_optim_hp()` function in the `hw2/answers.py` module.
# 1. Run the following blocks to train. Try to get above 35-40% test-set accuracy.

# %%
# Define a larger part of the CIFAR-10 dataset (still not the whole thing)
batch_size = 50
max_batches = 100
in_features = 3*32*32
num_classes = 10
dl_train = torch.utils.data.DataLoader(ds_train, batch_size, shuffle=False)
dl_test = torch.utils.data.DataLoader(ds_test, batch_size//2, shuffle=False)

# %%
# Define a function to train a model with our Trainer and various optimizers
def train_with_optimizer(opt_name, opt_class, fig):
    torch.manual_seed(seed)
    
    # Get hyperparameters
    hp = answers.part2_optim_hp(opt_name)
    hidden_features = [128] * 5
    num_epochs = 10
    
    # Create model, loss and optimizer instances
    model = models.MLP(in_features, num_classes, hidden_features, wstd=hp['wstd'])
    loss_fn = blocks.CrossEntropyLoss()
    optimizer = opt_class(model.params(), learn_rate=hp['lr'], reg=hp['reg'])

    # Train with the Trainer
    trainer = training.BlocksTrainer(model, loss_fn, optimizer)
    fit_res = trainer.fit(dl_train, dl_test, num_epochs, max_batches=max_batches)
    
    fig, axes = plot_fit(fit_res, fig=fig, legend=opt_name)
    return fig

# %%
fig_optim = None
fig_optim = train_with_optimizer('vanilla', optimizers.VanillaSGD, fig_optim)
# Out:
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.168, Accuracy 20.4): 100%|██████████| 100/100 [00:01<00:00, 76.47it/s]
# test_batch (Avg. Loss 2.062, Accuracy 23.2): 100%|██████████| 100/100 [00:00<00:00, 193.22it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 1.995, Accuracy 25.9): 100%|██████████| 100/100 [00:01<00:00, 81.71it/s]
# test_batch (Avg. Loss 1.989, Accuracy 27.8): 100%|██████████| 100/100 [00:00<00:00, 209.05it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.919, Accuracy 29.6): 100%|██████████| 100/100 [00:01<00:00, 81.75it/s]
# test_batch (Avg. Loss 1.947, Accuracy 30.1): 100%|██████████| 100/100 [00:00<00:00, 206.35it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.865, Accuracy 32.5): 100%|██████████| 100/100 [00:01<00:00, 82.46it/s]
# test_batch (Avg. Loss 1.915, Accuracy 32.1): 100%|██████████| 100/100 [00:00<00:00, 169.21it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.824, Accuracy 34.7): 100%|██████████| 100/100 [00:01<00:00, 72.47it/s]
# test_batch (Avg. Loss 1.891, Accuracy 32.6): 100%|██████████| 100/100 [00:00<00:00, 180.47it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.789, Accuracy 35.7): 100%|██████████| 100/100 [00:01<00:00, 77.79it/s]
# test_batch (Avg. Loss 1.863, Accuracy 34.1): 100%|██████████| 100/100 [00:00<00:00, 191.08it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.757, Accuracy 37.0): 100%|██████████| 100/100 [00:01<00:00, 73.04it/s]
# test_batch (Avg. Loss 1.843, Accuracy 34.5): 100%|██████████| 100/100 [00:00<00:00, 189.65it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.729, Accuracy 38.1): 100%|██████████| 100/100 [00:01<00:00, 74.47it/s]
# test_batch (Avg. Loss 1.831, Accuracy 35.1): 100%|██████████| 100/100 [00:00<00:00, 128.34it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.702, Accuracy 39.3): 100%|██████████| 100/100 [00:01<00:00, 72.65it/s]
# test_batch (Avg. Loss 1.822, Accuracy 36.0): 100%|██████████| 100/100 [00:00<00:00, 197.03it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.679, Accuracy 39.8): 100%|██████████| 100/100 [00:01<00:00, 79.69it/s]
# test_batch (Avg. Loss 1.808, Accuracy 35.5): 100%|██████████| 100/100 [00:00<00:00, 191.53it/s]

# %% [markdown]
# ## Momentum
# <a id=part2_4></a>

# %% [markdown]
# The simple vanilla SGD update is rarely used in practice since it's very slow to converge relative to other optimization algorithms.
#
# One reason is that naïvely updating in the direction of the current gradient causes it to fluctuate wildly in areas of the loss surface where some dimensions are much steeper than others.
# Another reason is that using the same learning rate for all parameters is not a great idea since not all parameters are created equal. For example, parameters associated with rare features should be updated with a larger step than ones associated with commonly-occurring features because they'll get less updates through the gradients.
#
# Therefore more advanced optimizers take into account the previous gradients of a parameter and/or try to use a per-parameter specific learning rate instead of a common one.

# %% [markdown]
# Let's now implement a simple and common optimizer: SGD with Momentum. This optimizer takes **previous gradients** of a parameter into account when updating it's value instead of just the current one. In practice it usually provides faster convergence than the vanilla SGD.
#
# The SGD with Momentum update rule can be stated as follows:
# $$\begin{align}
# \vec{v}_{t+1} &= \mu \vec{v}_t - \eta \delta \vec{\theta}_t \\
# \vec{\theta}_{t+1} &= \vec{\theta}_t + \vec{v}_{t+1}
# \end{align}$$
#
# Where $\eta$ is the learning rate,
# $\vec{\theta}$ is a model parameter,
# $\delta \vec{\theta}_t=\pderiv{L}{\vec{\theta}}(\vec{\theta}_t)$ is the gradient of the loss w.r.t. to the parameter and $\mu$ is a hyperparameter known as momentum.
#
# Expanding the update rule recursively shows us now the parameter update infact depends on all previous gradient values for that parameter, where the old gradients are exponentially decayed by a factor of $\mu$ at each timestep.
#
# Since we're incorporating previous gradient (update directions), a noisy value of the current gradient will have less effect so that the general direction of previous updates is maintained somewhat. The following figure illustrates this.
#
# <img src="imgs/sgd-momentum.png" width="600" />

# %% [markdown]
# **TODO**:
# 1. Complete the implementation of the `MomentumSGD` class in the `hw2/optimizers.py` module.
# 1. Tweak the learning rate for momentum in `part2_optim_hp()` the function in the `hw2/answers.py` module.
# 1. Run the following block to compare to the vanilla SGD.

# %%
fig_optim = train_with_optimizer('momentum', optimizers.MomentumSGD, fig_optim)
fig_optim
# Out:
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.192, Accuracy 18.8): 100%|██████████| 100/100 [00:01<00:00, 77.62it/s]
# test_batch (Avg. Loss 2.040, Accuracy 26.1): 100%|██████████| 100/100 [00:00<00:00, 189.71it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 1.980, Accuracy 27.0): 100%|██████████| 100/100 [00:01<00:00, 71.29it/s]
# test_batch (Avg. Loss 1.957, Accuracy 29.2): 100%|██████████| 100/100 [00:00<00:00, 182.40it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.909, Accuracy 30.5): 100%|██████████| 100/100 [00:01<00:00, 66.86it/s]
# test_batch (Avg. Loss 1.903, Accuracy 31.1): 100%|██████████| 100/100 [00:00<00:00, 189.62it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.847, Accuracy 33.3): 100%|██████████| 100/100 [00:01<00:00, 73.80it/s]
# test_batch (Avg. Loss 1.857, Accuracy 31.9): 100%|██████████| 100/100 [00:00<00:00, 199.23it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.796, Accuracy 35.3): 100%|██████████| 100/100 [00:01<00:00, 77.27it/s]
# test_batch (Avg. Loss 1.826, Accuracy 34.6): 100%|██████████| 100/100 [00:00<00:00, 207.17it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.753, Accuracy 36.8): 100%|██████████| 100/100 [00:01<00:00, 77.02it/s]
# test_batch (Avg. Loss 1.793, Accuracy 36.8): 100%|██████████| 100/100 [00:00<00:00, 182.81it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.710, Accuracy 38.6): 100%|██████████| 100/100 [00:01<00:00, 73.28it/s]
# test_batch (Avg. Loss 1.767, Accuracy 38.2): 100%|██████████| 100/100 [00:00<00:00, 182.36it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.672, Accuracy 39.9): 100%|██████████| 100/100 [00:01<00:00, 70.92it/s]
# test_batch (Avg. Loss 1.757, Accuracy 38.2): 100%|██████████| 100/100 [00:00<00:00, 195.84it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.634, Accuracy 41.0): 100%|██████████| 100/100 [00:01<00:00, 74.04it/s]
# test_batch (Avg. Loss 1.747, Accuracy 38.5): 100%|██████████| 100/100 [00:00<00:00, 193.99it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.594, Accuracy 43.0): 100%|██████████| 100/100 [00:01<00:00, 75.69it/s]
# test_batch (Avg. Loss 1.728, Accuracy 38.9): 100%|██████████| 100/100 [00:00<00:00, 201.10it/s]

# %% [markdown]
# ## RMSProp
# <a id=part2_5></a>

# %% [markdown]
# This is another optmizer that accounts for previous gradients, but this time it uses them to adapt the learning rate per parameter.
#
# RMSProp maintains a decaying moving average of previous squared gradients,
# $$
# \vec{r}_{t+1} = \gamma\vec{r}_{t} + (1-\gamma)\delta\vec{\theta}_t^2
# $$
#
# where $0<\gamma<1$ is a decay constant usually set close to $1$. The update rule for each parameter is then,
# $$
# \vec{\theta}_{t+1} = \vec{\theta}_t - \left( \frac{\eta}{\sqrt{r_{t+1}+\varepsilon}} \right) \delta\vec{\theta}_t
# $$
#
# where $\varepsilon$ is a small constant to prevent numerical instability. The idea here is to decrease the learning rate for parameters with high gradient values and vice-versa. The decaying moving average prevents accumulating all the past gradients which would cause the effective learning rate to become zero.

# %% [markdown]
# **TODO**:
# 1. Complete the implementation of the `RMSProp` class in the `hw2/optimizers.py` module.
# 1. Tweak the learning rate for RMSProp in `part2_optim_hp()` the function in the `hw2/answers.py` module.
# 1. Run the following block to compare to the other optimizers.

# %%
fig_optim = train_with_optimizer('rmsprop', optimizers.RMSProp, fig_optim)
fig_optim
# Out:
# --- EPOCH 1/10 ---
# train_batch (2.195):  11%|█         | 11/100 [00:00<00:01, 62.49it/s]
# C:\Users\mazor\PycharmProjects\CNN-ex2\hw2\optimizers.py:152: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   p -= (self.learn_rate / torch.tensor(self.rt[k] + self.eps).sqrt()) * dp
# train_batch (Avg. Loss 2.115, Accuracy 21.4): 100%|██████████| 100/100 [00:01<00:00, 57.71it/s]
# test_batch (Avg. Loss 1.999, Accuracy 25.3): 100%|██████████| 100/100 [00:00<00:00, 216.87it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 1.933, Accuracy 29.2): 100%|██████████| 100/100 [00:01<00:00, 62.79it/s]
# test_batch (Avg. Loss 1.928, Accuracy 29.6): 100%|██████████| 100/100 [00:00<00:00, 199.15it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.862, Accuracy 32.2): 100%|██████████| 100/100 [00:01<00:00, 61.65it/s]
# test_batch (Avg. Loss 1.883, Accuracy 31.8): 100%|██████████| 100/100 [00:00<00:00, 188.99it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.808, Accuracy 34.7): 100%|██████████| 100/100 [00:01<00:00, 59.71it/s]
# test_batch (Avg. Loss 1.842, Accuracy 34.1): 100%|██████████| 100/100 [00:00<00:00, 195.53it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.764, Accuracy 36.1): 100%|██████████| 100/100 [00:01<00:00, 59.49it/s]
# test_batch (Avg. Loss 1.803, Accuracy 36.4): 100%|██████████| 100/100 [00:00<00:00, 192.26it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.725, Accuracy 37.8): 100%|██████████| 100/100 [00:01<00:00, 58.77it/s]
# test_batch (Avg. Loss 1.788, Accuracy 36.2): 100%|██████████| 100/100 [00:00<00:00, 206.52it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.693, Accuracy 39.0): 100%|██████████| 100/100 [00:01<00:00, 61.96it/s]
# test_batch (Avg. Loss 1.764, Accuracy 36.7): 100%|██████████| 100/100 [00:00<00:00, 206.56it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.663, Accuracy 40.3): 100%|██████████| 100/100 [00:01<00:00, 57.24it/s]
# test_batch (Avg. Loss 1.745, Accuracy 37.5): 100%|██████████| 100/100 [00:00<00:00, 168.31it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.633, Accuracy 41.4): 100%|██████████| 100/100 [00:01<00:00, 59.44it/s]
# test_batch (Avg. Loss 1.743, Accuracy 37.4): 100%|██████████| 100/100 [00:00<00:00, 185.14it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.609, Accuracy 42.1): 100%|██████████| 100/100 [00:01<00:00, 60.57it/s]
# test_batch (Avg. Loss 1.736, Accuracy 37.4): 100%|██████████| 100/100 [00:00<00:00, 191.53it/s]

# %% [markdown]
# Note that you should get better train/test accuracy with Momentum and RMSProp than Vanilla.

# %% [markdown]
# ## Dropout Regularization
# <a id=part2_6></a>

# %% [markdown]
# [Dropout](http://jmlr.org/papers/volume15/srivastava14a.old/srivastava14a.pdf) is a useful technique to improve generalization of deep models.
#
# The idea is simple: during the forward pass drop, i.e. set to to zero, the activation of each neuron, with a probability of $p$. For example, if $p=0.5$ this means we drop half the activations on average.
#
# There are a few important things to note about dropout:
# 1. It is only performed during training. When testing our model the dropout layers should be a no-op.
# 1. In the backward pass, gradients are only propagated back into neurons that weren't dropped during the forward pass.
# 1. During testing, the activations must be scaled since the expected value of each neuron during the training phase is now $1-p$ times it's original expectation. Thus, we need to scale the test-time activations by $1-p$ to match. Equivalently, we can scale the train time activations by $1/(1-p)$.

# %% [markdown]
# **TODO**: Complete the implementation of the `Dropout` class in the `hw2/blocks.py` module.

# %%
from hw2.grad_compare import compare_block_to_torch

# Check architecture of MLP with dropout layers
mlp_dropout = models.MLP(in_features, num_classes, [50]*3, dropout=0.6)
print(mlp_dropout)
test.assertEqual(len(mlp_dropout.sequence), 10)
for b1, b2 in zip(mlp_dropout.sequence, mlp_dropout.sequence[1:]):
    if str(b1) == 'relu':
        test.assertTrue(str(b2).startswith('Dropout'))
test.assertTrue(str(mlp_dropout.sequence[-1]).startswith('Linear'))

# Test end-to-end gradient in train and test modes.
mlp_dropout.train(True)
for diff in compare_block_to_torch(mlp_dropout, torch.randn(500, in_features)):
    test.assertLess(diff, 1e-2)
    
mlp_dropout.train(False)
for diff in compare_block_to_torch(mlp_dropout, torch.randn(500, in_features)):
    test.assertLess(diff, 1e-2)
# Out:
# MLP, Sequential
# 	[0] Linear(3072, 50)
# 	[1] ReLU
# 	[2] Dropout(p=0.6)
# 	[3] Linear(50, 50)
# 	[4] ReLU
# 	[5] Dropout(p=0.6)
# 	[6] Linear(50, 50)
# 	[7] ReLU
# 	[8] Dropout(p=0.6)
# 	[9] Linear(50, 10)
#
# Comparing gradients...
# input    diff=0.000
# param#01 diff=0.000
# param#02 diff=0.000
# param#03 diff=0.000
# param#04 diff=0.000
# param#05 diff=0.000
# param#06 diff=0.000
# param#07 diff=0.000
# param#08 diff=0.000
# Comparing gradients...
# input    diff=0.000
# param#01 diff=0.000
# param#02 diff=0.000
# param#03 diff=0.000
# param#04 diff=0.000
# param#05 diff=0.000
# param#06 diff=0.000
# param#07 diff=0.000
# param#08 diff=0.000

# %% [markdown]
# To see whether dropout really improves generalization, let's take a small training set
# (small enough to overfit) and a large test set and check whether we get less overfitting and
# perhaps improved test-set accuracy when using dropout.

# %%
# Define a small set from CIFAR-10, but take a larger test set since we want to test generalization
batch_size = 10
max_batches = 40
in_features = 3*32*32
num_classes = 10
dl_train = torch.utils.data.DataLoader(ds_train, batch_size, shuffle=False)
dl_test = torch.utils.data.DataLoader(ds_test, batch_size*2, shuffle=False)

# %% [markdown]
# **TODO**:
# Tweak the hyperparameters for this section in the `part2_dropout_hp()` function in the `hw2/answers.py` module. Try to set them so that the first model (with `dropout`=0) overfits. You can disable the other dropout options until you tune the hyperparameters. We can then see the effect of dropout for generalization.

# %%
# Get hyperparameters
hp = answers.part2_dropout_hp()
hidden_features = [400] * 1
num_epochs = 80

# %%
torch.manual_seed(seed)
fig=None
for dropout in [0, 0.4, 0.8]:
# for dropout in [0]:
    model = models.MLP(in_features, num_classes, hidden_features, wstd=hp['wstd'], dropout=dropout)
    loss_fn = blocks.CrossEntropyLoss()
    optimizer = optimizers.MomentumSGD(model.params(), learn_rate=hp['lr'], reg=0)

    print('*** Training with dropout=', dropout)
    trainer = training.BlocksTrainer(model, loss_fn, optimizer)
    fit_res_dropout = trainer.fit(dl_train, dl_test, num_epochs, max_batches=max_batches, print_every=6)
    fig, axes = plot_fit(fit_res_dropout, fig=fig, legend=f'dropout={dropout}', log_loss=True)
# Out:
# *** Training with dropout= 0
# --- EPOCH 1/80 ---
# train_batch (Avg. Loss 3.708, Accuracy 13.2): 100%|██████████| 40/40 [00:00<00:00, 86.76it/s]
# test_batch (Avg. Loss 2.659, Accuracy 14.1): 100%|██████████| 40/40 [00:00<00:00, 209.38it/s]
# train_batch (Avg. Loss 2.403, Accuracy 24.0): 100%|██████████| 40/40 [00:00<00:00, 92.36it/s]
# test_batch (Avg. Loss 2.511, Accuracy 17.2): 100%|██████████| 40/40 [00:00<00:00, 213.41it/s]
# train_batch (Avg. Loss 1.962, Accuracy 32.8): 100%|██████████| 40/40 [00:00<00:00, 89.36it/s]
# test_batch (Avg. Loss 2.482, Accuracy 19.2): 100%|██████████| 40/40 [00:00<00:00, 211.59it/s]
# train_batch (Avg. Loss 1.751, Accuracy 41.8): 100%|██████████| 40/40 [00:00<00:00, 90.68it/s]
# test_batch (Avg. Loss 2.494, Accuracy 19.2): 100%|██████████| 40/40 [00:00<00:00, 211.56it/s]
# train_batch (Avg. Loss 1.607, Accuracy 46.5): 100%|██████████| 40/40 [00:00<00:00, 92.78it/s]
# test_batch (Avg. Loss 2.498, Accuracy 20.0): 100%|██████████| 40/40 [00:00<00:00, 229.79it/s]
# train_batch (Avg. Loss 1.495, Accuracy 49.5): 100%|██████████| 40/40 [00:00<00:00, 92.08it/s]
# test_batch (Avg. Loss 2.543, Accuracy 19.9): 100%|██████████| 40/40 [00:00<00:00, 220.94it/s]
# --- EPOCH 7/80 ---
# train_batch (Avg. Loss 1.398, Accuracy 51.5): 100%|██████████| 40/40 [00:00<00:00, 97.54it/s]
# test_batch (Avg. Loss 2.578, Accuracy 21.1): 100%|██████████| 40/40 [00:00<00:00, 225.94it/s]
# train_batch (Avg. Loss 1.282, Accuracy 58.5): 100%|██████████| 40/40 [00:00<00:00, 91.72it/s]
# test_batch (Avg. Loss 2.536, Accuracy 21.5): 100%|██████████| 40/40 [00:00<00:00, 217.93it/s]
# train_batch (Avg. Loss 1.176, Accuracy 61.8): 100%|██████████| 40/40 [00:00<00:00, 92.57it/s]
# test_batch (Avg. Loss 2.509, Accuracy 22.2): 100%|██████████| 40/40 [00:00<00:00, 229.83it/s]
# train_batch (Avg. Loss 1.090, Accuracy 65.5): 100%|██████████| 40/40 [00:00<00:00, 90.38it/s]
# test_batch (Avg. Loss 2.498, Accuracy 22.5): 100%|██████████| 40/40 [00:00<00:00, 215.01it/s]
# train_batch (Avg. Loss 1.025, Accuracy 68.2): 100%|██████████| 40/40 [00:00<00:00, 91.40it/s]
# test_batch (Avg. Loss 2.508, Accuracy 22.4): 100%|██████████| 40/40 [00:00<00:00, 209.38it/s]
# train_batch (Avg. Loss 0.964, Accuracy 72.2): 100%|██████████| 40/40 [00:00<00:00, 91.51it/s]
# test_batch (Avg. Loss 2.520, Accuracy 21.5): 100%|██████████| 40/40 [00:00<00:00, 215.01it/s]
# --- EPOCH 13/80 ---
# train_batch (Avg. Loss 0.906, Accuracy 73.5): 100%|██████████| 40/40 [00:00<00:00, 93.00it/s]
# test_batch (Avg. Loss 2.524, Accuracy 21.5): 100%|██████████| 40/40 [00:00<00:00, 220.95it/s]
# train_batch (Avg. Loss 0.843, Accuracy 75.8): 100%|██████████| 40/40 [00:00<00:00, 90.89it/s]
# test_batch (Avg. Loss 2.533, Accuracy 21.0): 100%|██████████| 40/40 [00:00<00:00, 218.53it/s]
# train_batch (Avg. Loss 0.780, Accuracy 78.8): 100%|██████████| 40/40 [00:00<00:00, 89.76it/s]
# test_batch (Avg. Loss 2.537, Accuracy 21.2): 100%|██████████| 40/40 [00:00<00:00, 212.72it/s]
# train_batch (Avg. Loss 0.721, Accuracy 82.5): 100%|██████████| 40/40 [00:00<00:00, 85.81it/s]
# test_batch (Avg. Loss 2.550, Accuracy 21.4): 100%|██████████| 40/40 [00:00<00:00, 188.19it/s]
# train_batch (Avg. Loss 0.671, Accuracy 85.5): 100%|██████████| 40/40 [00:00<00:00, 87.53it/s]
# test_batch (Avg. Loss 2.562, Accuracy 20.8): 100%|██████████| 40/40 [00:00<00:00, 220.99it/s]
# train_batch (Avg. Loss 0.629, Accuracy 86.5): 100%|██████████| 40/40 [00:00<00:00, 84.14it/s]
# test_batch (Avg. Loss 2.576, Accuracy 20.5): 100%|██████████| 40/40 [00:00<00:00, 198.12it/s]
# --- EPOCH 19/80 ---
# train_batch (Avg. Loss 0.591, Accuracy 87.2): 100%|██████████| 40/40 [00:00<00:00, 93.21it/s]
# test_batch (Avg. Loss 2.595, Accuracy 21.1): 100%|██████████| 40/40 [00:00<00:00, 238.93it/s]
# train_batch (Avg. Loss 0.560, Accuracy 88.5): 100%|██████████| 40/40 [00:00<00:00, 96.88it/s]
# test_batch (Avg. Loss 2.609, Accuracy 20.8): 100%|██████████| 40/40 [00:00<00:00, 229.17it/s]
# train_batch (Avg. Loss 0.529, Accuracy 89.8): 100%|██████████| 40/40 [00:00<00:00, 96.42it/s]
# test_batch (Avg. Loss 2.627, Accuracy 21.0): 100%|██████████| 40/40 [00:00<00:00, 244.57it/s]
# train_batch (Avg. Loss 0.504, Accuracy 90.5): 100%|██████████| 40/40 [00:00<00:00, 95.79it/s]
# test_batch (Avg. Loss 2.647, Accuracy 20.9): 100%|██████████| 40/40 [00:00<00:00, 197.97it/s]
# train_batch (Avg. Loss 0.481, Accuracy 91.5): 100%|██████████| 40/40 [00:00<00:00, 85.81it/s]
# test_batch (Avg. Loss 2.671, Accuracy 21.4): 100%|██████████| 40/40 [00:00<00:00, 240.15it/s]
# train_batch (Avg. Loss 0.460, Accuracy 91.8): 100%|██████████| 40/40 [00:00<00:00, 96.79it/s]
# test_batch (Avg. Loss 2.691, Accuracy 21.0): 100%|██████████| 40/40 [00:00<00:00, 240.32it/s]
# --- EPOCH 25/80 ---
# train_batch (Avg. Loss 0.440, Accuracy 93.0): 100%|██████████| 40/40 [00:00<00:00, 98.48it/s]
# test_batch (Avg. Loss 2.714, Accuracy 20.9): 100%|██████████| 40/40 [00:00<00:00, 242.28it/s]
# train_batch (Avg. Loss 0.423, Accuracy 94.0): 100%|██████████| 40/40 [00:00<00:00, 96.31it/s]
# test_batch (Avg. Loss 2.744, Accuracy 20.6): 100%|██████████| 40/40 [00:00<00:00, 229.80it/s]
# train_batch (Avg. Loss 0.409, Accuracy 94.5): 100%|██████████| 40/40 [00:00<00:00, 100.99it/s]
# test_batch (Avg. Loss 2.765, Accuracy 20.6): 100%|██████████| 40/40 [00:00<00:00, 240.88it/s]
# train_batch (Avg. Loss 0.394, Accuracy 95.2): 100%|██████████| 40/40 [00:00<00:00, 96.90it/s]
# test_batch (Avg. Loss 2.794, Accuracy 20.6): 100%|██████████| 40/40 [00:00<00:00, 232.51it/s]
# train_batch (Avg. Loss 0.382, Accuracy 95.8): 100%|██████████| 40/40 [00:00<00:00, 103.34it/s]
# test_batch (Avg. Loss 2.822, Accuracy 20.8): 100%|██████████| 40/40 [00:00<00:00, 232.51it/s]
# train_batch (Avg. Loss 0.371, Accuracy 96.2): 100%|██████████| 40/40 [00:00<00:00, 96.36it/s]
# test_batch (Avg. Loss 2.840, Accuracy 20.8): 100%|██████████| 40/40 [00:00<00:00, 217.34it/s]
# --- EPOCH 31/80 ---
# train_batch (Avg. Loss 0.359, Accuracy 97.0): 100%|██████████| 40/40 [00:00<00:00, 102.15it/s]
# test_batch (Avg. Loss 2.869, Accuracy 20.6): 100%|██████████| 40/40 [00:00<00:00, 235.24it/s]
# train_batch (Avg. Loss 0.351, Accuracy 96.8): 100%|██████████| 40/40 [00:00<00:00, 98.02it/s]
# test_batch (Avg. Loss 2.887, Accuracy 20.9): 100%|██████████| 40/40 [00:00<00:00, 225.94it/s]
# train_batch (Avg. Loss 0.341, Accuracy 97.0): 100%|██████████| 40/40 [00:00<00:00, 98.26it/s]
# test_batch (Avg. Loss 2.904, Accuracy 20.4): 100%|██████████| 40/40 [00:00<00:00, 232.51it/s]
# train_batch (Avg. Loss 0.335, Accuracy 97.0): 100%|██████████| 40/40 [00:00<00:00, 100.73it/s]
# test_batch (Avg. Loss 2.912, Accuracy 20.8): 100%|██████████| 40/40 [00:00<00:00, 200.45it/s]
# train_batch (Avg. Loss 0.326, Accuracy 97.5): 100%|██████████| 40/40 [00:00<00:00, 83.71it/s]
# test_batch (Avg. Loss 2.935, Accuracy 21.0): 100%|██████████| 40/40 [00:00<00:00, 217.91it/s]
# train_batch (Avg. Loss 0.319, Accuracy 96.8): 100%|██████████| 40/40 [00:00<00:00, 90.37it/s]
# test_batch (Avg. Loss 2.937, Accuracy 21.1): 100%|██████████| 40/40 [00:00<00:00, 206.14it/s]
# --- EPOCH 37/80 ---
# train_batch (Avg. Loss 0.310, Accuracy 97.0): 100%|██████████| 40/40 [00:00<00:00, 86.45it/s]
# test_batch (Avg. Loss 2.939, Accuracy 21.6): 100%|██████████| 40/40 [00:00<00:00, 200.02it/s]
# train_batch (Avg. Loss 0.304, Accuracy 97.0): 100%|██████████| 40/40 [00:00<00:00, 85.96it/s]
# test_batch (Avg. Loss 2.938, Accuracy 21.9): 100%|██████████| 40/40 [00:00<00:00, 215.31it/s]
# train_batch (Avg. Loss 0.295, Accuracy 97.8): 100%|██████████| 40/40 [00:00<00:00, 96.56it/s]
# test_batch (Avg. Loss 2.938, Accuracy 22.2): 100%|██████████| 40/40 [00:00<00:00, 240.39it/s]
# train_batch (Avg. Loss 0.288, Accuracy 97.2): 100%|██████████| 40/40 [00:00<00:00, 97.90it/s]
# test_batch (Avg. Loss 2.933, Accuracy 22.2): 100%|██████████| 40/40 [00:00<00:00, 245.47it/s]
# train_batch (Avg. Loss 0.280, Accuracy 97.5): 100%|██████████| 40/40 [00:00<00:00, 100.91it/s]
# test_batch (Avg. Loss 2.935, Accuracy 22.2): 100%|██████████| 40/40 [00:00<00:00, 241.29it/s]
# train_batch (Avg. Loss 0.273, Accuracy 97.5): 100%|██████████| 40/40 [00:00<00:00, 91.16it/s]
# test_batch (Avg. Loss 2.926, Accuracy 21.5): 100%|██████████| 40/40 [00:00<00:00, 202.52it/s]
# --- EPOCH 43/80 ---
# train_batch (Avg. Loss 0.265, Accuracy 97.8): 100%|██████████| 40/40 [00:00<00:00, 91.82it/s]
# test_batch (Avg. Loss 2.916, Accuracy 21.5): 100%|██████████| 40/40 [00:00<00:00, 210.51it/s]
# train_batch (Avg. Loss 0.258, Accuracy 97.8): 100%|██████████| 40/40 [00:00<00:00, 88.98it/s]
# test_batch (Avg. Loss 2.913, Accuracy 22.0): 100%|██████████| 40/40 [00:00<00:00, 209.89it/s]
# train_batch (Avg. Loss 0.250, Accuracy 98.5): 100%|██████████| 40/40 [00:00<00:00, 102.26it/s]
# test_batch (Avg. Loss 2.907, Accuracy 22.2): 100%|██████████| 40/40 [00:00<00:00, 252.31it/s]
# train_batch (Avg. Loss 0.242, Accuracy 98.5): 100%|██████████| 40/40 [00:00<00:00, 99.02it/s]
# test_batch (Avg. Loss 2.909, Accuracy 22.2): 100%|██████████| 40/40 [00:00<00:00, 241.61it/s]
# train_batch (Avg. Loss 0.237, Accuracy 98.0): 100%|██████████| 40/40 [00:00<00:00, 99.05it/s]
# test_batch (Avg. Loss 2.904, Accuracy 22.2): 100%|██████████| 40/40 [00:00<00:00, 246.34it/s]
# train_batch (Avg. Loss 0.231, Accuracy 98.2): 100%|██████████| 40/40 [00:00<00:00, 100.54it/s]
# test_batch (Avg. Loss 2.906, Accuracy 22.2): 100%|██████████| 40/40 [00:00<00:00, 238.67it/s]
# --- EPOCH 49/80 ---
# train_batch (Avg. Loss 0.224, Accuracy 99.2): 100%|██████████| 40/40 [00:00<00:00, 89.23it/s]
# test_batch (Avg. Loss 2.905, Accuracy 22.1): 100%|██████████| 40/40 [00:00<00:00, 228.79it/s]
# train_batch (Avg. Loss 0.218, Accuracy 99.2): 100%|██████████| 40/40 [00:00<00:00, 93.81it/s]
# test_batch (Avg. Loss 2.918, Accuracy 22.0): 100%|██████████| 40/40 [00:00<00:00, 225.94it/s]
# train_batch (Avg. Loss 0.214, Accuracy 99.0): 100%|██████████| 40/40 [00:00<00:00, 96.84it/s]
# test_batch (Avg. Loss 2.938, Accuracy 21.6): 100%|██████████| 40/40 [00:00<00:00, 227.44it/s]
# train_batch (Avg. Loss 0.209, Accuracy 99.0): 100%|██████████| 40/40 [00:00<00:00, 98.37it/s]
# test_batch (Avg. Loss 2.951, Accuracy 21.9): 100%|██████████| 40/40 [00:00<00:00, 218.68it/s]
# train_batch (Avg. Loss 0.206, Accuracy 98.8): 100%|██████████| 40/40 [00:00<00:00, 96.68it/s]
# test_batch (Avg. Loss 2.965, Accuracy 22.0): 100%|██████████| 40/40 [00:00<00:00, 232.08it/s]
# train_batch (Avg. Loss 0.201, Accuracy 99.0): 100%|██████████| 40/40 [00:00<00:00, 99.23it/s]
# test_batch (Avg. Loss 2.974, Accuracy 22.0): 100%|██████████| 40/40 [00:00<00:00, 223.41it/s]
# --- EPOCH 55/80 ---
# train_batch (Avg. Loss 0.196, Accuracy 99.0): 100%|██████████| 40/40 [00:00<00:00, 90.04it/s]
# test_batch (Avg. Loss 2.965, Accuracy 22.5): 100%|██████████| 40/40 [00:00<00:00, 194.13it/s]
# train_batch (Avg. Loss 0.190, Accuracy 99.0): 100%|██████████| 40/40 [00:00<00:00, 96.13it/s]
# test_batch (Avg. Loss 2.958, Accuracy 22.2): 100%|██████████| 40/40 [00:00<00:00, 235.24it/s]
# train_batch (Avg. Loss 0.184, Accuracy 99.2): 100%|██████████| 40/40 [00:00<00:00, 96.83it/s]
# test_batch (Avg. Loss 2.951, Accuracy 22.4): 100%|██████████| 40/40 [00:00<00:00, 228.52it/s]
# train_batch (Avg. Loss 0.178, Accuracy 99.2): 100%|██████████| 40/40 [00:00<00:00, 90.15it/s]
# test_batch (Avg. Loss 2.933, Accuracy 22.9): 100%|██████████| 40/40 [00:00<00:00, 227.22it/s]
# train_batch (Avg. Loss 0.171, Accuracy 99.2): 100%|██████████| 40/40 [00:00<00:00, 93.59it/s]
# test_batch (Avg. Loss 2.918, Accuracy 22.9): 100%|██████████| 40/40 [00:00<00:00, 204.04it/s]
# train_batch (Avg. Loss 0.164, Accuracy 99.2): 100%|██████████| 40/40 [00:00<00:00, 54.53it/s]
# test_batch (Avg. Loss 2.909, Accuracy 22.8): 100%|██████████| 40/40 [00:00<00:00, 170.65it/s]
# --- EPOCH 61/80 ---
# train_batch (Avg. Loss 0.156, Accuracy 99.2): 100%|██████████| 40/40 [00:00<00:00, 70.91it/s]
# test_batch (Avg. Loss 2.898, Accuracy 23.1): 100%|██████████| 40/40 [00:00<00:00, 171.00it/s]
# train_batch (Avg. Loss 0.148, Accuracy 99.5): 100%|██████████| 40/40 [00:00<00:00, 69.13it/s]
# test_batch (Avg. Loss 2.909, Accuracy 23.5): 100%|██████████| 40/40 [00:00<00:00, 185.77it/s]
# train_batch (Avg. Loss 0.141, Accuracy 99.5): 100%|██████████| 40/40 [00:00<00:00, 79.37it/s]
# test_batch (Avg. Loss 2.932, Accuracy 23.2): 100%|██████████| 40/40 [00:00<00:00, 194.13it/s]
# train_batch (Avg. Loss 0.134, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 88.59it/s]
# test_batch (Avg. Loss 2.964, Accuracy 23.2): 100%|██████████| 40/40 [00:00<00:00, 197.97it/s]
# train_batch (Avg. Loss 0.129, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 79.38it/s]
# test_batch (Avg. Loss 3.006, Accuracy 22.9): 100%|██████████| 40/40 [00:00<00:00, 222.17it/s]
# train_batch (Avg. Loss 0.125, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 94.94it/s]
# test_batch (Avg. Loss 3.042, Accuracy 22.2): 100%|██████████| 40/40 [00:00<00:00, 223.26it/s]
# --- EPOCH 67/80 ---
# train_batch (Avg. Loss 0.121, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 84.85it/s]
# test_batch (Avg. Loss 3.070, Accuracy 22.2): 100%|██████████| 40/40 [00:00<00:00, 176.95it/s]
# train_batch (Avg. Loss 0.117, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 75.34it/s]
# test_batch (Avg. Loss 3.095, Accuracy 22.1): 100%|██████████| 40/40 [00:00<00:00, 187.23it/s]
# train_batch (Avg. Loss 0.115, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 79.63it/s]
# test_batch (Avg. Loss 3.111, Accuracy 22.4): 100%|██████████| 40/40 [00:00<00:00, 207.21it/s]
# train_batch (Avg. Loss 0.112, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 91.54it/s]
# test_batch (Avg. Loss 3.129, Accuracy 22.5): 100%|██████████| 40/40 [00:00<00:00, 213.86it/s]
# train_batch (Avg. Loss 0.110, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 88.28it/s]
# test_batch (Avg. Loss 3.138, Accuracy 22.9): 100%|██████████| 40/40 [00:00<00:00, 213.79it/s]
# train_batch (Avg. Loss 0.107, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 91.10it/s]
# test_batch (Avg. Loss 3.148, Accuracy 22.8): 100%|██████████| 40/40 [00:00<00:00, 186.00it/s]
# --- EPOCH 73/80 ---
# train_batch (Avg. Loss 0.105, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 89.87it/s]
# test_batch (Avg. Loss 3.156, Accuracy 22.9): 100%|██████████| 40/40 [00:00<00:00, 206.14it/s]
# train_batch (Avg. Loss 0.104, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 82.46it/s]
# test_batch (Avg. Loss 3.165, Accuracy 23.0): 100%|██████████| 40/40 [00:00<00:00, 217.34it/s]
# train_batch (Avg. Loss 0.102, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 97.30it/s]
# test_batch (Avg. Loss 3.169, Accuracy 23.1): 100%|██████████| 40/40 [00:00<00:00, 235.24it/s]
# train_batch (Avg. Loss 0.100, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 98.50it/s]
# test_batch (Avg. Loss 3.173, Accuracy 22.8): 100%|██████████| 40/40 [00:00<00:00, 233.87it/s]
# train_batch (Avg. Loss 0.099, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 101.24it/s]
# test_batch (Avg. Loss 3.180, Accuracy 22.9): 100%|██████████| 40/40 [00:00<00:00, 227.22it/s]
# train_batch (Avg. Loss 0.097, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 76.98it/s]
# test_batch (Avg. Loss 3.191, Accuracy 23.4): 100%|██████████| 40/40 [00:00<00:00, 81.81it/s]
# --- EPOCH 79/80 ---
# train_batch (Avg. Loss 0.096, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 63.58it/s]
# test_batch (Avg. Loss 3.205, Accuracy 24.2): 100%|██████████| 40/40 [00:00<00:00, 219.73it/s]
# --- EPOCH 80/80 ---
# train_batch (Avg. Loss 0.094, Accuracy 99.8): 100%|██████████| 40/40 [00:00<00:00, 80.63it/s]
# test_batch (Avg. Loss 3.216, Accuracy 24.1): 100%|██████████| 40/40 [00:00<00:00, 207.21it/s]
# *** Training with dropout= 0.4
# --- EPOCH 1/80 ---
# train_batch (Avg. Loss 3.809, Accuracy 10.5): 100%|██████████| 40/40 [00:00<00:00, 102.28it/s]
# test_batch (Avg. Loss 2.377, Accuracy 16.8): 100%|██████████| 40/40 [00:00<00:00, 231.16it/s]
# train_batch (Avg. Loss 2.779, Accuracy 17.0): 100%|██████████| 40/40 [00:00<00:00, 99.48it/s]
# test_batch (Avg. Loss 2.282, Accuracy 21.0): 100%|██████████| 40/40 [00:00<00:00, 233.86it/s]
# train_batch (Avg. Loss 2.299, Accuracy 22.2): 100%|██████████| 40/40 [00:00<00:00, 106.64it/s]
# test_batch (Avg. Loss 2.167, Accuracy 23.2): 100%|██████████| 40/40 [00:00<00:00, 240.91it/s]
# train_batch (Avg. Loss 2.105, Accuracy 25.5): 100%|██████████| 40/40 [00:00<00:00, 97.54it/s]
# test_batch (Avg. Loss 2.102, Accuracy 25.2): 100%|██████████| 40/40 [00:00<00:00, 229.83it/s]
# train_batch (Avg. Loss 1.972, Accuracy 29.0): 100%|██████████| 40/40 [00:00<00:00, 106.64it/s]
# test_batch (Avg. Loss 2.056, Accuracy 26.9): 100%|██████████| 40/40 [00:00<00:00, 210.49it/s]
# train_batch (Avg. Loss 1.917, Accuracy 32.0): 100%|██████████| 40/40 [00:00<00:00, 102.28it/s]
# test_batch (Avg. Loss 2.041, Accuracy 26.2): 100%|██████████| 40/40 [00:00<00:00, 228.52it/s]
# --- EPOCH 7/80 ---
# train_batch (Avg. Loss 1.812, Accuracy 32.8): 100%|██████████| 40/40 [00:00<00:00, 105.80it/s]
# test_batch (Avg. Loss 2.053, Accuracy 26.4): 100%|██████████| 40/40 [00:00<00:00, 223.42it/s]
# train_batch (Avg. Loss 1.789, Accuracy 35.2): 100%|██████████| 40/40 [00:00<00:00, 100.99it/s]
# test_batch (Avg. Loss 2.027, Accuracy 28.0): 100%|██████████| 40/40 [00:00<00:00, 216.17it/s]
# train_batch (Avg. Loss 1.700, Accuracy 36.0): 100%|██████████| 40/40 [00:00<00:00, 97.78it/s]
# test_batch (Avg. Loss 2.022, Accuracy 29.1): 100%|██████████| 40/40 [00:00<00:00, 225.94it/s]
# train_batch (Avg. Loss 1.609, Accuracy 45.0): 100%|██████████| 40/40 [00:00<00:00, 95.90it/s]
# test_batch (Avg. Loss 2.021, Accuracy 27.1): 100%|██████████| 40/40 [00:00<00:00, 220.95it/s]
# train_batch (Avg. Loss 1.622, Accuracy 42.5): 100%|██████████| 40/40 [00:00<00:00, 101.24it/s]
# test_batch (Avg. Loss 2.003, Accuracy 29.1): 100%|██████████| 40/40 [00:00<00:00, 232.51it/s]
# train_batch (Avg. Loss 1.603, Accuracy 41.0): 100%|██████████| 40/40 [00:00<00:00, 87.70it/s]
# test_batch (Avg. Loss 2.009, Accuracy 28.1): 100%|██████████| 40/40 [00:00<00:00, 209.38it/s]
# --- EPOCH 13/80 ---
# train_batch (Avg. Loss 1.563, Accuracy 45.8): 100%|██████████| 40/40 [00:00<00:00, 89.67it/s]
# test_batch (Avg. Loss 2.005, Accuracy 28.1): 100%|██████████| 40/40 [00:00<00:00, 218.53it/s]
# train_batch (Avg. Loss 1.540, Accuracy 44.8): 100%|██████████| 40/40 [00:00<00:00, 100.23it/s]
# test_batch (Avg. Loss 2.023, Accuracy 27.0): 100%|██████████| 40/40 [00:00<00:00, 228.52it/s]
# train_batch (Avg. Loss 1.461, Accuracy 49.2): 100%|██████████| 40/40 [00:00<00:00, 101.76it/s]
# test_batch (Avg. Loss 2.003, Accuracy 27.8): 100%|██████████| 40/40 [00:00<00:00, 195.08it/s]
# train_batch (Avg. Loss 1.399, Accuracy 53.8): 100%|██████████| 40/40 [00:00<00:00, 98.26it/s]
# test_batch (Avg. Loss 1.988, Accuracy 28.6): 100%|██████████| 40/40 [00:00<00:00, 228.52it/s]
# train_batch (Avg. Loss 1.444, Accuracy 51.0): 100%|██████████| 40/40 [00:00<00:00, 102.02it/s]
# test_batch (Avg. Loss 1.997, Accuracy 28.4): 100%|██████████| 40/40 [00:00<00:00, 238.04it/s]
# train_batch (Avg. Loss 1.398, Accuracy 52.2): 100%|██████████| 40/40 [00:00<00:00, 96.17it/s]
# test_batch (Avg. Loss 1.997, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 202.36it/s]
# --- EPOCH 19/80 ---
# train_batch (Avg. Loss 1.357, Accuracy 54.8): 100%|██████████| 40/40 [00:00<00:00, 98.34it/s]
# test_batch (Avg. Loss 2.010, Accuracy 29.1): 100%|██████████| 40/40 [00:00<00:00, 208.29it/s]
# train_batch (Avg. Loss 1.369, Accuracy 54.2): 100%|██████████| 40/40 [00:00<00:00, 95.25it/s]
# test_batch (Avg. Loss 1.985, Accuracy 27.9): 100%|██████████| 40/40 [00:00<00:00, 235.24it/s]
# train_batch (Avg. Loss 1.362, Accuracy 54.5): 100%|██████████| 40/40 [00:00<00:00, 89.63it/s]
# test_batch (Avg. Loss 2.001, Accuracy 29.0): 100%|██████████| 40/40 [00:00<00:00, 180.22it/s]
# train_batch (Avg. Loss 1.305, Accuracy 57.5): 100%|██████████| 40/40 [00:00<00:00, 93.06it/s]
# test_batch (Avg. Loss 1.993, Accuracy 28.1): 100%|██████████| 40/40 [00:00<00:00, 235.24it/s]
# train_batch (Avg. Loss 1.267, Accuracy 59.5): 100%|██████████| 40/40 [00:00<00:00, 93.04it/s]
# test_batch (Avg. Loss 1.983, Accuracy 28.4): 100%|██████████| 40/40 [00:00<00:00, 203.91it/s]
# train_batch (Avg. Loss 1.229, Accuracy 58.8): 100%|██████████| 40/40 [00:00<00:00, 97.94it/s]
# test_batch (Avg. Loss 1.981, Accuracy 28.1): 100%|██████████| 40/40 [00:00<00:00, 238.04it/s]
# --- EPOCH 25/80 ---
# train_batch (Avg. Loss 1.224, Accuracy 60.2): 100%|██████████| 40/40 [00:00<00:00, 99.48it/s]
# test_batch (Avg. Loss 1.988, Accuracy 27.2): 100%|██████████| 40/40 [00:00<00:00, 220.95it/s]
# train_batch (Avg. Loss 1.139, Accuracy 62.0): 100%|██████████| 40/40 [00:00<00:00, 103.07it/s]
# test_batch (Avg. Loss 2.002, Accuracy 28.0): 100%|██████████| 40/40 [00:00<00:00, 242.37it/s]
# train_batch (Avg. Loss 1.207, Accuracy 59.5): 100%|██████████| 40/40 [00:00<00:00, 92.36it/s]
# test_batch (Avg. Loss 1.996, Accuracy 27.9): 100%|██████████| 40/40 [00:00<00:00, 223.41it/s]
# train_batch (Avg. Loss 1.192, Accuracy 61.5): 100%|██████████| 40/40 [00:00<00:00, 100.48it/s]
# test_batch (Avg. Loss 1.991, Accuracy 28.9): 100%|██████████| 40/40 [00:00<00:00, 232.51it/s]
# train_batch (Avg. Loss 1.113, Accuracy 63.2): 100%|██████████| 40/40 [00:00<00:00, 108.38it/s]
# test_batch (Avg. Loss 1.999, Accuracy 29.5): 100%|██████████| 40/40 [00:00<00:00, 236.64it/s]
# train_batch (Avg. Loss 1.109, Accuracy 66.8): 100%|██████████| 40/40 [00:00<00:00, 108.67it/s]
# test_batch (Avg. Loss 1.986, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 242.37it/s]
# --- EPOCH 31/80 ---
# train_batch (Avg. Loss 1.051, Accuracy 66.2): 100%|██████████| 40/40 [00:00<00:00, 102.80it/s]
# test_batch (Avg. Loss 2.003, Accuracy 30.2): 100%|██████████| 40/40 [00:00<00:00, 231.16it/s]
# train_batch (Avg. Loss 1.094, Accuracy 64.0): 100%|██████████| 40/40 [00:00<00:00, 108.08it/s]
# test_batch (Avg. Loss 2.008, Accuracy 29.9): 100%|██████████| 40/40 [00:00<00:00, 235.24it/s]
# train_batch (Avg. Loss 1.051, Accuracy 66.5): 100%|██████████| 40/40 [00:00<00:00, 100.23it/s]
# test_batch (Avg. Loss 2.009, Accuracy 29.0): 100%|██████████| 40/40 [00:00<00:00, 235.24it/s]
# train_batch (Avg. Loss 1.063, Accuracy 66.8): 100%|██████████| 40/40 [00:00<00:00, 108.08it/s]
# test_batch (Avg. Loss 1.992, Accuracy 28.6): 100%|██████████| 40/40 [00:00<00:00, 222.17it/s]
# train_batch (Avg. Loss 1.018, Accuracy 68.8): 100%|██████████| 40/40 [00:00<00:00, 99.98it/s]
# test_batch (Avg. Loss 2.004, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 216.17it/s]
# train_batch (Avg. Loss 1.025, Accuracy 68.8): 100%|██████████| 40/40 [00:00<00:00, 101.24it/s]
# test_batch (Avg. Loss 2.024, Accuracy 27.4): 100%|██████████| 40/40 [00:00<00:00, 217.34it/s]
# --- EPOCH 37/80 ---
# train_batch (Avg. Loss 0.999, Accuracy 70.0): 100%|██████████| 40/40 [00:00<00:00, 97.54it/s]
# test_batch (Avg. Loss 2.006, Accuracy 27.9): 100%|██████████| 40/40 [00:00<00:00, 236.63it/s]
# train_batch (Avg. Loss 0.952, Accuracy 72.0): 100%|██████████| 40/40 [00:00<00:00, 103.87it/s]
# test_batch (Avg. Loss 2.021, Accuracy 29.0): 100%|██████████| 40/40 [00:00<00:00, 245.34it/s]
# train_batch (Avg. Loss 0.913, Accuracy 71.2): 100%|██████████| 40/40 [00:00<00:00, 98.50it/s]
# test_batch (Avg. Loss 2.022, Accuracy 29.1): 100%|██████████| 40/40 [00:00<00:00, 207.21it/s]
# train_batch (Avg. Loss 0.960, Accuracy 71.0): 100%|██████████| 40/40 [00:00<00:00, 82.46it/s]
# test_batch (Avg. Loss 2.020, Accuracy 30.2): 100%|██████████| 40/40 [00:00<00:00, 216.17it/s]
# train_batch (Avg. Loss 0.915, Accuracy 74.2): 100%|██████████| 40/40 [00:00<00:00, 96.83it/s]
# test_batch (Avg. Loss 2.021, Accuracy 29.4): 100%|██████████| 40/40 [00:00<00:00, 227.22it/s]
# train_batch (Avg. Loss 0.933, Accuracy 72.2): 100%|██████████| 40/40 [00:00<00:00, 102.67it/s]
# test_batch (Avg. Loss 2.017, Accuracy 28.0): 100%|██████████| 40/40 [00:00<00:00, 198.96it/s]
# --- EPOCH 43/80 ---
# train_batch (Avg. Loss 0.892, Accuracy 70.8): 100%|██████████| 40/40 [00:00<00:00, 98.02it/s]
# test_batch (Avg. Loss 2.014, Accuracy 30.0): 100%|██████████| 40/40 [00:00<00:00, 205.08it/s]
# train_batch (Avg. Loss 0.859, Accuracy 77.5): 100%|██████████| 40/40 [00:00<00:00, 99.23it/s]
# test_batch (Avg. Loss 2.021, Accuracy 28.8): 100%|██████████| 40/40 [00:00<00:00, 231.16it/s]
# train_batch (Avg. Loss 0.793, Accuracy 78.2): 100%|██████████| 40/40 [00:00<00:00, 102.02it/s]
# test_batch (Avg. Loss 2.034, Accuracy 27.8): 100%|██████████| 40/40 [00:00<00:00, 206.14it/s]
# train_batch (Avg. Loss 0.886, Accuracy 72.5): 100%|██████████| 40/40 [00:00<00:00, 71.41it/s]
# test_batch (Avg. Loss 2.033, Accuracy 28.4): 100%|██████████| 40/40 [00:00<00:00, 196.03it/s]
# train_batch (Avg. Loss 0.834, Accuracy 74.5): 100%|██████████| 40/40 [00:00<00:00, 104.69it/s]
# test_batch (Avg. Loss 2.047, Accuracy 28.4): 100%|██████████| 40/40 [00:00<00:00, 246.85it/s]
# train_batch (Avg. Loss 0.850, Accuracy 75.5): 100%|██████████| 40/40 [00:00<00:00, 107.22it/s]
# test_batch (Avg. Loss 2.049, Accuracy 28.4): 100%|██████████| 40/40 [00:00<00:00, 207.21it/s]
# --- EPOCH 49/80 ---
# train_batch (Avg. Loss 0.812, Accuracy 74.8): 100%|██████████| 40/40 [00:00<00:00, 66.32it/s]
# test_batch (Avg. Loss 2.068, Accuracy 27.5): 100%|██████████| 40/40 [00:00<00:00, 223.41it/s]
# train_batch (Avg. Loss 0.781, Accuracy 78.5): 100%|██████████| 40/40 [00:00<00:00, 100.48it/s]
# test_batch (Avg. Loss 2.047, Accuracy 27.8): 100%|██████████| 40/40 [00:00<00:00, 239.47it/s]
# train_batch (Avg. Loss 0.779, Accuracy 76.0): 100%|██████████| 40/40 [00:00<00:00, 74.89it/s]
# test_batch (Avg. Loss 2.052, Accuracy 28.5): 100%|██████████| 40/40 [00:00<00:00, 195.08it/s]
# train_batch (Avg. Loss 0.775, Accuracy 78.5): 100%|██████████| 40/40 [00:00<00:00, 67.55it/s]
# test_batch (Avg. Loss 2.049, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 159.33it/s]
# train_batch (Avg. Loss 0.779, Accuracy 78.8): 100%|██████████| 40/40 [00:00<00:00, 64.09it/s]
# test_batch (Avg. Loss 2.052, Accuracy 27.8): 100%|██████████| 40/40 [00:00<00:00, 208.29it/s]
# train_batch (Avg. Loss 0.715, Accuracy 79.8): 100%|██████████| 40/40 [00:00<00:00, 95.67it/s]
# test_batch (Avg. Loss 2.055, Accuracy 29.1): 100%|██████████| 40/40 [00:00<00:00, 224.67it/s]
# --- EPOCH 55/80 ---
# train_batch (Avg. Loss 0.734, Accuracy 79.2): 100%|██████████| 40/40 [00:00<00:00, 98.02it/s]
# test_batch (Avg. Loss 2.049, Accuracy 29.5): 100%|██████████| 40/40 [00:00<00:00, 219.73it/s]
# train_batch (Avg. Loss 0.690, Accuracy 81.2): 100%|██████████| 40/40 [00:00<00:00, 98.50it/s]
# test_batch (Avg. Loss 2.069, Accuracy 27.8): 100%|██████████| 40/40 [00:00<00:00, 218.53it/s]
# train_batch (Avg. Loss 0.686, Accuracy 81.8): 100%|██████████| 40/40 [00:00<00:00, 98.99it/s]
# test_batch (Avg. Loss 2.068, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 207.21it/s]
# train_batch (Avg. Loss 0.716, Accuracy 79.2): 100%|██████████| 40/40 [00:00<00:00, 93.66it/s]
# test_batch (Avg. Loss 2.068, Accuracy 28.5): 100%|██████████| 40/40 [00:00<00:00, 235.24it/s]
# train_batch (Avg. Loss 0.680, Accuracy 82.0): 100%|██████████| 40/40 [00:00<00:00, 104.69it/s]
# test_batch (Avg. Loss 2.068, Accuracy 28.5): 100%|██████████| 40/40 [00:00<00:00, 238.04it/s]
# train_batch (Avg. Loss 0.688, Accuracy 81.2): 100%|██████████| 40/40 [00:00<00:00, 96.36it/s]
# test_batch (Avg. Loss 2.088, Accuracy 27.9): 100%|██████████| 40/40 [00:00<00:00, 233.87it/s]
# --- EPOCH 61/80 ---
# train_batch (Avg. Loss 0.657, Accuracy 82.5): 100%|██████████| 40/40 [00:00<00:00, 102.02it/s]
# test_batch (Avg. Loss 2.087, Accuracy 28.6): 100%|██████████| 40/40 [00:00<00:00, 224.67it/s]
# train_batch (Avg. Loss 0.670, Accuracy 81.5): 100%|██████████| 40/40 [00:00<00:00, 86.00it/s]
# test_batch (Avg. Loss 2.102, Accuracy 28.4): 100%|██████████| 40/40 [00:00<00:00, 210.48it/s]
# train_batch (Avg. Loss 0.628, Accuracy 84.8): 100%|██████████| 40/40 [00:00<00:00, 90.89it/s]
# test_batch (Avg. Loss 2.099, Accuracy 28.5): 100%|██████████| 40/40 [00:00<00:00, 233.87it/s]
# train_batch (Avg. Loss 0.633, Accuracy 83.0): 100%|██████████| 40/40 [00:00<00:00, 99.73it/s]
# test_batch (Avg. Loss 2.114, Accuracy 28.6): 100%|██████████| 40/40 [00:00<00:00, 188.64it/s]
# train_batch (Avg. Loss 0.647, Accuracy 83.5): 100%|██████████| 40/40 [00:00<00:00, 78.26it/s]
# test_batch (Avg. Loss 2.129, Accuracy 28.5): 100%|██████████| 40/40 [00:00<00:00, 201.97it/s]
# train_batch (Avg. Loss 0.649, Accuracy 83.0): 100%|██████████| 40/40 [00:00<00:00, 86.56it/s]
# test_batch (Avg. Loss 2.096, Accuracy 28.6): 100%|██████████| 40/40 [00:00<00:00, 195.08it/s]
# --- EPOCH 67/80 ---
# train_batch (Avg. Loss 0.584, Accuracy 85.5): 100%|██████████| 40/40 [00:00<00:00, 89.87it/s]
# test_batch (Avg. Loss 2.116, Accuracy 27.9): 100%|██████████| 40/40 [00:00<00:00, 189.53it/s]
# train_batch (Avg. Loss 0.582, Accuracy 86.0): 100%|██████████| 40/40 [00:00<00:00, 95.67it/s]
# test_batch (Avg. Loss 2.114, Accuracy 28.9): 100%|██████████| 40/40 [00:00<00:00, 223.41it/s]
# train_batch (Avg. Loss 0.562, Accuracy 86.0): 100%|██████████| 40/40 [00:00<00:00, 102.81it/s]
# test_batch (Avg. Loss 2.108, Accuracy 27.5): 100%|██████████| 40/40 [00:00<00:00, 220.94it/s]
# train_batch (Avg. Loss 0.567, Accuracy 85.8): 100%|██████████| 40/40 [00:00<00:00, 101.24it/s]
# test_batch (Avg. Loss 2.128, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 235.24it/s]
# train_batch (Avg. Loss 0.547, Accuracy 87.0): 100%|██████████| 40/40 [00:00<00:00, 102.54it/s]
# test_batch (Avg. Loss 2.150, Accuracy 26.9): 100%|██████████| 40/40 [00:00<00:00, 219.73it/s]
# train_batch (Avg. Loss 0.549, Accuracy 87.2): 100%|██████████| 40/40 [00:00<00:00, 104.42it/s]
# test_batch (Avg. Loss 2.121, Accuracy 27.2): 100%|██████████| 40/40 [00:00<00:00, 236.63it/s]
# --- EPOCH 73/80 ---
# train_batch (Avg. Loss 0.558, Accuracy 86.8): 100%|██████████| 40/40 [00:00<00:00, 102.28it/s]
# test_batch (Avg. Loss 2.154, Accuracy 28.1): 100%|██████████| 40/40 [00:00<00:00, 220.95it/s]
# train_batch (Avg. Loss 0.502, Accuracy 86.5): 100%|██████████| 40/40 [00:00<00:00, 98.99it/s]
# test_batch (Avg. Loss 2.147, Accuracy 27.9): 100%|██████████| 40/40 [00:00<00:00, 238.04it/s]
# train_batch (Avg. Loss 0.543, Accuracy 86.5): 100%|██████████| 40/40 [00:00<00:00, 101.50it/s]
# test_batch (Avg. Loss 2.150, Accuracy 27.6): 100%|██████████| 40/40 [00:00<00:00, 223.41it/s]
# train_batch (Avg. Loss 0.504, Accuracy 88.2): 100%|██████████| 40/40 [00:00<00:00, 105.80it/s]
# test_batch (Avg. Loss 2.141, Accuracy 27.2): 100%|██████████| 40/40 [00:00<00:00, 238.04it/s]
# train_batch (Avg. Loss 0.529, Accuracy 89.0): 100%|██████████| 40/40 [00:00<00:00, 101.76it/s]
# test_batch (Avg. Loss 2.154, Accuracy 28.5): 100%|██████████| 40/40 [00:00<00:00, 225.94it/s]
# train_batch (Avg. Loss 0.527, Accuracy 88.0): 100%|██████████| 40/40 [00:00<00:00, 104.42it/s]
# test_batch (Avg. Loss 2.157, Accuracy 27.9): 100%|██████████| 40/40 [00:00<00:00, 231.16it/s]
# --- EPOCH 79/80 ---
# train_batch (Avg. Loss 0.495, Accuracy 88.2): 100%|██████████| 40/40 [00:00<00:00, 97.54it/s]
# test_batch (Avg. Loss 2.165, Accuracy 28.9): 100%|██████████| 40/40 [00:00<00:00, 219.73it/s]
# --- EPOCH 80/80 ---
# train_batch (Avg. Loss 0.503, Accuracy 87.2): 100%|██████████| 40/40 [00:00<00:00, 91.72it/s]
# test_batch (Avg. Loss 2.161, Accuracy 28.4): 100%|██████████| 40/40 [00:00<00:00, 217.34it/s]
# *** Training with dropout= 0.8
# --- EPOCH 1/80 ---
# train_batch (Avg. Loss 3.197, Accuracy 11.2): 100%|██████████| 40/40 [00:00<00:00, 83.49it/s]
# test_batch (Avg. Loss 2.316, Accuracy 12.8): 100%|██████████| 40/40 [00:00<00:00, 139.34it/s]
# train_batch (Avg. Loss 2.650, Accuracy 13.2): 100%|██████████| 40/40 [00:00<00:00, 65.24it/s]
# test_batch (Avg. Loss 2.259, Accuracy 16.8): 100%|██████████| 40/40 [00:00<00:00, 208.29it/s]
# train_batch (Avg. Loss 2.533, Accuracy 15.8): 100%|██████████| 40/40 [00:00<00:00, 98.26it/s]
# test_batch (Avg. Loss 2.237, Accuracy 18.0): 100%|██████████| 40/40 [00:00<00:00, 229.83it/s]
# train_batch (Avg. Loss 2.421, Accuracy 12.5): 100%|██████████| 40/40 [00:00<00:00, 98.02it/s]
# test_batch (Avg. Loss 2.227, Accuracy 17.4): 100%|██████████| 40/40 [00:00<00:00, 236.63it/s]
# train_batch (Avg. Loss 2.327, Accuracy 18.2): 100%|██████████| 40/40 [00:00<00:00, 94.54it/s]
# test_batch (Avg. Loss 2.207, Accuracy 19.6): 100%|██████████| 40/40 [00:00<00:00, 231.16it/s]
# train_batch (Avg. Loss 2.272, Accuracy 14.2): 100%|██████████| 40/40 [00:00<00:00, 94.54it/s]
# test_batch (Avg. Loss 2.198, Accuracy 20.4): 100%|██████████| 40/40 [00:00<00:00, 233.87it/s]
# --- EPOCH 7/80 ---
# train_batch (Avg. Loss 2.215, Accuracy 20.0): 100%|██████████| 40/40 [00:00<00:00, 99.23it/s]
# test_batch (Avg. Loss 2.197, Accuracy 19.6): 100%|██████████| 40/40 [00:00<00:00, 233.87it/s]
# train_batch (Avg. Loss 2.195, Accuracy 19.2): 100%|██████████| 40/40 [00:00<00:00, 93.22it/s]
# test_batch (Avg. Loss 2.191, Accuracy 20.1): 100%|██████████| 40/40 [00:00<00:00, 183.44it/s]
# train_batch (Avg. Loss 2.215, Accuracy 17.0): 100%|██████████| 40/40 [00:00<00:00, 78.72it/s]
# test_batch (Avg. Loss 2.183, Accuracy 20.0): 100%|██████████| 40/40 [00:00<00:00, 228.52it/s]
# train_batch (Avg. Loss 2.150, Accuracy 20.5): 100%|██████████| 40/40 [00:00<00:00, 83.49it/s]
# test_batch (Avg. Loss 2.170, Accuracy 23.8): 100%|██████████| 40/40 [00:00<00:00, 201.98it/s]
# train_batch (Avg. Loss 2.179, Accuracy 19.8): 100%|██████████| 40/40 [00:00<00:00, 87.70it/s]
# test_batch (Avg. Loss 2.168, Accuracy 22.8): 100%|██████████| 40/40 [00:00<00:00, 206.14it/s]
# train_batch (Avg. Loss 2.196, Accuracy 19.8): 100%|██████████| 40/40 [00:00<00:00, 84.01it/s]
# test_batch (Avg. Loss 2.158, Accuracy 23.0): 100%|██████████| 40/40 [00:00<00:00, 192.26it/s]
# --- EPOCH 13/80 ---
# train_batch (Avg. Loss 2.125, Accuracy 20.0): 100%|██████████| 40/40 [00:00<00:00, 89.27it/s]
# test_batch (Avg. Loss 2.165, Accuracy 20.5): 100%|██████████| 40/40 [00:00<00:00, 227.22it/s]
# train_batch (Avg. Loss 2.071, Accuracy 24.0): 100%|██████████| 40/40 [00:00<00:00, 92.57it/s]
# test_batch (Avg. Loss 2.153, Accuracy 21.5): 100%|██████████| 40/40 [00:00<00:00, 198.96it/s]
# train_batch (Avg. Loss 2.108, Accuracy 20.2): 100%|██████████| 40/40 [00:00<00:00, 86.94it/s]
# test_batch (Avg. Loss 2.150, Accuracy 21.0): 100%|██████████| 40/40 [00:00<00:00, 229.83it/s]
# train_batch (Avg. Loss 2.085, Accuracy 24.2): 100%|██████████| 40/40 [00:00<00:00, 94.32it/s]
# test_batch (Avg. Loss 2.151, Accuracy 22.2): 100%|██████████| 40/40 [00:00<00:00, 219.73it/s]
# train_batch (Avg. Loss 2.038, Accuracy 29.2): 100%|██████████| 40/40 [00:00<00:00, 91.72it/s]
# test_batch (Avg. Loss 2.138, Accuracy 23.8): 100%|██████████| 40/40 [00:00<00:00, 235.24it/s]
# train_batch (Avg. Loss 2.039, Accuracy 26.2): 100%|██████████| 40/40 [00:00<00:00, 98.74it/s]
# test_batch (Avg. Loss 2.136, Accuracy 22.6): 100%|██████████| 40/40 [00:00<00:00, 236.63it/s]
# --- EPOCH 19/80 ---
# train_batch (Avg. Loss 2.058, Accuracy 27.8): 100%|██████████| 40/40 [00:00<00:00, 94.32it/s]
# test_batch (Avg. Loss 2.138, Accuracy 22.4): 100%|██████████| 40/40 [00:00<00:00, 233.87it/s]
# train_batch (Avg. Loss 2.034, Accuracy 29.5): 100%|██████████| 40/40 [00:00<00:00, 95.44it/s]
# test_batch (Avg. Loss 2.125, Accuracy 24.0): 100%|██████████| 40/40 [00:00<00:00, 232.51it/s]
# train_batch (Avg. Loss 2.069, Accuracy 26.5): 100%|██████████| 40/40 [00:00<00:00, 91.72it/s]
# test_batch (Avg. Loss 2.124, Accuracy 24.5): 100%|██████████| 40/40 [00:00<00:00, 223.41it/s]
# train_batch (Avg. Loss 2.009, Accuracy 27.8): 100%|██████████| 40/40 [00:00<00:00, 95.44it/s]
# test_batch (Avg. Loss 2.120, Accuracy 24.1): 100%|██████████| 40/40 [00:00<00:00, 224.67it/s]
# train_batch (Avg. Loss 2.016, Accuracy 25.8): 100%|██████████| 40/40 [00:00<00:00, 97.54it/s]
# test_batch (Avg. Loss 2.115, Accuracy 23.6): 100%|██████████| 40/40 [00:00<00:00, 229.83it/s]
# train_batch (Avg. Loss 2.039, Accuracy 25.8): 100%|██████████| 40/40 [00:00<00:00, 96.60it/s]
# test_batch (Avg. Loss 2.109, Accuracy 24.9): 100%|██████████| 40/40 [00:00<00:00, 219.73it/s]
# --- EPOCH 25/80 ---
# train_batch (Avg. Loss 1.964, Accuracy 29.0): 100%|██████████| 40/40 [00:00<00:00, 93.22it/s]
# test_batch (Avg. Loss 2.108, Accuracy 23.9): 100%|██████████| 40/40 [00:00<00:00, 222.17it/s]
# train_batch (Avg. Loss 1.989, Accuracy 27.5): 100%|██████████| 40/40 [00:00<00:00, 91.10it/s]
# test_batch (Avg. Loss 2.103, Accuracy 24.1): 100%|██████████| 40/40 [00:00<00:00, 210.48it/s]
# train_batch (Avg. Loss 1.974, Accuracy 29.8): 100%|██████████| 40/40 [00:00<00:00, 91.72it/s]
# test_batch (Avg. Loss 2.093, Accuracy 25.4): 100%|██████████| 40/40 [00:00<00:00, 219.73it/s]
# train_batch (Avg. Loss 1.956, Accuracy 29.0): 100%|██████████| 40/40 [00:00<00:00, 95.22it/s]
# test_batch (Avg. Loss 2.087, Accuracy 26.1): 100%|██████████| 40/40 [00:00<00:00, 222.17it/s]
# train_batch (Avg. Loss 1.963, Accuracy 27.5): 100%|██████████| 40/40 [00:00<00:00, 93.00it/s]
# test_batch (Avg. Loss 2.094, Accuracy 24.6): 100%|██████████| 40/40 [00:00<00:00, 222.17it/s]
# train_batch (Avg. Loss 1.993, Accuracy 26.2): 100%|██████████| 40/40 [00:00<00:00, 96.83it/s]
# test_batch (Avg. Loss 2.085, Accuracy 25.5): 100%|██████████| 40/40 [00:00<00:00, 208.29it/s]
# --- EPOCH 31/80 ---
# train_batch (Avg. Loss 1.946, Accuracy 32.2): 100%|██████████| 40/40 [00:00<00:00, 95.44it/s]
# test_batch (Avg. Loss 2.079, Accuracy 26.6): 100%|██████████| 40/40 [00:00<00:00, 218.53it/s]
# train_batch (Avg. Loss 1.980, Accuracy 30.2): 100%|██████████| 40/40 [00:00<00:00, 85.63it/s]
# test_batch (Avg. Loss 2.080, Accuracy 25.9): 100%|██████████| 40/40 [00:00<00:00, 219.73it/s]
# train_batch (Avg. Loss 1.931, Accuracy 33.5): 100%|██████████| 40/40 [00:00<00:00, 93.66it/s]
# test_batch (Avg. Loss 2.079, Accuracy 24.9): 100%|██████████| 40/40 [00:00<00:00, 206.14it/s]
# train_batch (Avg. Loss 1.940, Accuracy 28.5): 100%|██████████| 40/40 [00:00<00:00, 90.07it/s]
# test_batch (Avg. Loss 2.070, Accuracy 26.8): 100%|██████████| 40/40 [00:00<00:00, 231.16it/s]
# train_batch (Avg. Loss 1.933, Accuracy 29.5): 100%|██████████| 40/40 [00:00<00:00, 94.10it/s]
# test_batch (Avg. Loss 2.073, Accuracy 25.9): 100%|██████████| 40/40 [00:00<00:00, 231.16it/s]
# train_batch (Avg. Loss 1.908, Accuracy 30.5): 100%|██████████| 40/40 [00:00<00:00, 84.73it/s]
# test_batch (Avg. Loss 2.071, Accuracy 26.9): 100%|██████████| 40/40 [00:00<00:00, 213.86it/s]
# --- EPOCH 37/80 ---
# train_batch (Avg. Loss 1.928, Accuracy 32.8): 100%|██████████| 40/40 [00:00<00:00, 61.52it/s]
# test_batch (Avg. Loss 2.065, Accuracy 27.1): 100%|██████████| 40/40 [00:00<00:00, 201.98it/s]
# train_batch (Avg. Loss 1.900, Accuracy 31.8): 100%|██████████| 40/40 [00:00<00:00, 93.44it/s]
# test_batch (Avg. Loss 2.059, Accuracy 27.0): 100%|██████████| 40/40 [00:00<00:00, 224.67it/s]
# train_batch (Avg. Loss 1.875, Accuracy 30.5): 100%|██████████| 40/40 [00:00<00:00, 96.60it/s]
# test_batch (Avg. Loss 2.058, Accuracy 26.2): 100%|██████████| 40/40 [00:00<00:00, 233.87it/s]
# train_batch (Avg. Loss 1.884, Accuracy 33.5): 100%|██████████| 40/40 [00:00<00:00, 98.99it/s]
# test_batch (Avg. Loss 2.061, Accuracy 26.5): 100%|██████████| 40/40 [00:00<00:00, 233.86it/s]
# train_batch (Avg. Loss 1.889, Accuracy 33.2): 100%|██████████| 40/40 [00:00<00:00, 94.77it/s]
# test_batch (Avg. Loss 2.051, Accuracy 26.8): 100%|██████████| 40/40 [00:00<00:00, 228.52it/s]
# train_batch (Avg. Loss 1.842, Accuracy 35.5): 100%|██████████| 40/40 [00:00<00:00, 96.83it/s]
# test_batch (Avg. Loss 2.044, Accuracy 27.6): 100%|██████████| 40/40 [00:00<00:00, 236.63it/s]
# --- EPOCH 43/80 ---
# train_batch (Avg. Loss 1.833, Accuracy 37.5): 100%|██████████| 40/40 [00:00<00:00, 94.77it/s]
# test_batch (Avg. Loss 2.049, Accuracy 26.4): 100%|██████████| 40/40 [00:00<00:00, 228.52it/s]
# train_batch (Avg. Loss 1.865, Accuracy 35.2): 100%|██████████| 40/40 [00:00<00:00, 92.79it/s]
# test_batch (Avg. Loss 2.047, Accuracy 27.9): 100%|██████████| 40/40 [00:00<00:00, 229.83it/s]
# train_batch (Avg. Loss 1.872, Accuracy 32.2): 100%|██████████| 40/40 [00:00<00:00, 90.89it/s]
# test_batch (Avg. Loss 2.042, Accuracy 27.4): 100%|██████████| 40/40 [00:00<00:00, 215.01it/s]
# train_batch (Avg. Loss 1.854, Accuracy 36.0): 100%|██████████| 40/40 [00:00<00:00, 93.22it/s]
# test_batch (Avg. Loss 2.038, Accuracy 28.0): 100%|██████████| 40/40 [00:00<00:00, 222.17it/s]
# train_batch (Avg. Loss 1.844, Accuracy 35.8): 100%|██████████| 40/40 [00:00<00:00, 93.22it/s]
# test_batch (Avg. Loss 2.039, Accuracy 27.8): 100%|██████████| 40/40 [00:00<00:00, 218.53it/s]
# train_batch (Avg. Loss 1.853, Accuracy 33.8): 100%|██████████| 40/40 [00:00<00:00, 96.83it/s]
# test_batch (Avg. Loss 2.035, Accuracy 28.1): 100%|██████████| 40/40 [00:00<00:00, 224.67it/s]
# --- EPOCH 49/80 ---
# train_batch (Avg. Loss 1.814, Accuracy 38.5): 100%|██████████| 40/40 [00:00<00:00, 97.78it/s]
# test_batch (Avg. Loss 2.031, Accuracy 28.1): 100%|██████████| 40/40 [00:00<00:00, 231.16it/s]
# train_batch (Avg. Loss 1.826, Accuracy 34.8): 100%|██████████| 40/40 [00:00<00:00, 96.83it/s]
# test_batch (Avg. Loss 2.031, Accuracy 28.1): 100%|██████████| 40/40 [00:00<00:00, 229.84it/s]
# train_batch (Avg. Loss 1.796, Accuracy 37.5): 100%|██████████| 40/40 [00:00<00:00, 92.57it/s]
# test_batch (Avg. Loss 2.033, Accuracy 27.5): 100%|██████████| 40/40 [00:00<00:00, 231.16it/s]
# train_batch (Avg. Loss 1.799, Accuracy 36.2): 100%|██████████| 40/40 [00:00<00:00, 93.22it/s]
# test_batch (Avg. Loss 2.027, Accuracy 28.0): 100%|██████████| 40/40 [00:00<00:00, 223.41it/s]
# train_batch (Avg. Loss 1.801, Accuracy 36.8): 100%|██████████| 40/40 [00:00<00:00, 94.32it/s]
# test_batch (Avg. Loss 2.028, Accuracy 28.9): 100%|██████████| 40/40 [00:00<00:00, 231.16it/s]
# train_batch (Avg. Loss 1.837, Accuracy 32.8): 100%|██████████| 40/40 [00:00<00:00, 91.51it/s]
# test_batch (Avg. Loss 2.029, Accuracy 28.5): 100%|██████████| 40/40 [00:00<00:00, 228.52it/s]
# --- EPOCH 55/80 ---
# train_batch (Avg. Loss 1.759, Accuracy 37.5): 100%|██████████| 40/40 [00:00<00:00, 89.87it/s]
# test_batch (Avg. Loss 2.032, Accuracy 28.4): 100%|██████████| 40/40 [00:00<00:00, 223.41it/s]
# train_batch (Avg. Loss 1.795, Accuracy 36.0): 100%|██████████| 40/40 [00:00<00:00, 87.70it/s]
# test_batch (Avg. Loss 2.022, Accuracy 29.2): 100%|██████████| 40/40 [00:00<00:00, 209.38it/s]
# train_batch (Avg. Loss 1.793, Accuracy 39.0): 100%|██████████| 40/40 [00:00<00:00, 81.45it/s]
# test_batch (Avg. Loss 2.022, Accuracy 28.1): 100%|██████████| 40/40 [00:00<00:00, 228.52it/s]
# train_batch (Avg. Loss 1.800, Accuracy 35.0): 100%|██████████| 40/40 [00:00<00:00, 99.23it/s]
# test_batch (Avg. Loss 2.024, Accuracy 28.4): 100%|██████████| 40/40 [00:00<00:00, 239.47it/s]
# train_batch (Avg. Loss 1.783, Accuracy 37.8): 100%|██████████| 40/40 [00:00<00:00, 93.00it/s]
# test_batch (Avg. Loss 2.011, Accuracy 28.6): 100%|██████████| 40/40 [00:00<00:00, 233.87it/s]
# train_batch (Avg. Loss 1.807, Accuracy 35.5): 100%|██████████| 40/40 [00:00<00:00, 94.32it/s]
# test_batch (Avg. Loss 2.018, Accuracy 27.9): 100%|██████████| 40/40 [00:00<00:00, 233.87it/s]
# --- EPOCH 61/80 ---
# train_batch (Avg. Loss 1.780, Accuracy 38.2): 100%|██████████| 40/40 [00:00<00:00, 92.36it/s]
# test_batch (Avg. Loss 2.016, Accuracy 28.1): 100%|██████████| 40/40 [00:00<00:00, 224.67it/s]
# train_batch (Avg. Loss 1.793, Accuracy 35.5): 100%|██████████| 40/40 [00:00<00:00, 83.84it/s]
# test_batch (Avg. Loss 2.013, Accuracy 28.0): 100%|██████████| 40/40 [00:00<00:00, 207.21it/s]
# train_batch (Avg. Loss 1.809, Accuracy 34.5): 100%|██████████| 40/40 [00:00<00:00, 81.95it/s]
# test_batch (Avg. Loss 2.011, Accuracy 28.2): 100%|██████████| 40/40 [00:00<00:00, 192.26it/s]
# train_batch (Avg. Loss 1.747, Accuracy 39.5): 100%|██████████| 40/40 [00:00<00:00, 89.67it/s]
# test_batch (Avg. Loss 2.003, Accuracy 28.6): 100%|██████████| 40/40 [00:00<00:00, 227.22it/s]
# train_batch (Avg. Loss 1.740, Accuracy 39.8): 100%|██████████| 40/40 [00:00<00:00, 95.90it/s]
# test_batch (Avg. Loss 2.000, Accuracy 29.4): 100%|██████████| 40/40 [00:00<00:00, 238.04it/s]
# train_batch (Avg. Loss 1.719, Accuracy 40.0): 100%|██████████| 40/40 [00:00<00:00, 98.74it/s]
# test_batch (Avg. Loss 2.001, Accuracy 29.1): 100%|██████████| 40/40 [00:00<00:00, 228.52it/s]
# --- EPOCH 67/80 ---
# train_batch (Avg. Loss 1.757, Accuracy 39.2): 100%|██████████| 40/40 [00:00<00:00, 86.75it/s]
# test_batch (Avg. Loss 2.001, Accuracy 28.4): 100%|██████████| 40/40 [00:00<00:00, 212.72it/s]
# train_batch (Avg. Loss 1.694, Accuracy 42.0): 100%|██████████| 40/40 [00:00<00:00, 89.47it/s]
# test_batch (Avg. Loss 2.001, Accuracy 28.9): 100%|██████████| 40/40 [00:00<00:00, 217.34it/s]
# train_batch (Avg. Loss 1.717, Accuracy 41.2): 100%|██████████| 40/40 [00:00<00:00, 91.51it/s]
# test_batch (Avg. Loss 2.003, Accuracy 28.9): 100%|██████████| 40/40 [00:00<00:00, 224.67it/s]
# train_batch (Avg. Loss 1.726, Accuracy 40.5): 100%|██████████| 40/40 [00:00<00:00, 93.66it/s]
# test_batch (Avg. Loss 2.004, Accuracy 28.8): 100%|██████████| 40/40 [00:00<00:00, 228.52it/s]
# train_batch (Avg. Loss 1.756, Accuracy 38.0): 100%|██████████| 40/40 [00:00<00:00, 90.27it/s]
# test_batch (Avg. Loss 2.007, Accuracy 28.0): 100%|██████████| 40/40 [00:00<00:00, 220.94it/s]
# train_batch (Avg. Loss 1.717, Accuracy 41.5): 100%|██████████| 40/40 [00:00<00:00, 90.07it/s]
# test_batch (Avg. Loss 2.001, Accuracy 29.6): 100%|██████████| 40/40 [00:00<00:00, 204.04it/s]
# --- EPOCH 73/80 ---
# train_batch (Avg. Loss 1.716, Accuracy 40.2): 100%|██████████| 40/40 [00:00<00:00, 87.89it/s]
# test_batch (Avg. Loss 1.992, Accuracy 29.8): 100%|██████████| 40/40 [00:00<00:00, 218.53it/s]
# train_batch (Avg. Loss 1.731, Accuracy 39.8): 100%|██████████| 40/40 [00:00<00:00, 89.47it/s]
# test_batch (Avg. Loss 2.000, Accuracy 29.5): 100%|██████████| 40/40 [00:00<00:00, 215.01it/s]
# train_batch (Avg. Loss 1.723, Accuracy 40.2): 100%|██████████| 40/40 [00:00<00:00, 88.87it/s]
# test_batch (Avg. Loss 2.000, Accuracy 29.0): 100%|██████████| 40/40 [00:00<00:00, 211.59it/s]
# train_batch (Avg. Loss 1.701, Accuracy 41.5): 100%|██████████| 40/40 [00:00<00:00, 90.27it/s]
# test_batch (Avg. Loss 1.989, Accuracy 30.2): 100%|██████████| 40/40 [00:00<00:00, 217.34it/s]
# train_batch (Avg. Loss 1.672, Accuracy 44.0): 100%|██████████| 40/40 [00:00<00:00, 92.79it/s]
# test_batch (Avg. Loss 1.983, Accuracy 30.9): 100%|██████████| 40/40 [00:00<00:00, 225.94it/s]
# train_batch (Avg. Loss 1.659, Accuracy 44.0): 100%|██████████| 40/40 [00:00<00:00, 94.54it/s]
# test_batch (Avg. Loss 1.990, Accuracy 29.4): 100%|██████████| 40/40 [00:00<00:00, 224.67it/s]
# --- EPOCH 79/80 ---
# train_batch (Avg. Loss 1.717, Accuracy 42.5): 100%|██████████| 40/40 [00:00<00:00, 91.51it/s]
# test_batch (Avg. Loss 1.984, Accuracy 30.1): 100%|██████████| 40/40 [00:00<00:00, 211.59it/s]
# --- EPOCH 80/80 ---
# train_batch (Avg. Loss 1.657, Accuracy 46.5): 100%|██████████| 40/40 [00:00<00:00, 87.51it/s]
# test_batch (Avg. Loss 1.988, Accuracy 29.4): 100%|██████████| 40/40 [00:00<00:00, 209.38it/s]

# %% [markdown]
# ## Questions
# <a id=part2_7></a>

# %% [markdown]
# **TODO** Answer the following questions. Write your answers in the appropriate variables in the module `hw2/answers.py`.

# %%
from helpers.answers import display_answer
import hw2.answers

# %% [markdown]
# ### Question 1
#
# Regarding the graphs you got for the three dropout configurations:
#
# 1. Explain the graphs of no-dropout vs dropout. Do they match what you expected to see?
#     - If yes, explain why and provide examples based on the graphs.
#     - If no, explain what you think the problem is and what should be modified to fix it.
#
# 2. Compare the low-dropout setting to the high-dropout setting and explain based on your graphs.

# %%
display_answer(hw2.answers.part2_q1)
# Out:
# **Your answer:**
# 1. They mostly match what we expected to see.
# We trained the model without dropout until it overfits - achieving near perfect results on the training set but
# only about 20% for the test set.
# As expected, dropout helps us to avoid overfitting with 30 epochs - as soon as we turned on dropout (with both
# probability values) the model improves on the test set (it overfits less w.r.t the training set).
# Seeing as dropout aims to reach a more sparse representation of the data, I think running with more epochs and dropout parameters
# would be interesting to check how changing the dropout value affects convergence rate and the achieved test set accuracy.
# 2. Dropout with 0.4 achieved better result compared to the 0.8 one for 30 epochs.
# Intuitively, since higher dropout means we use less of our data, we should require more epochs when increasing it.
# Here both models train for the same amount of epochs so it makes sense that the 0.4 one got better results.
# Given enough epochs its possible that 0.8 dropout model could pull ahead of the 0.4 one in terms of test set accuracy.
# We tried this expriment with 80 epochs and indeed in our case the model with 0.8 dropout got the best test set accuracy.

# %% [markdown]
# ### Question 2
#
# When training a model with the cross-entropy loss function, is it possible for the test loss to **increase** for a few epochs while the test accuracy also **increases**?
#
# If it's possible explain how, if it's not explain why not.

# %%
display_answer(hw2.answers.part2_q2)
# Out:
# **Your answer:**
# Yes, its possible. The Cross Entropy loss receives as arguments the class scores $\hat{y}$ and the real labels $y$.
# In order to increase the loss, the score of the right class (denoted $x_y$) needs to decrease. Note that the sum-log-exp
# term weights the same whether $x_y$ is the right class or not.
# In order to increase the test accuracy, we need more samples such that $x_y$ is the maximum class score.
# Both can happen simultaneously - the score of the right class can decrease while still remaining the maximum score,
# or it can decrease and then become the maximum score (because other classes decreased further).
# In conclusion, this can happen - especially at the first few epochs before convergance is achieved.
